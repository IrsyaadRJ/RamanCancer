# %%
# %cd /kaggle/input/chemcancer-v2/src/
# %mkdir /kaggle/working/Deep_Learning_metrics/
# %mkdir /kaggle/working/During_train/
# %mkdir /kaggle/working/CV_CNN_models
# %mkdir /kaggle/working/CV_CNN_results
# %mkdir /kaggle/working/CV_CNN_fold_data
# %mkdir /kaggle/working/CV_CNN_cm
# Out:
# /kaggle/input/chemcancer-v2/src

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tensorflow.keras.optimizers import Adam
from data import *
from machine_learning_models import *
from deep_learning_models import *
from vision_transformer import *
from utils_dl_model import *
from utils_ml_model import print_ml_results
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
# Set the seed value.
SEED = 7
np.random.seed(SEED)

# Deep Learning parameters
DL_EPOCH = 500
DL_BATCH_SIZE = 32
DL_CNN_VERSION = 3
DL_TRANSFORMER_VISION_VERSION = 14
DL_CV_FOLD = 5

DO_DL = True
CV_DL = True
OPT_DL = False

DO_CNN = True
DO_TRANSFORMER_VISION = False
DO_ML = False

# Percentage of test set out of the dataset.
TEST_SET = 0.2

# Percentage of validation set out of the training dataset.
VAL_SET = 0.2

# Folder path associated with deep learning models
dl_models_folder = "../Deep_Learning_models/"
dl_metrics_folder = "../Deep_Learning_metrics/"
dl_weights_folder = "../Deep_Learning_weights/"
dl_cv_models_folder = "../Deep_Learning_CV/"
dl_cv_results_folder = "../Deep_Learning_CV_results/"

# Folder path associated with machine learning models
ml_models_folder = "../Machine_Learning_models/"
ml_models_results_folder = "../Machine_Learning_models_results/"

# Model names (Saved in h5 format)
cnn_model_name = f"cnn_v{DL_CNN_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"
transformer_vis_model_name = f"transformer_vision_v{DL_TRANSFORMER_VISION_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"

# Metric filenames
cnn_metrics_filename = f"metrics_{cnn_model_name}.json"
transformer_vis_metrics_filename = f"metrics_{transformer_vis_model_name}.json"

# Weight filenames
cnn_weights_filename = f"weights_{cnn_model_name}.json"
transformer_vis_weights_filename = f"weights_{transformer_vis_model_name}.json"


# Deep Learning models path
if DO_CNN:
    dl_model_path = os.path.join(
        dl_models_folder, cnn_model_name)
elif DO_TRANSFORMER_VISION:
    dl_model_path = os.path.join(
        dl_models_folder, transformer_vis_model_name)


# Deep Learning metrics path
if DO_CNN:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, cnn_metrics_filename)
elif DO_TRANSFORMER_VISION:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, transformer_vis_metrics_filename)


# Deep Learning weights path
if DO_CNN:
    dl_weights_path = os.path.join(
        dl_weights_folder, cnn_weights_filename)

elif DO_TRANSFORMER_VISION:
    dl_weights_path = os.path.join(
        dl_weights_folder, transformer_vis_weights_filename)

# %%
# Load the data
data_file = "../Data/HC05_HC07.csv"

if OPT_DL:
    X_filtered, y = preprocess_cv_raw_data(data_file)
    optimize_hyperparameters(X_filtered, y, 50, dl_cv_models_folder, dl_cv_results_folder)

else:
    # Train deep learning model with cross validation
    if CV_DL:
        X_filtered, y = preprocess_cv_raw_data(data_file)
    else:
        # Preprocess the raw data
        X_train, X_test, y_train, y_test = preprocess_raw_data(
            data_file, TEST_SET)

# Do Deep Learning
if DO_DL:
    dl_weights_path = "../During_train/cnn_v3-250-val_acc0.86.h5"
    if os.path.exists(dl_model_path):
        if DO_TRANSFORMER_VISION:
            model = tf.keras.models.load_model(
                dl_model_path, custom_objects={'ClassToken': ClassToken, 'TransformerBlock': TransformerBlock})
        elif DO_CNN:
            model = tf.keras.models.load_model(dl_model_path)
            print("Loaded trained model from", dl_model_path)
    elif os.path.exists(dl_weights_path):
        if DO_TRANSFORMER_VISION:
            print("hello")
            # model = create_vit(input_shape, patch_size, num_patches, num_classes,
            #                         embed_dim, num_heads, mlp_dim, num_layers, dropout_rate)
            # model.load_weights(dl_weights_path)
        elif DO_CNN:
            X_train = X_train.reshape(
                X_train.shape[0], X_train.shape[1], 1)
            X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
            input_shape = (X_train.shape[1], 1)
            num_classes = len(np.unique(y_train))
            learning_rate = 1.4286522423518213e-09
            dropout_rate = 0.2
            l2_regularizer = 0.000417822262290105
            model = cnn_model_3_opt(
                input_shape, num_classes, learning_rate, dropout_rate, l2_regularizer)
            model.load_weights(dl_weights_path)
            print("Loaded trained model weights from", dl_weights_path)
            # Evaluating the model
            print("Evaluating the CNN model... ")
            # Calculate model loss and accuracy
            test_loss, test_accuracy = model.evaluate(X_test, y_test)
            print("Test loss:", test_loss)
            print("Test accuracy:", test_accuracy)
    else:
        if CV_DL:
            # learning_rate = 3.408170980489466e-05
            # dropout_rate = 0.3
            # l2_regularizer = 0.00010124894257897855
            if DO_CNN:
                learning_rate = 1.4286522423518213e-05
                dropout_rate = 0.4
                l2_regularizer = 0.000417822262290105
                # Start the timer
                start_time = time.time()
                perform_cnn_cv(X_filtered, y, learning_rate, dropout_rate, l2_regularizer,
                                        n_splits=DL_CV_FOLD, epochs=DL_EPOCH, batch_size=DL_BATCH_SIZE, cnn_version=DL_CNN_VERSION,
                                        do_opt=True, models_folder="/kaggle/working/CV_CNN_models", results_folder= "/kaggle/working/CV_CNN_results")
                # End the timer
                end_time = time.time()
                # Calculate the elapsed time
                elapsed_time = end_time - start_time
                # Print the elapsed time
                print("Training time: {:.2f} seconds".format(elapsed_time))
            elif DO_TRANSFORMER_VISION:
                # Train and evaluate deep learning models
                print("Building Transformer model...")
                patch_size = 30
                embed_dim = 64
                num_heads = 4
                mlp_dim = 128  # patch_size * patch_size * input_shape[1]
                num_layers = 4
                dropout_rate = 0.3

                # Create the model
                perform_vit_cross_validation(X_filtered, y, patch_size, embed_dim, num_heads, mlp_dim, num_layers, dropout_rate,
                                            n_splits=DL_CV_FOLD, epochs=DL_EPOCH, batch_size=DL_BATCH_SIZE, 
                                            vit_version = DL_TRANSFORMER_VISION_VERSION, val_set = 0.2,
                                            do_opt = True, models_folder = "/kaggle/working/CV_VIT_models", results_folder = "/kaggle/working/CV_VIT_results")

        else:
            # Reshape the input data for deep learning models
            print("Reshaping the data for CNN model...")
            X_train = X_train.reshape(
                X_train.shape[0], X_train.shape[1], 1)
            X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
            input_shape = (X_train.shape[1], 1)
            num_classes = len(np.unique(y_train))

            # Splitting the training data to create a validation set
            print("Splitting the training data to create a validation set...")
            X_train, X_val, y_train, y_val = train_test_split(
                X_train, y_train, test_size=VAL_SET, random_state=SEED, stratify=y_train)

            filepath = ""

            if DO_CNN:
                # Train and evaluate deep learning models
                print("Building CNN model...")
                # model = cnn_model_3_3(input_shape, num_classes)
                # learning_rate = 3.408170980489466e-05
                # dropout_rate = 0.3
                # l2_regularizer = 0.00010124894257897855
                learning_rate = 1.4286522423518213e-05
                dropout_rate = 0.2
                l2_regularizer = 0.000417822262290105
                model = cnn_model_3_opt(
                    input_shape, num_classes, learning_rate, dropout_rate, l2_regularizer)

                filepath = '../During_train/cnn_v3-{epoch:02d}-val_acc{val_accuracy:.2f}.h5'

            elif DO_TRANSFORMER_VISION:
                # Train and evaluate deep learning models
                print("Building Transformer model...")
                # Define model parameters
                print(f"X_train shape = {X_train.shape}")
                input_shape = (X_train.shape[1], 1)  # (270,1)
                # cancer cell lines, monocytes, and T-cells
                num_classes = len(np.unique(y_train))
                patch_size = 3
                num_patches = input_shape[0] // patch_size
                embed_dim = 64
                num_heads = 4
                mlp_dim = 128  # patch_size * patch_size * input_shape[1]
                num_layers = 4
                dropout_rate = 0.3

                # Create the model
                model = create_vit(input_shape, patch_size, num_patches, num_classes,
                                   embed_dim, num_heads, mlp_dim, num_layers, dropout_rate)
                model.summary()
                # Compile the model
                model.compile(
                    optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
                filepath = '../During_train/vit_v11-{epoch:02d}-val_acc{val_accuracy:.2f}.h5'

            # Train the model
            print("Training and evaluating the model...")
            # Start the timer
            start_time = time.time()
            model_history = model.fit(X_train, y_train, batch_size=DL_BATCH_SIZE,
                                      epochs=DL_EPOCH, validation_data=(X_val, y_val), shuffle=True, callbacks=callbacks)
            # End the timer
            end_time = time.time()
            # Calculate the elapsed time
            elapsed_time = end_time - start_time
            # Print the elapsed time
            print("Training time: {:.2f} seconds".format(elapsed_time))
            # Compile the model

            # Save the deep learning model
            print("Saving model to ", dl_model_path)
            model.save(dl_model_path)

            # Save the deep learning model's weights
            print("Saving model weights to ", dl_weights_path)
            model.save_weights(dl_weights_path)

            # Evaluating the model
            print("Evaluating the CNN model... ")
            # Calculate model loss and accuracy
            test_loss, test_accuracy = model.evaluate(X_test, y_test)
            print("Test loss:", test_loss)
            print("Test accuracy:", test_accuracy)

            # Save the model's metrics
            print("Saving the model metrics to ", dl_metrics_path)
            save_dl_metrics(model_history, test_loss,
                            test_accuracy, dl_metrics_path)

            # Plot the model history
            plot_dl_history(model_history)
# Out:
# Load the data
# Data shape : (2373, 274)
# Extract the feature and target data
# X shaped: (2373, 270)
# y shaped: (2373,)
# Apply filters and background substraction to the features dataset
# ========================================
# Fold: 1
# Splitting the data
# Standardizing the data
# Reshaping the data for deep learning models
# Building the model 3 with the following hyperparameters:
# Learning rate: 1.4286522423518213e-05
# Dropout rate: 0.4
# L2 Regularizer: 0.000417822262290105
# Number of epochs: 500
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/500
# 48/48 [==============================] - 11s 15ms/step - loss: 2.2681 - accuracy: 0.3472 - val_loss: 1.3659 - val_accuracy: 0.3158
# Epoch 2/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.7819 - accuracy: 0.3465 - val_loss: 1.3679 - val_accuracy: 0.3184
# Epoch 3/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.6047 - accuracy: 0.3518 - val_loss: 1.3368 - val_accuracy: 0.3711
# Epoch 4/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.4554 - accuracy: 0.3762 - val_loss: 1.3622 - val_accuracy: 0.3289
# Epoch 5/500
# 48/48 [==============================] - 1s 11ms/step - loss: 1.4166 - accuracy: 0.3669 - val_loss: 1.3503 - val_accuracy: 0.2895
# Epoch 6/500
# 48/48 [==============================] - 1s 11ms/step - loss: 1.3885 - accuracy: 0.3755 - val_loss: 1.3256 - val_accuracy: 0.3632
# Epoch 7/500
# 48/48 [==============================] - 1s 11ms/step - loss: 1.3529 - accuracy: 0.3966 - val_loss: 1.3272 - val_accuracy: 0.3737
# Epoch 8/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3485 - accuracy: 0.3827 - val_loss: 1.3243 - val_accuracy: 0.3447
# Epoch 9/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3493 - accuracy: 0.3926 - val_loss: 1.3266 - val_accuracy: 0.3789
# Epoch 10/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3364 - accuracy: 0.3775 - val_loss: 1.3155 - val_accuracy: 0.3921
# Epoch 11/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3361 - accuracy: 0.3860 - val_loss: 1.3086 - val_accuracy: 0.3763
# Epoch 12/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.3337 - accuracy: 0.3999 - val_loss: 1.3041 - val_accuracy: 0.3947
# Epoch 13/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3085 - accuracy: 0.4177 - val_loss: 1.3026 - val_accuracy: 0.3579
# Epoch 14/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3185 - accuracy: 0.3913 - val_loss: 1.2978 - val_accuracy: 0.4000
# Epoch 15/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3126 - accuracy: 0.3926 - val_loss: 1.2957 - val_accuracy: 0.4211
# Epoch 16/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3083 - accuracy: 0.4058 - val_loss: 1.2846 - val_accuracy: 0.4395
# Epoch 17/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.3020 - accuracy: 0.3986 - val_loss: 1.2837 - val_accuracy: 0.4368
# Epoch 18/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3009 - accuracy: 0.3841 - val_loss: 1.2778 - val_accuracy: 0.4395
# Epoch 19/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.2968 - accuracy: 0.4084 - val_loss: 1.2724 - val_accuracy: 0.4316
# Epoch 20/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2877 - accuracy: 0.4315 - val_loss: 1.2718 - val_accuracy: 0.4316
# Epoch 21/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2892 - accuracy: 0.4256 - val_loss: 1.2723 - val_accuracy: 0.3974
# Epoch 22/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2752 - accuracy: 0.4177 - val_loss: 1.2678 - val_accuracy: 0.4263
# Epoch 23/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2789 - accuracy: 0.4032 - val_loss: 1.2709 - val_accuracy: 0.4026
# Epoch 24/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2710 - accuracy: 0.4321 - val_loss: 1.2569 - val_accuracy: 0.4447
# Epoch 25/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2712 - accuracy: 0.4157 - val_loss: 1.2623 - val_accuracy: 0.3921
# Epoch 26/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2569 - accuracy: 0.4348 - val_loss: 1.2601 - val_accuracy: 0.4158
# Epoch 27/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2635 - accuracy: 0.4308 - val_loss: 1.2513 - val_accuracy: 0.4395
# Epoch 28/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.2588 - accuracy: 0.4394 - val_loss: 1.2412 - val_accuracy: 0.4395
# Epoch 29/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2549 - accuracy: 0.4170 - val_loss: 1.2436 - val_accuracy: 0.4474
# Epoch 30/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.2525 - accuracy: 0.4447 - val_loss: 1.2396 - val_accuracy: 0.4263
# Epoch 31/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.2524 - accuracy: 0.4302 - val_loss: 1.2287 - val_accuracy: 0.4500
# Epoch 32/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2333 - accuracy: 0.4315 - val_loss: 1.2191 - val_accuracy: 0.4737
# Epoch 33/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2303 - accuracy: 0.4414 - val_loss: 1.2201 - val_accuracy: 0.4789
# Epoch 34/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2491 - accuracy: 0.4223 - val_loss: 1.2224 - val_accuracy: 0.4526
# Epoch 35/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2341 - accuracy: 0.4275 - val_loss: 1.2115 - val_accuracy: 0.4579
# Epoch 36/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.2275 - accuracy: 0.4440 - val_loss: 1.2139 - val_accuracy: 0.4289
# Epoch 37/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2369 - accuracy: 0.4440 - val_loss: 1.2040 - val_accuracy: 0.4421
# Epoch 38/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.2162 - accuracy: 0.4433 - val_loss: 1.2033 - val_accuracy: 0.4816
# Epoch 39/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2199 - accuracy: 0.4368 - val_loss: 1.1959 - val_accuracy: 0.4789
# Epoch 40/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2041 - accuracy: 0.4513 - val_loss: 1.1973 - val_accuracy: 0.4868
# Epoch 41/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2023 - accuracy: 0.4513 - val_loss: 1.1905 - val_accuracy: 0.4816
# Epoch 42/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1993 - accuracy: 0.4473 - val_loss: 1.1957 - val_accuracy: 0.4474
# Epoch 43/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1940 - accuracy: 0.4414 - val_loss: 1.1894 - val_accuracy: 0.4500
# Epoch 44/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.1848 - accuracy: 0.4657 - val_loss: 1.1835 - val_accuracy: 0.4526
# Epoch 45/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1925 - accuracy: 0.4519 - val_loss: 1.1846 - val_accuracy: 0.4737
# Epoch 46/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1902 - accuracy: 0.4618 - val_loss: 1.1817 - val_accuracy: 0.4526
# Epoch 47/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1708 - accuracy: 0.4723 - val_loss: 1.1610 - val_accuracy: 0.4789
# Epoch 48/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1645 - accuracy: 0.4460 - val_loss: 1.1589 - val_accuracy: 0.4684
# Epoch 49/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1603 - accuracy: 0.4644 - val_loss: 1.1559 - val_accuracy: 0.4684
# Epoch 50/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1631 - accuracy: 0.4539 - val_loss: 1.1679 - val_accuracy: 0.4579
# Epoch 51/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1598 - accuracy: 0.4736 - val_loss: 1.1444 - val_accuracy: 0.4474
# Epoch 52/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1625 - accuracy: 0.4704 - val_loss: 1.1409 - val_accuracy: 0.4789
# Epoch 53/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.1624 - accuracy: 0.4789 - val_loss: 1.1385 - val_accuracy: 0.4868
# Epoch 54/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1487 - accuracy: 0.4789 - val_loss: 1.1395 - val_accuracy: 0.4658
# Epoch 55/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1665 - accuracy: 0.4657 - val_loss: 1.1370 - val_accuracy: 0.4895
# Epoch 56/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1529 - accuracy: 0.4769 - val_loss: 1.1340 - val_accuracy: 0.4947
# Epoch 57/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1437 - accuracy: 0.4750 - val_loss: 1.1283 - val_accuracy: 0.4895
# Epoch 58/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1369 - accuracy: 0.4783 - val_loss: 1.1252 - val_accuracy: 0.4895
# Epoch 59/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1429 - accuracy: 0.4802 - val_loss: 1.1245 - val_accuracy: 0.4763
# Epoch 60/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1289 - accuracy: 0.5033 - val_loss: 1.1147 - val_accuracy: 0.4816
# Epoch 61/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1282 - accuracy: 0.4789 - val_loss: 1.1103 - val_accuracy: 0.4763
# Epoch 62/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1241 - accuracy: 0.4941 - val_loss: 1.1103 - val_accuracy: 0.4763
# Epoch 63/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1212 - accuracy: 0.4901 - val_loss: 1.0969 - val_accuracy: 0.4842
# Epoch 64/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.1090 - accuracy: 0.4954 - val_loss: 1.0981 - val_accuracy: 0.4789
# Epoch 65/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1094 - accuracy: 0.4941 - val_loss: 1.1081 - val_accuracy: 0.5053
# Epoch 66/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.1028 - accuracy: 0.5132 - val_loss: 1.0966 - val_accuracy: 0.5105
# Epoch 67/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.1144 - accuracy: 0.4941 - val_loss: 1.0901 - val_accuracy: 0.5132
# Epoch 68/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0963 - accuracy: 0.4987 - val_loss: 1.0859 - val_accuracy: 0.5263
# Epoch 69/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.1060 - accuracy: 0.4796 - val_loss: 1.0802 - val_accuracy: 0.5053
# Epoch 70/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0966 - accuracy: 0.4875 - val_loss: 1.0821 - val_accuracy: 0.5316
# Epoch 71/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.1054 - accuracy: 0.5119 - val_loss: 1.0856 - val_accuracy: 0.5079
# Epoch 72/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.0859 - accuracy: 0.5079 - val_loss: 1.0515 - val_accuracy: 0.5184
# Epoch 73/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0811 - accuracy: 0.5125 - val_loss: 1.0433 - val_accuracy: 0.5526
# Epoch 74/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.0779 - accuracy: 0.5092 - val_loss: 1.0567 - val_accuracy: 0.5368
# Epoch 75/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.0725 - accuracy: 0.5231 - val_loss: 1.0368 - val_accuracy: 0.5289
# Epoch 76/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0687 - accuracy: 0.5237 - val_loss: 1.0308 - val_accuracy: 0.5368
# Epoch 77/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0645 - accuracy: 0.5303 - val_loss: 1.0156 - val_accuracy: 0.5684
# Epoch 78/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0367 - accuracy: 0.5250 - val_loss: 1.0306 - val_accuracy: 0.5605
# Epoch 79/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0645 - accuracy: 0.5382 - val_loss: 1.0016 - val_accuracy: 0.5579
# Epoch 80/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.0486 - accuracy: 0.5310 - val_loss: 1.0038 - val_accuracy: 0.5500
# Epoch 81/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0490 - accuracy: 0.5448 - val_loss: 1.0308 - val_accuracy: 0.5579
# Epoch 82/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.0618 - accuracy: 0.5237 - val_loss: 1.0256 - val_accuracy: 0.5763
# Epoch 83/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0524 - accuracy: 0.5296 - val_loss: 0.9973 - val_accuracy: 0.5947
# Epoch 84/500
# 48/48 [==============================] - 1s 13ms/step - loss: 1.0477 - accuracy: 0.5599 - val_loss: 0.9763 - val_accuracy: 0.6026
# Epoch 85/500
# 48/48 [==============================] - 1s 12ms/step - loss: 1.0199 - accuracy: 0.5725 - val_loss: 0.9523 - val_accuracy: 0.6211
# Epoch 86/500
# 48/48 [==============================] - 0s 10ms/step - loss: 1.0321 - accuracy: 0.5613 - val_loss: 0.9573 - val_accuracy: 0.6263
# Epoch 87/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0024 - accuracy: 0.5626 - val_loss: 0.9607 - val_accuracy: 0.6158
# Epoch 88/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.0117 - accuracy: 0.5626 - val_loss: 0.9888 - val_accuracy: 0.5842
# Epoch 89/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0068 - accuracy: 0.5837 - val_loss: 0.9474 - val_accuracy: 0.6105
# Epoch 90/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9903 - accuracy: 0.5889 - val_loss: 0.9348 - val_accuracy: 0.6316
# Epoch 91/500
# 48/48 [==============================] - 0s 9ms/step - loss: 1.0142 - accuracy: 0.5896 - val_loss: 0.9612 - val_accuracy: 0.5842
# Epoch 92/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.9747 - accuracy: 0.5883 - val_loss: 0.9073 - val_accuracy: 0.6447
# Epoch 93/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9703 - accuracy: 0.6186 - val_loss: 0.8836 - val_accuracy: 0.6368
# Epoch 94/500
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0015 - accuracy: 0.5771 - val_loss: 0.9038 - val_accuracy: 0.6632
# Epoch 95/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9544 - accuracy: 0.6014 - val_loss: 0.9192 - val_accuracy: 0.6342
# Epoch 96/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.9689 - accuracy: 0.6001 - val_loss: 0.8836 - val_accuracy: 0.6553
# Epoch 97/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.9715 - accuracy: 0.6054 - val_loss: 0.8948 - val_accuracy: 0.6421
# Epoch 98/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.9542 - accuracy: 0.6146 - val_loss: 0.8815 - val_accuracy: 0.6711
# Epoch 99/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9764 - accuracy: 0.5935 - val_loss: 0.8876 - val_accuracy: 0.6711
# Epoch 100/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9528 - accuracy: 0.6265 - val_loss: 0.9415 - val_accuracy: 0.5895
# Epoch 101/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9523 - accuracy: 0.6238 - val_loss: 0.8746 - val_accuracy: 0.6474
# Epoch 102/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9736 - accuracy: 0.6159 - val_loss: 0.8548 - val_accuracy: 0.6737
# Epoch 103/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9335 - accuracy: 0.6469 - val_loss: 0.8333 - val_accuracy: 0.6684
# Epoch 104/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.9349 - accuracy: 0.6271 - val_loss: 0.8678 - val_accuracy: 0.6868
# Epoch 105/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9384 - accuracy: 0.6469 - val_loss: 0.8340 - val_accuracy: 0.6711
# Epoch 106/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8902 - accuracy: 0.6640 - val_loss: 0.8419 - val_accuracy: 0.6526
# Epoch 107/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9357 - accuracy: 0.6423 - val_loss: 0.8465 - val_accuracy: 0.6684
# Epoch 108/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9031 - accuracy: 0.6456 - val_loss: 0.8372 - val_accuracy: 0.7053
# Epoch 109/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9076 - accuracy: 0.6706 - val_loss: 0.8154 - val_accuracy: 0.7237
# Epoch 110/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8989 - accuracy: 0.6601 - val_loss: 0.8195 - val_accuracy: 0.7026
# Epoch 111/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8678 - accuracy: 0.6700 - val_loss: 0.8110 - val_accuracy: 0.7211
# Epoch 112/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.8891 - accuracy: 0.6752 - val_loss: 0.8167 - val_accuracy: 0.6974
# Epoch 113/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.8742 - accuracy: 0.6798 - val_loss: 0.7945 - val_accuracy: 0.7079
# Epoch 114/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.8592 - accuracy: 0.7022 - val_loss: 0.7761 - val_accuracy: 0.7158
# Epoch 115/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8946 - accuracy: 0.6746 - val_loss: 0.7994 - val_accuracy: 0.6974
# Epoch 116/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8485 - accuracy: 0.7062 - val_loss: 0.8178 - val_accuracy: 0.7079
# Epoch 117/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.8699 - accuracy: 0.6858 - val_loss: 0.7724 - val_accuracy: 0.7079
# Epoch 118/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8392 - accuracy: 0.7036 - val_loss: 0.7777 - val_accuracy: 0.7184
# Epoch 119/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8247 - accuracy: 0.7200 - val_loss: 0.7506 - val_accuracy: 0.7553
# Epoch 120/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8454 - accuracy: 0.6937 - val_loss: 0.7775 - val_accuracy: 0.7026
# Epoch 121/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8199 - accuracy: 0.7207 - val_loss: 0.8688 - val_accuracy: 0.6474
# Epoch 122/500
# 48/48 [==============================] - 1s 12ms/step - loss: 0.8467 - accuracy: 0.7062 - val_loss: 0.8212 - val_accuracy: 0.7105
# Epoch 123/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.8306 - accuracy: 0.7036 - val_loss: 0.7695 - val_accuracy: 0.7079
# Epoch 124/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.7942 - accuracy: 0.7154 - val_loss: 0.7860 - val_accuracy: 0.7105
# Epoch 125/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.7993 - accuracy: 0.7246 - val_loss: 0.7672 - val_accuracy: 0.7053
# Epoch 126/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8109 - accuracy: 0.7246 - val_loss: 0.9096 - val_accuracy: 0.6368
# Epoch 127/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.8103 - accuracy: 0.7213 - val_loss: 0.8784 - val_accuracy: 0.6605
# Epoch 128/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.8177 - accuracy: 0.7279 - val_loss: 0.7941 - val_accuracy: 0.7184
# Epoch 129/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.8192 - accuracy: 0.7299 - val_loss: 0.7266 - val_accuracy: 0.7632
# Epoch 130/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.8015 - accuracy: 0.7378 - val_loss: 0.7570 - val_accuracy: 0.7553
# Epoch 131/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7760 - accuracy: 0.7510 - val_loss: 0.7053 - val_accuracy: 0.7737
# Epoch 132/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7585 - accuracy: 0.7516 - val_loss: 0.7312 - val_accuracy: 0.7500
# Epoch 133/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7763 - accuracy: 0.7312 - val_loss: 0.7586 - val_accuracy: 0.7526
# Epoch 134/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7471 - accuracy: 0.7523 - val_loss: 0.7240 - val_accuracy: 0.7711
# Epoch 135/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8107 - accuracy: 0.7411 - val_loss: 0.7477 - val_accuracy: 0.7763
# Epoch 136/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7734 - accuracy: 0.7457 - val_loss: 0.7851 - val_accuracy: 0.7026
# Epoch 137/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.7569 - accuracy: 0.7490 - val_loss: 0.7281 - val_accuracy: 0.7447
# Epoch 138/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7712 - accuracy: 0.7477 - val_loss: 0.7081 - val_accuracy: 0.7816
# Epoch 139/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7760 - accuracy: 0.7516 - val_loss: 0.7273 - val_accuracy: 0.7605
# Epoch 140/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.7432 - accuracy: 0.7576 - val_loss: 0.7261 - val_accuracy: 0.7711
# Epoch 141/500
# 48/48 [==============================] - 1s 11ms/step - loss: 0.7263 - accuracy: 0.7675 - val_loss: 0.7874 - val_accuracy: 0.7263
# Epoch 142/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.7205 - accuracy: 0.7655 - val_loss: 0.8288 - val_accuracy: 0.6658
# Epoch 143/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7246 - accuracy: 0.7701 - val_loss: 0.8344 - val_accuracy: 0.6921
# Epoch 144/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.7169 - accuracy: 0.7767 - val_loss: 0.7724 - val_accuracy: 0.7316
# Epoch 145/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7250 - accuracy: 0.7734 - val_loss: 0.7015 - val_accuracy: 0.7658
# Epoch 146/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7489 - accuracy: 0.7615 - val_loss: 0.6988 - val_accuracy: 0.7763
# Epoch 147/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.7284 - accuracy: 0.7806 - val_loss: 0.6866 - val_accuracy: 0.7921
# Epoch 148/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7250 - accuracy: 0.7839 - val_loss: 0.7445 - val_accuracy: 0.7684
# Epoch 149/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7164 - accuracy: 0.7813 - val_loss: 0.7876 - val_accuracy: 0.7632
# Epoch 150/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6944 - accuracy: 0.7892 - val_loss: 0.6937 - val_accuracy: 0.7921
# Epoch 151/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7181 - accuracy: 0.7813 - val_loss: 0.7280 - val_accuracy: 0.7632
# Epoch 152/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7018 - accuracy: 0.7839 - val_loss: 0.7814 - val_accuracy: 0.6921
# Epoch 153/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6611 - accuracy: 0.8090 - val_loss: 1.0831 - val_accuracy: 0.5684
# Epoch 154/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7041 - accuracy: 0.7767 - val_loss: 0.7576 - val_accuracy: 0.7500
# Epoch 155/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6661 - accuracy: 0.8004 - val_loss: 0.6950 - val_accuracy: 0.7868
# Epoch 156/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6789 - accuracy: 0.8050 - val_loss: 0.7403 - val_accuracy: 0.7263
# Epoch 157/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 0.7945 - val_loss: 0.7061 - val_accuracy: 0.7763
# Epoch 158/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6735 - accuracy: 0.7991 - val_loss: 0.6736 - val_accuracy: 0.7895
# Epoch 159/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6430 - accuracy: 0.8142 - val_loss: 0.6992 - val_accuracy: 0.7974
# Epoch 160/500
# 48/48 [==============================] - 1s 11ms/step - loss: 0.6720 - accuracy: 0.8017 - val_loss: 0.6808 - val_accuracy: 0.7947
# Epoch 161/500
# 48/48 [==============================] - 1s 12ms/step - loss: 0.6845 - accuracy: 0.7866 - val_loss: 0.8428 - val_accuracy: 0.7105
# Epoch 162/500
# 48/48 [==============================] - 1s 12ms/step - loss: 0.6886 - accuracy: 0.7991 - val_loss: 0.6809 - val_accuracy: 0.8026
# Epoch 163/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.7276 - accuracy: 0.7899 - val_loss: 0.7681 - val_accuracy: 0.7579
# Epoch 164/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.6701 - accuracy: 0.7991 - val_loss: 0.7498 - val_accuracy: 0.7526
# Epoch 165/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6539 - accuracy: 0.8149 - val_loss: 0.6712 - val_accuracy: 0.8026
# Epoch 166/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7154 - accuracy: 0.7872 - val_loss: 0.6923 - val_accuracy: 0.8132
# Epoch 167/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6777 - accuracy: 0.8057 - val_loss: 0.7556 - val_accuracy: 0.7447
# Epoch 168/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6592 - accuracy: 0.8215 - val_loss: 0.6396 - val_accuracy: 0.8237
# Epoch 169/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6666 - accuracy: 0.8109 - val_loss: 0.6515 - val_accuracy: 0.8289
# Epoch 170/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6571 - accuracy: 0.8123 - val_loss: 0.7213 - val_accuracy: 0.7842
# Epoch 171/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6415 - accuracy: 0.8248 - val_loss: 0.7155 - val_accuracy: 0.7632
# Epoch 172/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6269 - accuracy: 0.8320 - val_loss: 0.6991 - val_accuracy: 0.7921
# Epoch 173/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6460 - accuracy: 0.8123 - val_loss: 0.6922 - val_accuracy: 0.7921
# Epoch 174/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6414 - accuracy: 0.8215 - val_loss: 0.7069 - val_accuracy: 0.7684
# Epoch 175/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6632 - accuracy: 0.8129 - val_loss: 0.6521 - val_accuracy: 0.8289
# Epoch 176/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6404 - accuracy: 0.8274 - val_loss: 0.6209 - val_accuracy: 0.8237
# Epoch 177/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6292 - accuracy: 0.8379 - val_loss: 0.6584 - val_accuracy: 0.8132
# Epoch 178/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.6336 - accuracy: 0.8261 - val_loss: 0.7356 - val_accuracy: 0.7605
# Epoch 179/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6123 - accuracy: 0.8393 - val_loss: 0.7551 - val_accuracy: 0.7500
# Epoch 180/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.6238 - accuracy: 0.8254 - val_loss: 0.6169 - val_accuracy: 0.8316
# Epoch 181/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.6439 - accuracy: 0.8208 - val_loss: 0.8429 - val_accuracy: 0.7211
# Epoch 182/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6483 - accuracy: 0.8281 - val_loss: 0.6459 - val_accuracy: 0.8316
# Epoch 183/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6469 - accuracy: 0.8149 - val_loss: 0.7298 - val_accuracy: 0.7737
# Epoch 184/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6379 - accuracy: 0.8241 - val_loss: 0.6223 - val_accuracy: 0.8316
# Epoch 185/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6249 - accuracy: 0.8221 - val_loss: 0.6450 - val_accuracy: 0.8132
# Epoch 186/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6355 - accuracy: 0.8320 - val_loss: 0.6672 - val_accuracy: 0.8105
# Epoch 187/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.6110 - accuracy: 0.8524 - val_loss: 0.6291 - val_accuracy: 0.8237
# Epoch 188/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.6156 - accuracy: 0.8419 - val_loss: 0.6502 - val_accuracy: 0.8132
# Epoch 189/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5883 - accuracy: 0.8399 - val_loss: 0.6821 - val_accuracy: 0.8079
# Epoch 190/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5844 - accuracy: 0.8340 - val_loss: 0.6721 - val_accuracy: 0.8184
# Epoch 191/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6117 - accuracy: 0.8399 - val_loss: 0.6981 - val_accuracy: 0.8158
# Epoch 192/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.6172 - accuracy: 0.8399 - val_loss: 0.6813 - val_accuracy: 0.7947
# Epoch 193/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6038 - accuracy: 0.8505 - val_loss: 0.6561 - val_accuracy: 0.8211
# Epoch 194/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5968 - accuracy: 0.8426 - val_loss: 0.6849 - val_accuracy: 0.7947
# Epoch 195/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5906 - accuracy: 0.8406 - val_loss: 0.6968 - val_accuracy: 0.8132
# Epoch 196/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5560 - accuracy: 0.8636 - val_loss: 0.7137 - val_accuracy: 0.8079
# Epoch 197/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5921 - accuracy: 0.8366 - val_loss: 0.7382 - val_accuracy: 0.7553
# Epoch 198/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6115 - accuracy: 0.8333 - val_loss: 0.6148 - val_accuracy: 0.8526
# Epoch 199/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5679 - accuracy: 0.8570 - val_loss: 0.6141 - val_accuracy: 0.8500
# Epoch 200/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5845 - accuracy: 0.8511 - val_loss: 0.8191 - val_accuracy: 0.7605
# Epoch 201/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5983 - accuracy: 0.8412 - val_loss: 0.6197 - val_accuracy: 0.8342
# Epoch 202/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5878 - accuracy: 0.8564 - val_loss: 0.6397 - val_accuracy: 0.8263
# Epoch 203/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5863 - accuracy: 0.8505 - val_loss: 0.6446 - val_accuracy: 0.8500
# Epoch 204/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5620 - accuracy: 0.8603 - val_loss: 0.7013 - val_accuracy: 0.8000
# Epoch 205/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5781 - accuracy: 0.8650 - val_loss: 0.6490 - val_accuracy: 0.8263
# Epoch 206/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5829 - accuracy: 0.8524 - val_loss: 0.6193 - val_accuracy: 0.8342
# Epoch 207/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5900 - accuracy: 0.8570 - val_loss: 0.6092 - val_accuracy: 0.8395
# Epoch 208/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5819 - accuracy: 0.8584 - val_loss: 0.6769 - val_accuracy: 0.8211
# Epoch 209/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6206 - accuracy: 0.8472 - val_loss: 0.6894 - val_accuracy: 0.8000
# Epoch 210/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5866 - accuracy: 0.8544 - val_loss: 0.6596 - val_accuracy: 0.8105
# Epoch 211/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5936 - accuracy: 0.8412 - val_loss: 0.6389 - val_accuracy: 0.8447
# Epoch 212/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5710 - accuracy: 0.8557 - val_loss: 0.6457 - val_accuracy: 0.8237
# Epoch 213/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5944 - accuracy: 0.8564 - val_loss: 0.6269 - val_accuracy: 0.8237
# Epoch 214/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5708 - accuracy: 0.8643 - val_loss: 0.6234 - val_accuracy: 0.8342
# Epoch 215/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6051 - accuracy: 0.8472 - val_loss: 0.6753 - val_accuracy: 0.8026
# Epoch 216/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6045 - accuracy: 0.8353 - val_loss: 0.6377 - val_accuracy: 0.8342
# Epoch 217/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5759 - accuracy: 0.8557 - val_loss: 0.7369 - val_accuracy: 0.7737
# Epoch 218/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5515 - accuracy: 0.8603 - val_loss: 0.6258 - val_accuracy: 0.8421
# Epoch 219/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5751 - accuracy: 0.8623 - val_loss: 0.8493 - val_accuracy: 0.6789
# Epoch 220/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5623 - accuracy: 0.8623 - val_loss: 0.6933 - val_accuracy: 0.7947
# Epoch 221/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5745 - accuracy: 0.8617 - val_loss: 0.6950 - val_accuracy: 0.7816
# Epoch 222/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5718 - accuracy: 0.8577 - val_loss: 0.6350 - val_accuracy: 0.8395
# Epoch 223/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5632 - accuracy: 0.8722 - val_loss: 0.7483 - val_accuracy: 0.7684
# Epoch 224/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5961 - accuracy: 0.8538 - val_loss: 0.6222 - val_accuracy: 0.8368
# Epoch 225/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5527 - accuracy: 0.8610 - val_loss: 0.6513 - val_accuracy: 0.8553
# Epoch 226/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5686 - accuracy: 0.8610 - val_loss: 0.6329 - val_accuracy: 0.8237
# Epoch 227/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5971 - accuracy: 0.8445 - val_loss: 0.6083 - val_accuracy: 0.8500
# Epoch 228/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5862 - accuracy: 0.8557 - val_loss: 0.5882 - val_accuracy: 0.8553
# Epoch 229/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5624 - accuracy: 0.8610 - val_loss: 0.5932 - val_accuracy: 0.8605
# Epoch 230/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5536 - accuracy: 0.8650 - val_loss: 0.6223 - val_accuracy: 0.8316
# Epoch 231/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5693 - accuracy: 0.8570 - val_loss: 0.6011 - val_accuracy: 0.8553
# Epoch 232/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5468 - accuracy: 0.8669 - val_loss: 0.6053 - val_accuracy: 0.8368
# Epoch 233/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5486 - accuracy: 0.8682 - val_loss: 0.7079 - val_accuracy: 0.8105
# Epoch 234/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5643 - accuracy: 0.8557 - val_loss: 0.6767 - val_accuracy: 0.8263
# Epoch 235/500
# 48/48 [==============================] - 1s 15ms/step - loss: 0.5670 - accuracy: 0.8643 - val_loss: 0.6081 - val_accuracy: 0.8632
# Epoch 236/500
# 48/48 [==============================] - 1s 13ms/step - loss: 0.5651 - accuracy: 0.8584 - val_loss: 0.6902 - val_accuracy: 0.8237
# Epoch 237/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5329 - accuracy: 0.8696 - val_loss: 0.6011 - val_accuracy: 0.8474
# Epoch 238/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5582 - accuracy: 0.8696 - val_loss: 0.6520 - val_accuracy: 0.8316
# Epoch 239/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5873 - accuracy: 0.8570 - val_loss: 0.6648 - val_accuracy: 0.8158
# Epoch 240/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5389 - accuracy: 0.8801 - val_loss: 0.6138 - val_accuracy: 0.8395
# Epoch 241/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5510 - accuracy: 0.8702 - val_loss: 0.6091 - val_accuracy: 0.8447
# Epoch 242/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5635 - accuracy: 0.8636 - val_loss: 0.5919 - val_accuracy: 0.8579
# Epoch 243/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5517 - accuracy: 0.8656 - val_loss: 0.6512 - val_accuracy: 0.8211
# Epoch 244/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5786 - accuracy: 0.8577 - val_loss: 0.7305 - val_accuracy: 0.7816
# Epoch 245/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5607 - accuracy: 0.8788 - val_loss: 0.6798 - val_accuracy: 0.8053
# Epoch 246/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5741 - accuracy: 0.8590 - val_loss: 0.6586 - val_accuracy: 0.8132
# Epoch 247/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5584 - accuracy: 0.8623 - val_loss: 0.5760 - val_accuracy: 0.8658
# Epoch 248/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5746 - accuracy: 0.8676 - val_loss: 0.6106 - val_accuracy: 0.8368
# Epoch 249/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5692 - accuracy: 0.8617 - val_loss: 0.6091 - val_accuracy: 0.8342
# Epoch 250/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5667 - accuracy: 0.8682 - val_loss: 0.7039 - val_accuracy: 0.7895
# Epoch 251/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5422 - accuracy: 0.8775 - val_loss: 0.6241 - val_accuracy: 0.8263
# Epoch 252/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5871 - accuracy: 0.8603 - val_loss: 0.6351 - val_accuracy: 0.8316
# Epoch 253/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5538 - accuracy: 0.8663 - val_loss: 0.6827 - val_accuracy: 0.7947
# Epoch 254/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5458 - accuracy: 0.8762 - val_loss: 0.6813 - val_accuracy: 0.8079
# Epoch 255/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5644 - accuracy: 0.8682 - val_loss: 0.6087 - val_accuracy: 0.8500
# Epoch 256/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5316 - accuracy: 0.8841 - val_loss: 0.6735 - val_accuracy: 0.8237
# Epoch 257/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5147 - accuracy: 0.8926 - val_loss: 0.7802 - val_accuracy: 0.7789
# Epoch 258/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5611 - accuracy: 0.8722 - val_loss: 0.6226 - val_accuracy: 0.8421
# Epoch 259/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5373 - accuracy: 0.8827 - val_loss: 0.6013 - val_accuracy: 0.8553
# Epoch 260/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5409 - accuracy: 0.8650 - val_loss: 0.5995 - val_accuracy: 0.8421
# Epoch 261/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5531 - accuracy: 0.8689 - val_loss: 0.6415 - val_accuracy: 0.8395
# Epoch 262/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5722 - accuracy: 0.8676 - val_loss: 0.7093 - val_accuracy: 0.7947
# Epoch 263/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5236 - accuracy: 0.8847 - val_loss: 0.5968 - val_accuracy: 0.8500
# Epoch 264/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5518 - accuracy: 0.8748 - val_loss: 0.5795 - val_accuracy: 0.8526
# Epoch 265/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5368 - accuracy: 0.8775 - val_loss: 0.6326 - val_accuracy: 0.8342
# Epoch 266/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5512 - accuracy: 0.8636 - val_loss: 0.5790 - val_accuracy: 0.8421
# Epoch 267/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5201 - accuracy: 0.8854 - val_loss: 0.5973 - val_accuracy: 0.8553
# Epoch 268/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5298 - accuracy: 0.8762 - val_loss: 0.6586 - val_accuracy: 0.8263
# Epoch 269/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5607 - accuracy: 0.8702 - val_loss: 0.6222 - val_accuracy: 0.8316
# Epoch 270/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5827 - accuracy: 0.8577 - val_loss: 0.6175 - val_accuracy: 0.8342
# Epoch 271/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5281 - accuracy: 0.8847 - val_loss: 0.6163 - val_accuracy: 0.8395
# Epoch 272/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5416 - accuracy: 0.8788 - val_loss: 0.6097 - val_accuracy: 0.8342
# Epoch 273/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5319 - accuracy: 0.8841 - val_loss: 0.6253 - val_accuracy: 0.8263
# Epoch 274/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5392 - accuracy: 0.8775 - val_loss: 0.5970 - val_accuracy: 0.8605
# Epoch 275/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5287 - accuracy: 0.8841 - val_loss: 0.6921 - val_accuracy: 0.7921
# Epoch 276/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5408 - accuracy: 0.8794 - val_loss: 0.5976 - val_accuracy: 0.8421
# Epoch 277/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5242 - accuracy: 0.8814 - val_loss: 0.7529 - val_accuracy: 0.7816
# Epoch 278/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5402 - accuracy: 0.8854 - val_loss: 0.5861 - val_accuracy: 0.8605
# Epoch 279/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5412 - accuracy: 0.8841 - val_loss: 0.5602 - val_accuracy: 0.8553
# Epoch 280/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4991 - accuracy: 0.8900 - val_loss: 0.5484 - val_accuracy: 0.8579
# Epoch 281/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5598 - accuracy: 0.8689 - val_loss: 0.6303 - val_accuracy: 0.8263
# Epoch 282/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5623 - accuracy: 0.8696 - val_loss: 0.5908 - val_accuracy: 0.8526
# Epoch 283/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5375 - accuracy: 0.8775 - val_loss: 0.6422 - val_accuracy: 0.8316
# Epoch 284/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5347 - accuracy: 0.8762 - val_loss: 0.8104 - val_accuracy: 0.7342
# Epoch 285/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5435 - accuracy: 0.8781 - val_loss: 0.6011 - val_accuracy: 0.8447
# Epoch 286/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5123 - accuracy: 0.8794 - val_loss: 0.6133 - val_accuracy: 0.8395
# Epoch 287/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5397 - accuracy: 0.8755 - val_loss: 0.6034 - val_accuracy: 0.8579
# Epoch 288/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5178 - accuracy: 0.8762 - val_loss: 0.6044 - val_accuracy: 0.8474
# Epoch 289/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5667 - accuracy: 0.8682 - val_loss: 0.6065 - val_accuracy: 0.8395
# Epoch 290/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5402 - accuracy: 0.8801 - val_loss: 0.6262 - val_accuracy: 0.8289
# Epoch 291/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5423 - accuracy: 0.8874 - val_loss: 0.6063 - val_accuracy: 0.8421
# Epoch 292/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5235 - accuracy: 0.8808 - val_loss: 0.6039 - val_accuracy: 0.8316
# Epoch 293/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4893 - accuracy: 0.8933 - val_loss: 0.6165 - val_accuracy: 0.8421
# Epoch 294/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5269 - accuracy: 0.8669 - val_loss: 0.6099 - val_accuracy: 0.8395
# Epoch 295/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5196 - accuracy: 0.8900 - val_loss: 0.6305 - val_accuracy: 0.8316
# Epoch 296/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5027 - accuracy: 0.8887 - val_loss: 0.6028 - val_accuracy: 0.8474
# Epoch 297/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5127 - accuracy: 0.8874 - val_loss: 0.5971 - val_accuracy: 0.8711
# Epoch 298/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4957 - accuracy: 0.8939 - val_loss: 0.5789 - val_accuracy: 0.8447
# Epoch 299/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5420 - accuracy: 0.8933 - val_loss: 0.6042 - val_accuracy: 0.8263
# Epoch 300/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5114 - accuracy: 0.8887 - val_loss: 0.5649 - val_accuracy: 0.8684
# Epoch 301/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5623 - accuracy: 0.8623 - val_loss: 0.5852 - val_accuracy: 0.8553
# Epoch 302/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5348 - accuracy: 0.8689 - val_loss: 0.6108 - val_accuracy: 0.8553
# Epoch 303/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5404 - accuracy: 0.8762 - val_loss: 0.5801 - val_accuracy: 0.8605
# Epoch 304/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5301 - accuracy: 0.8887 - val_loss: 0.5910 - val_accuracy: 0.8447
# Epoch 305/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5154 - accuracy: 0.8841 - val_loss: 0.6180 - val_accuracy: 0.8316
# Epoch 306/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5462 - accuracy: 0.8768 - val_loss: 0.7944 - val_accuracy: 0.7763
# Epoch 307/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5388 - accuracy: 0.8860 - val_loss: 0.5993 - val_accuracy: 0.8526
# Epoch 308/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5089 - accuracy: 0.8893 - val_loss: 0.5977 - val_accuracy: 0.8500
# Epoch 309/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5273 - accuracy: 0.8933 - val_loss: 0.6287 - val_accuracy: 0.8316
# Epoch 310/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5283 - accuracy: 0.8887 - val_loss: 0.6389 - val_accuracy: 0.8184
# Epoch 311/500
# 48/48 [==============================] - 1s 13ms/step - loss: 0.5023 - accuracy: 0.9051 - val_loss: 0.6342 - val_accuracy: 0.8184
# Epoch 312/500
# 48/48 [==============================] - 1s 12ms/step - loss: 0.5261 - accuracy: 0.8880 - val_loss: 0.6142 - val_accuracy: 0.8316
# Epoch 313/500
# 48/48 [==============================] - 1s 11ms/step - loss: 0.5500 - accuracy: 0.8808 - val_loss: 0.6196 - val_accuracy: 0.8316
# Epoch 314/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5394 - accuracy: 0.8808 - val_loss: 0.5925 - val_accuracy: 0.8500
# Epoch 315/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5184 - accuracy: 0.8893 - val_loss: 0.6426 - val_accuracy: 0.8368
# Epoch 316/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5096 - accuracy: 0.8887 - val_loss: 0.5811 - val_accuracy: 0.8632
# Epoch 317/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4955 - accuracy: 0.8906 - val_loss: 0.6723 - val_accuracy: 0.7974
# Epoch 318/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5195 - accuracy: 0.8880 - val_loss: 0.6165 - val_accuracy: 0.8474
# Epoch 319/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4964 - accuracy: 0.8939 - val_loss: 0.5693 - val_accuracy: 0.8526
# Epoch 320/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5011 - accuracy: 0.8860 - val_loss: 0.5869 - val_accuracy: 0.8395
# Epoch 321/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5153 - accuracy: 0.8926 - val_loss: 0.5458 - val_accuracy: 0.8789
# Epoch 322/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4872 - accuracy: 0.8939 - val_loss: 0.5827 - val_accuracy: 0.8526
# Epoch 323/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5093 - accuracy: 0.8972 - val_loss: 0.6131 - val_accuracy: 0.8395
# Epoch 324/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4884 - accuracy: 0.8999 - val_loss: 0.5621 - val_accuracy: 0.8526
# Epoch 325/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5523 - accuracy: 0.8742 - val_loss: 0.5991 - val_accuracy: 0.8579
# Epoch 326/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5450 - accuracy: 0.8656 - val_loss: 0.6342 - val_accuracy: 0.8263
# Epoch 327/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5081 - accuracy: 0.9005 - val_loss: 0.6330 - val_accuracy: 0.8263
# Epoch 328/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5033 - accuracy: 0.8946 - val_loss: 0.6075 - val_accuracy: 0.8237
# Epoch 329/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5115 - accuracy: 0.8893 - val_loss: 0.5958 - val_accuracy: 0.8474
# Epoch 330/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4989 - accuracy: 0.8913 - val_loss: 0.6062 - val_accuracy: 0.8316
# Epoch 331/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5164 - accuracy: 0.8880 - val_loss: 0.6123 - val_accuracy: 0.8316
# Epoch 332/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4885 - accuracy: 0.8913 - val_loss: 0.8143 - val_accuracy: 0.7605
# Epoch 333/500
# ...
# Epoch 404/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5015 - accuracy: 0.8947 - val_loss: 0.5806 - val_accuracy: 0.8447
# Epoch 405/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5090 - accuracy: 0.8960 - val_loss: 0.6212 - val_accuracy: 0.8289
# Epoch 406/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5236 - accuracy: 0.8861 - val_loss: 0.6365 - val_accuracy: 0.8289
# Epoch 407/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5455 - accuracy: 0.8822 - val_loss: 0.5918 - val_accuracy: 0.8447
# Epoch 408/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5341 - accuracy: 0.8822 - val_loss: 0.5780 - val_accuracy: 0.8500
# Epoch 409/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5156 - accuracy: 0.8920 - val_loss: 0.5882 - val_accuracy: 0.8447
# Epoch 410/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5094 - accuracy: 0.8808 - val_loss: 0.5750 - val_accuracy: 0.8474
# Epoch 411/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5157 - accuracy: 0.8927 - val_loss: 0.5609 - val_accuracy: 0.8632
# Epoch 412/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5013 - accuracy: 0.8927 - val_loss: 0.5903 - val_accuracy: 0.8526
# Epoch 413/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5282 - accuracy: 0.8789 - val_loss: 0.5704 - val_accuracy: 0.8579
# Epoch 414/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4835 - accuracy: 0.9006 - val_loss: 0.5840 - val_accuracy: 0.8526
# Epoch 415/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5284 - accuracy: 0.8802 - val_loss: 0.5814 - val_accuracy: 0.8447
# Epoch 416/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5368 - accuracy: 0.8716 - val_loss: 0.5956 - val_accuracy: 0.8500
# Epoch 417/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5037 - accuracy: 0.8940 - val_loss: 0.5591 - val_accuracy: 0.8632
# Epoch 418/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5023 - accuracy: 0.8980 - val_loss: 0.5615 - val_accuracy: 0.8474
# Epoch 419/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5158 - accuracy: 0.8907 - val_loss: 0.5713 - val_accuracy: 0.8474
# Epoch 420/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5106 - accuracy: 0.8855 - val_loss: 0.5656 - val_accuracy: 0.8500
# Epoch 421/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5070 - accuracy: 0.8894 - val_loss: 0.5706 - val_accuracy: 0.8632
# Epoch 422/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4940 - accuracy: 0.9019 - val_loss: 0.6415 - val_accuracy: 0.8105
# Epoch 423/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5295 - accuracy: 0.8887 - val_loss: 0.5628 - val_accuracy: 0.8553
# Epoch 424/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5040 - accuracy: 0.8841 - val_loss: 0.5807 - val_accuracy: 0.8316
# Epoch 425/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5013 - accuracy: 0.8881 - val_loss: 0.6184 - val_accuracy: 0.8132
# Epoch 426/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5148 - accuracy: 0.8769 - val_loss: 0.6602 - val_accuracy: 0.8184
# Epoch 427/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5136 - accuracy: 0.8947 - val_loss: 0.5828 - val_accuracy: 0.8368
# Epoch 428/500
# 48/48 [==============================] - 1s 12ms/step - loss: 0.4869 - accuracy: 0.9026 - val_loss: 0.5899 - val_accuracy: 0.8500
# Epoch 429/500
# 48/48 [==============================] - 1s 12ms/step - loss: 0.5280 - accuracy: 0.8808 - val_loss: 0.6123 - val_accuracy: 0.8395
# Epoch 430/500
# 48/48 [==============================] - 1s 12ms/step - loss: 0.5327 - accuracy: 0.8848 - val_loss: 0.6020 - val_accuracy: 0.8526
# Epoch 431/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5261 - accuracy: 0.8802 - val_loss: 0.6418 - val_accuracy: 0.8132
# Epoch 432/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5070 - accuracy: 0.8907 - val_loss: 0.5906 - val_accuracy: 0.8447
# Epoch 433/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5117 - accuracy: 0.8881 - val_loss: 0.5863 - val_accuracy: 0.8395
# Epoch 434/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4991 - accuracy: 0.8861 - val_loss: 0.5851 - val_accuracy: 0.8553
# Epoch 435/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4933 - accuracy: 0.8973 - val_loss: 0.6044 - val_accuracy: 0.8368
# Epoch 436/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5300 - accuracy: 0.8749 - val_loss: 0.5873 - val_accuracy: 0.8368
# Epoch 437/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5226 - accuracy: 0.8815 - val_loss: 0.5877 - val_accuracy: 0.8500
# Epoch 438/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5088 - accuracy: 0.8874 - val_loss: 0.6075 - val_accuracy: 0.8316
# Epoch 439/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5306 - accuracy: 0.8828 - val_loss: 0.5734 - val_accuracy: 0.8605
# Epoch 440/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4783 - accuracy: 0.9019 - val_loss: 0.6228 - val_accuracy: 0.8211
# Epoch 441/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4710 - accuracy: 0.9013 - val_loss: 0.5808 - val_accuracy: 0.8447
# Epoch 442/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5241 - accuracy: 0.8881 - val_loss: 0.5912 - val_accuracy: 0.8447
# Epoch 443/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5131 - accuracy: 0.8874 - val_loss: 0.5858 - val_accuracy: 0.8500
# Epoch 444/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4865 - accuracy: 0.9078 - val_loss: 0.6428 - val_accuracy: 0.8132
# Epoch 445/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4944 - accuracy: 0.8828 - val_loss: 0.5735 - val_accuracy: 0.8632
# Epoch 446/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5215 - accuracy: 0.8749 - val_loss: 0.5799 - val_accuracy: 0.8579
# Epoch 447/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4994 - accuracy: 0.8874 - val_loss: 0.5941 - val_accuracy: 0.8447
# Epoch 448/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5036 - accuracy: 0.9006 - val_loss: 0.6595 - val_accuracy: 0.8184
# Epoch 449/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5400 - accuracy: 0.8697 - val_loss: 0.6148 - val_accuracy: 0.8395
# Epoch 450/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5062 - accuracy: 0.8848 - val_loss: 0.5905 - val_accuracy: 0.8421
# Epoch 451/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4800 - accuracy: 0.9105 - val_loss: 0.6196 - val_accuracy: 0.8263
# Epoch 452/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5294 - accuracy: 0.8808 - val_loss: 0.5903 - val_accuracy: 0.8526
# Epoch 453/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5428 - accuracy: 0.8789 - val_loss: 0.6211 - val_accuracy: 0.8184
# Epoch 454/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4857 - accuracy: 0.9059 - val_loss: 0.5918 - val_accuracy: 0.8368
# Epoch 455/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4893 - accuracy: 0.8999 - val_loss: 0.5910 - val_accuracy: 0.8368
# Epoch 456/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5141 - accuracy: 0.8953 - val_loss: 0.5980 - val_accuracy: 0.8421
# Epoch 457/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4894 - accuracy: 0.9052 - val_loss: 0.5866 - val_accuracy: 0.8289
# Epoch 458/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5069 - accuracy: 0.8953 - val_loss: 0.6235 - val_accuracy: 0.8105
# Epoch 459/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5143 - accuracy: 0.8894 - val_loss: 0.6031 - val_accuracy: 0.8184
# Epoch 460/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5095 - accuracy: 0.8927 - val_loss: 0.5795 - val_accuracy: 0.8421
# Epoch 461/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4965 - accuracy: 0.9092 - val_loss: 0.7047 - val_accuracy: 0.8053
# Epoch 462/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5152 - accuracy: 0.8815 - val_loss: 0.6377 - val_accuracy: 0.8184
# Epoch 463/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5394 - accuracy: 0.8874 - val_loss: 0.6525 - val_accuracy: 0.8000
# Epoch 464/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5234 - accuracy: 0.8874 - val_loss: 0.6234 - val_accuracy: 0.8289
# Epoch 465/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5086 - accuracy: 0.8907 - val_loss: 0.6159 - val_accuracy: 0.8395
# Epoch 466/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4870 - accuracy: 0.8960 - val_loss: 0.5968 - val_accuracy: 0.8395
# Epoch 467/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5309 - accuracy: 0.8874 - val_loss: 0.5813 - val_accuracy: 0.8395
# Epoch 468/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5068 - accuracy: 0.8940 - val_loss: 0.5658 - val_accuracy: 0.8447
# Epoch 469/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4984 - accuracy: 0.8960 - val_loss: 0.5695 - val_accuracy: 0.8605
# Epoch 470/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5206 - accuracy: 0.8934 - val_loss: 0.5962 - val_accuracy: 0.8421
# Epoch 471/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5216 - accuracy: 0.8789 - val_loss: 0.6310 - val_accuracy: 0.8395
# Epoch 472/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5066 - accuracy: 0.8986 - val_loss: 0.6061 - val_accuracy: 0.8395
# Epoch 473/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4841 - accuracy: 0.9111 - val_loss: 0.5891 - val_accuracy: 0.8395
# Epoch 474/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5110 - accuracy: 0.8887 - val_loss: 0.5813 - val_accuracy: 0.8447
# Epoch 475/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5270 - accuracy: 0.8769 - val_loss: 0.5911 - val_accuracy: 0.8368
# Epoch 476/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5299 - accuracy: 0.8855 - val_loss: 0.6142 - val_accuracy: 0.8421
# Epoch 477/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4968 - accuracy: 0.8927 - val_loss: 0.6263 - val_accuracy: 0.8316
# Epoch 478/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4834 - accuracy: 0.8973 - val_loss: 0.6168 - val_accuracy: 0.8421
# Epoch 479/500
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5311 - accuracy: 0.8776 - val_loss: 0.6065 - val_accuracy: 0.8263
# Epoch 480/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4802 - accuracy: 0.8999 - val_loss: 0.7427 - val_accuracy: 0.7921
# Epoch 481/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4904 - accuracy: 0.8986 - val_loss: 0.5976 - val_accuracy: 0.8316
# Epoch 482/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5345 - accuracy: 0.8815 - val_loss: 0.5425 - val_accuracy: 0.8711
# Epoch 483/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4831 - accuracy: 0.8927 - val_loss: 0.5491 - val_accuracy: 0.8421
# Epoch 484/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5114 - accuracy: 0.8881 - val_loss: 0.5504 - val_accuracy: 0.8526
# Epoch 485/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5130 - accuracy: 0.8835 - val_loss: 0.5962 - val_accuracy: 0.8395
# Epoch 486/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5243 - accuracy: 0.8927 - val_loss: 0.5745 - val_accuracy: 0.8447
# Epoch 487/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4973 - accuracy: 0.8901 - val_loss: 0.5763 - val_accuracy: 0.8632
# Epoch 488/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5064 - accuracy: 0.8887 - val_loss: 0.5619 - val_accuracy: 0.8605
# Epoch 489/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5001 - accuracy: 0.8947 - val_loss: 0.5451 - val_accuracy: 0.8632
# Epoch 490/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4749 - accuracy: 0.8973 - val_loss: 0.6199 - val_accuracy: 0.8500
# Epoch 491/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5036 - accuracy: 0.8986 - val_loss: 0.5761 - val_accuracy: 0.8500
# Epoch 492/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5085 - accuracy: 0.8920 - val_loss: 0.5661 - val_accuracy: 0.8421
# Epoch 493/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5247 - accuracy: 0.8874 - val_loss: 0.5857 - val_accuracy: 0.8368
# Epoch 494/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5304 - accuracy: 0.8835 - val_loss: 0.6290 - val_accuracy: 0.8421
# Epoch 495/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4943 - accuracy: 0.8986 - val_loss: 0.5591 - val_accuracy: 0.8526
# Epoch 496/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5019 - accuracy: 0.8966 - val_loss: 0.5716 - val_accuracy: 0.8421
# Epoch 497/500
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4772 - accuracy: 0.8914 - val_loss: 0.5744 - val_accuracy: 0.8447
# Epoch 498/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4851 - accuracy: 0.8953 - val_loss: 0.5905 - val_accuracy: 0.8447
# Epoch 499/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4867 - accuracy: 0.8986 - val_loss: 0.6094 - val_accuracy: 0.8421
# Epoch 500/500
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5146 - accuracy: 0.8914 - val_loss: 0.5921 - val_accuracy: 0.8553
# 15/15 [==============================] - 0s 2ms/step
# Precision: 0.8253
# Recall: 0.8156
# F1 Score: 0.8184
# Fold 5, Accuracy: 0.8228, Test Loss: 0.6459, Test Accuracy: 0.8228
# ========================================
# test losses: [0.6156262755393982, 0.5890207290649414, 0.5996803045272827, 0.7314331531524658, 0.6458779573440552]
# test accuracy: [0.8442105054855347, 0.8526315689086914, 0.8336842060089111, 0.8059071898460388, 0.8227847814559937]
# ****************************************
# Mean training loss over 5-fold cross-validation: 0.7038
# Mean training accuracy over 5-fold cross-validation: 0.7723
# Mean validation loss over 5-fold cross-validation: 0.7454
# Mean validation accuracy over 5-fold cross-validation: 0.7535
# ****************************************
# Mean accuracy over stratified 5-fold cross-validation: 0.8318
# Mean test loss over stratified 5-fold cross-validation: 0.6363
# Mean test accuracy over stratified 5-fold cross-validation: 0.8318
# ****************************************
# Standard deviation of training loss over 5-fold cross-validation: 0.2676
# Standard deviation of training accuracy over 5-fold cross-validation: 0.1637
# Standard deviation of validation loss over 5-fold cross-validation: 0.2168
# Standard deviation of validation accuracy over 5-fold cross-validation: 0.1418
# ****************************************
# Standard deviation of accuracy over stratified 5-fold cross-validation: 0.0164
# Standard deviation of test loss over stratified 5-fold cross-validation: 0.0513
# Standard deviation of test accuracy over stratified 5-fold cross-validation: 0.0164
# ****************************************
# Mean precision over stratified 5-fold cross-validation: 0.8328
# Standard deviation of precision over stratified 5-fold cross-validation: 0.0138
# Mean recall over stratified 5-fold cross-validation: 0.8286
# Standard deviation of recall over stratified 5-fold cross-validation: 0.0189
# Mean F1 score over stratified 5-fold cross-validation: 0.8292
# Standard deviation of F1 score over stratified 5-fold cross-validation: 0.0173
# Training time: 1218.08 seconds

# %%
def cnn_model_3(input_shape, num_classes):
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.5))
    
    model.add(Flatten())
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
import pickle

def perform_cnn_cv(X, y, learning_rate, dropout_rate, l2_regularizer, 
                             n_splits=5, epochs=100, batch_size=32, cnn_version = 1, val_set = 0.2,
                             do_opt = False,models_folder = "models", results_folder = "results"):
    
    if not os.path.exists(models_folder):
        os.makedirs(models_folder)

    if not os.path.exists(results_folder):
        os.makedirs(results_folder)
    accuracies = []
    test_losses = []
    test_accuracies = []
    
    # Initialize lists to store precision, recall, and F1 scores
    precisions = []
    recalls = []
    f1_scores = []
    
    # Initialize lists to store losses and accuracies for each epoch
    mean_training_losses = []
    mean_training_accuracies = []
    mean_val_losses = []   
    mean_val_accuracies = []
    
    # Initialize lists to store losses and accuracies for each epoch
    all_training_losses = []
    all_training_accuracies = []
    all_val_losses = []   
    all_val_accuracies = []
    
    fold = 1
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)
    
    for train_index, test_index in skf.split(X, y):
        # Split the data into training and validation sets
        print("=" * 40)
        print(f"Fold: {fold}")
        print("Splitting the data")
        X_train_full, X_test = X[train_index], X[test_index]
        y_train_full, y_test = y[train_index], y[test_index]
        
        # Standardize the data
        print("Standardizing the data")
        X_train_full, X_test = standardize_data(X_train_full, X_test)
        
        # Reshape the data
        print("Reshaping the data for deep learning models")
        X_train_full, X_test = reshape_data(X_train_full, X_test)
        
        # Input shape and number of classes for the model
        input_shape = (X_train_full.shape[1], 1)
        num_classes = len(np.unique(y))
        
        X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size = 0.2, random_state = seed_value, stratify = y_train_full)
        
        try:
            if do_opt:
                model = cnn_model_3(input_shape, num_classes)
#                 model = cnn_model_3_opt(input_shape, num_classes, learning_rate, dropout_rate, l2_regularizer)
            else:
                model = cnn_model_3(input_shape, num_classes)
            if model is not None:
                print("Building the model 3 with the following hyperparameters:")
                print(f"Learning rate: {learning_rate}")
                print(f"Dropout rate: {dropout_rate}") 
                print(f"L2 Regularizer: {l2_regularizer}")
                print(f"Number of epochs: {epochs}")
                print(f"Batch size: {batch_size}")
                # model.summary()
            else:
                print("Failed to build the CNN model.")
        except Exception as e:
            print(f"Error while building the CNN model: {e}")
        
        print("Saving the data")
        fold_data = {

            'X_train': X_train,
            'X_val': X_val,
            'X_test': X_test,
            'y_train': y_train,
            'y_val': y_val,
            'y_test': y_test
        }

        with open(f"/kaggle/working/CV_CNN_fold_data/fold_{fold}_data.pkl", 'wb') as f:
            pickle.dump(fold_data, f)
        
        
        print("Training the model")
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))
        y_pred = np.argmax(model.predict(X_test), axis=-1)
        accuracy = accuracy_score(y_test, y_pred)
        test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
        
            # Calculate precision, recall, and F1 score
        precision = precision_score(y_test, y_pred, average='macro')
        recall = recall_score(y_test, y_pred, average='macro')
        f1 = f1_score(y_test, y_pred, average='macro')

        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")

        # Append the scores to the lists
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        
        all_training_losses.extend(history.history['loss'])
        all_training_accuracies.extend(history.history['accuracy'])
        all_val_losses.extend(history.history['val_loss'])
        all_val_accuracies.extend(history.history['val_accuracy'])
        
        # Append the losses and accuracies for each epoch to the respective lists
        for epoch in range(epochs):
            if fold == 1:
                # For the first fold, initialize the lists with the first fold's values
                mean_training_losses.append(history.history['loss'][epoch])
                mean_training_accuracies.append(history.history['accuracy'][epoch])
                mean_val_losses.append(history.history['val_loss'][epoch])
                mean_val_accuracies.append(history.history['val_accuracy'][epoch])
            else:
                # For subsequent folds, add the fold's values to the running sum
                mean_training_losses[epoch] += history.history['loss'][epoch]
                mean_training_accuracies[epoch] += history.history['accuracy'][epoch]
                mean_val_losses[epoch] += history.history['val_loss'][epoch]
                mean_val_accuracies[epoch] += history.history['val_accuracy'][epoch]

        # Save the model
        if do_opt:
            model_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.h5"
        else:
            model_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.h5"
        model_filepath = os.path.join(models_folder, f"fold_{fold}_split_{n_splits}_{model_filename}")
        model.save(model_filepath)

        # Save the results as a JSON file
        if do_opt:
            results_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            results_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filepath = os.path.join(results_folder, f"fold_{fold}_split_{n_splits}_{results_filename}")

        results = {
            "fold": fold,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1_scores": f1_scores,
            "test_loss": test_loss,
            "test_accuracy": test_accuracy,
            "training_loss": history.history['loss'],
            "training_accuracy": history.history['accuracy'],
            "validation_loss": history.history['val_loss'],
            "validation_accuracy": history.history['val_accuracy'],
        }

        with open(results_filepath, "w") as results_file:
            json.dump(results, results_file, indent=4)
        
        # Append the results to the lists
        accuracies.append(accuracy)
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        
        print(f"Fold {fold}, Accuracy: {accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
        print("=" * 40)
        fold += 1

    # At the end, divide the sums by the number of folds to get the mean
    mean_training_losses = [loss / n_splits for loss in mean_training_losses]
    mean_training_accuracies = [acc / n_splits for acc in mean_training_accuracies]
    mean_val_losses = [loss / n_splits for loss in mean_val_losses]
    mean_val_accuracies = [acc / n_splits for acc in mean_val_accuracies]
    # Convert lists to numpy arrays for easier calculation of mean and standard deviation
    mean_accuracy = np.mean(accuracies)
    mean_test_loss = np.mean(test_losses)
    mean_test_accuracy = np.mean(test_accuracies)
    
    mean_training_loss = np.mean(all_training_losses)
    std_training_loss = np.std(all_training_losses)
    mean_training_accuracy = np.mean(all_training_accuracies)
    std_training_accuracy = np.std(all_training_accuracies)

    mean_val_loss = np.mean(all_val_losses)
    std_val_loss = np.std(all_val_losses)
    mean_val_accuracy = np.mean(all_val_accuracies)
    std_val_accuracy = np.std(all_val_accuracies)

    # Calculate standard deviations
    std_accuracy = np.std(accuracies)
    std_test_loss = np.std(test_losses)
    std_test_accuracy = np.std(test_accuracies)

    std_training_loss = np.std(mean_training_losses)
    std_training_accuracy = np.std(mean_training_accuracies)
    std_val_loss = np.std(mean_val_losses)
    std_val_accuracy = np.std(mean_val_accuracies)

    precisions = np.array(precisions)
    recalls = np.array(recalls)
    f1_scores = np.array(f1_scores)

      
    print(f"test losses: {test_losses}")
    print(f"test accuracy: {test_accuracies}")
    
    print("*" * 40)
    print(f"Mean training loss over {n_splits}-fold cross-validation: {mean_training_loss:.4f}")
    print(f"Mean training accuracy over {n_splits}-fold cross-validation: {mean_training_accuracy:.4f}")
    print(f"Mean validation loss over {n_splits}-fold cross-validation: {mean_val_loss:.4f}")
    print(f"Mean validation accuracy over {n_splits}-fold cross-validation: {mean_val_accuracy:.4f}")
    print("*" * 40)
    print(f"Mean accuracy over stratified {n_splits}-fold cross-validation: {mean_accuracy:.4f}")
    print(f"Mean test loss over stratified {n_splits}-fold cross-validation: {mean_test_loss:.4f}")
    print(f"Mean test accuracy over stratified {n_splits}-fold cross-validation: {mean_test_accuracy:.4f}")
    
    print("*" * 40)
    print(f"Standard deviation of training loss over {n_splits}-fold cross-validation: {std_training_loss:.4f}")
    print(f"Standard deviation of training accuracy over {n_splits}-fold cross-validation: {std_training_accuracy:.4f}")
    print(f"Standard deviation of validation loss over {n_splits}-fold cross-validation: {std_val_loss:.4f}")
    print(f"Standard deviation of validation accuracy over {n_splits}-fold cross-validation: {std_val_accuracy:.4f}")
        
    print("*" * 40)
    print(f"Standard deviation of accuracy over stratified {n_splits}-fold cross-validation: {std_accuracy:.4f}")
    print(f"Standard deviation of test loss over stratified {n_splits}-fold cross-validation: {std_test_loss:.4f}")
    print(f"Standard deviation of test accuracy over stratified {n_splits}-fold cross-validation: {std_test_accuracy:.4f}")
    print("*" * 40)
    
    # Calculate and print the mean and standard deviation of precision, recall, and F1 score
    print(f"Mean precision over stratified {n_splits}-fold cross-validation: {np.mean(precisions):.4f}")
    print(f"Standard deviation of precision over stratified {n_splits}-fold cross-validation: {np.std(precisions):.4f}")
    print(f"Mean recall over stratified {n_splits}-fold cross-validation: {np.mean(recalls):.4f}")
    print(f"Standard deviation of recall over stratified {n_splits}-fold cross-validation: {np.std(recalls):.4f}")
    print(f"Mean F1 score over stratified {n_splits}-fold cross-validation: {np.mean(f1_scores):.4f}")
    print(f"Standard deviation of F1 score over stratified {n_splits}-fold cross-validation: {np.std(f1_scores):.4f}")

    
# Define the directory where the JSON files are stored

    fig, axes = plt.subplots(2, n_splits, figsize=(20, 10))

    for fold in range(1, n_splits+1):
        # Load the JSON file for this fold
        if do_opt:
            cnn_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            cnn_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filename = f"fold_{fold}_split_{n_splits}_{cnn_filename}"
        
        results_filepath = os.path.join(results_folder, results_filename)
        
        with open(results_filepath, "r") as results_file:
            results = json.load(results_file)
        
        # Plot training and validation loss
        axes[0, fold-1].plot(results["training_loss"], label='Train')
        axes[0, fold-1].plot(results["validation_loss"], label='Validation')
        axes[0, fold-1].set_title(f'Fold {fold} Loss')
        axes[0, fold-1].set_xlabel('Epochs')
        axes[0, fold-1].set_ylabel('Loss')
        axes[0, fold-1].legend()

        # Plot training and validation accuracy
        axes[1, fold-1].plot(results["training_accuracy"], label='Train')
        axes[1, fold-1].plot(results["validation_accuracy"], label='Validation')
        axes[1, fold-1].set_title(f'Fold {fold} Accuracy')
        axes[1, fold-1].set_xlabel('Epochs')
        axes[1, fold-1].set_ylabel('Accuracy')
        axes[1, fold-1].legend()

    plt.tight_layout()
    plt.show()

    return mean_val_accuracies

# %%
# Given the paths you provided, let's generate confusion matrices for the VIT models:
cnn_model_path = "/kaggle/working/CV_CNN_models/"
data_model_path = "/kaggle/working/CV_CNN_fold_data/"
cm_model_path = "/kaggle/working/CV_CNN_cm/"

# Lists to store metrics
accuracies = []
precisions = []
recalls = []
f1_scores = []
confusion_matrices_cnn = []

# Loop through each fold
for fold in range(1, 6):
    # Load datasets for this fold
    with open(f"{data_model_path}fold_{fold}_data.pkl", 'rb') as f:
        fold_data = pickle.load(f)
        
    X_test = fold_data['X_test']
    y_test = fold_data['y_test']
    
    # Load the model for this fold
    model_file = f"fold_{fold}_split_5_cnn_v3_opt_32_300_seed7.h5"
    model_path = os.path.join(cnn_model_path, model_file)
    model = tf.keras.models.load_model(model_path)
    
    # Predict and evaluate
    y_pred = np.argmax(model.predict(X_test), axis=-1)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='macro')
    recall = recall_score(y_test, y_pred, average='macro')
    f1 = f1_score(y_test, y_pred, average='macro')
    cm = confusion_matrix(y_test, y_pred)
    
    # Save the confusion matrix
    with open(f"{cm_model_path}cnn_cm_fold_{fold}.pkl", 'wb') as cm_file:
        pickle.dump(cm, cm_file)
    
    # Store metrics
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)
    confusion_matrices_cnn.append(cm)
    
    # Print metrics for this fold
    print(f"Fold {fold}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print("-" * 40)

# This will give you a list of confusion matrices for each fold of the VIT models
confusion_matrices_cnn
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 25
#      23 model_file = f"fold_{fold}_split_5_cnn_v3_opt_32_300_seed7.h5"
#      24 model_path = os.path.join(cnn_model_path, model_file)
# ---> 25 model = tf.keras.models.load_model(model_path)
#      27 # Predict and evaluate
#      28 y_pred = np.argmax(model.predict(X_test), axis=-1)
#
# File /opt/conda/lib/python3.10/site-packages/keras/saving/saving_api.py:212, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
#     208         safe_mode=safe_mode,
#     209     )
#     211 # Legacy case.
# --> 212 return legacy_sm_saving_lib.load_model(
#     213     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214 )
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/keras/saving/legacy/save.py:230, in load_model(filepath, custom_objects, compile, options)
#     228 if isinstance(filepath_str, str):
#     229     if not tf.io.gfile.exists(filepath_str):
# --> 230         raise IOError(
#     231             f"No file or directory found at {filepath_str}"
#     232         )
#     234     if tf.io.gfile.isdir(filepath_str):
#     235         return saved_model_load.load(
#     236             filepath_str, compile, options
#     237         )
#
# OSError: No file or directory found at /kaggle/working/CV_CNN_models/fold_1_split_5_cnn_v3_opt_32_300_seed7.h5
