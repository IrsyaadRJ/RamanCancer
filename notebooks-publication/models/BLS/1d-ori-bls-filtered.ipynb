# %%
# %cd /kaggle/input/chemcancer-v2/src/
# Out:
# /kaggle/input/chemcancer-v2/src

# %%
pip install rvfln
# Out:
# Requirement already satisfied: rvfln in /opt/conda/lib/python3.10/site-packages (0.0.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tensorflow.keras.optimizers import Adam
from data import *
from machine_learning_models import *
from deep_learning_models import *
from vision_transformer import *
from utils_dl_model import *
from utils_ml_model import print_ml_results
from sklearn.model_selection import train_test_split
from rvfln.bls import BLSClassifier
from sklearn.metrics import accuracy_score

# %%
# Set the seed value.
SEED = 7
np.random.seed(SEED)

# Deep Learning parameters
DL_EPOCH = 500
DL_BATCH_SIZE = 32
DL_CNN_VERSION = 3
DL_TRANSFORMER_VISION_VERSION = 11
DL_BLS_VERSION = 1

DO_DL = True
CV_DL = True
OPT_DL = False

DO_CNN = False
DO_TRANSFORMER_VISION = False
DO_BLS = True
DO_ML = False

# Percentage of test set out of the dataset.
TEST_SET = 0.2

# Percentage of validation set out of the training dataset.
VAL_SET = 0.2

# %%
# Folder path associated with deep learning models
dl_models_folder = "/kaggle/working/Deep_Learning_models/"
dl_metrics_folder = "/kaggle/working/Deep_Learning_metrics/"
dl_weights_folder = "/kaggle/working/Deep_Learning_weights/"
dl_cv_models_folder = "/kaggle/working/Deep_Learning_CV/"
dl_cv_results_folder = "/kaggle/working/Deep_Learning_CV_results/"

# Folder path associated with machine learning models
ml_models_folder = "/kaggle/working/Machine_Learning_models/"
ml_models_results_folder = "/kaggle/working/Machine_Learning_models_results/"

# Model names (Saved in h5 format)
cnn_model_name = f"cnn_v{DL_CNN_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"
transformer_vis_model_name = f"transformer_vision_v{DL_TRANSFORMER_VISION_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"
bls_model_name = f"bls_v{DL_BLS_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"

# Metric filenames
cnn_metrics_filename = f"metrics_{cnn_model_name}.json"
transformer_vis_metrics_filename = f"metrics_{transformer_vis_model_name}.json"

# Weight filenames
cnn_weights_filename = f"weights_{cnn_model_name}.json"
transformer_vis_weights_filename = f"weights_{transformer_vis_model_name}.json"

# Deep Learning models path
if DO_CNN:
    dl_model_path = os.path.join(
        dl_models_folder, cnn_model_name)
elif DO_TRANSFORMER_VISION:
    dl_model_path = os.path.join(
        dl_models_folder, transformer_vis_model_name)


# Deep Learning metrics path
if DO_CNN:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, cnn_metrics_filename)
elif DO_TRANSFORMER_VISION:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, transformer_vis_metrics_filename)


# Deep Learning weights path
if DO_CNN:
    dl_weights_path = os.path.join(
        dl_weights_folder, cnn_weights_filename)

elif DO_TRANSFORMER_VISION:
    dl_weights_path = os.path.join(
        dl_weights_folder, transformer_vis_weights_filename)

# %%
# Load the data
data_file = "../Data/HC05_HC07.csv"

if OPT_DL:
    X_filtered, y = preprocess_cv_raw_data(data_file)
    optimize_hyperparameters(X_filtered, y, n_trials=50)

else:
    # Train deep learning model with cross validation
    if CV_DL:
        print("CV preprocessing")
        X_filtered, y = preprocess_cv_raw_data(data_file)
    else:
        # Preprocess the raw data
        X_train, X_test, y_train, y_test = preprocess_raw_data(
            data_file, TEST_SET)
# Out:
# CV preprocessing
# Load the data
# Data shape : (2373, 274)
# Extract the feature and target data
# X shaped: (2373, 270)
# y shaped: (2373,)
# Apply filters and background substraction to the features dataset

# %%
import optuna
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler
from rvfln.bls import BLSClassifier

def objective(trial,X,y):
    n_z = trial.suggest_int('n_z', 10, 40)
    n_z_features = trial.suggest_int('n_z_features', 50, 200)
    n_h = trial.suggest_int('n_h', 50, 200)
    alpha = trial.suggest_loguniform('alpha', 0.0001, 0.1)

    bls = BLSClassifier(n_z=n_z, n_z_features=n_z_features, n_h=n_h, alpha=alpha)

    fold = 1
    n_splits = 5
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)
    scores = []

    for train_index, test_index in skf.split(X, y):
        # Split the data into training and validation sets
        print("=" * 40)
        print(f"Fold: {fold}")
        print("Splitting the data")
        X_train_full, X_test = X[train_index], X[test_index]
        y_train_full, y_test = y[train_index], y[test_index]

        # Standardize the data
        print("Standardizing the data")
        X_train_full, X_test = standardize_data(X_train_full, X_test)

        # Split the training data into training and validation sets
        X_train, X_test, y_train, y_test = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=seed_value)

        # Fit the model and compute the accuracy
        bls.fit(X_train, y_train)
        score = bls.score(X_test, y_test)
        scores.append(score)
        print(f"Fold {fold}, BLS Test Score: {score:.4f}")
        fold += 1
    
    mean_scores = np.mean(scores)
    print(f"Mean BLS Test score over stratified {n_splits}-fold cross-validation: {mean_scores:.4f}")
    
    return mean_scores

# Create a study object
study = optuna.create_study(direction='maximize')

# Optimize the study
study.optimize(lambda trial: objective(trial, X_filtered, y), n_trials=100)

# Print the best parameters and the corresponding score
print("Best parameters: ", study.best_params)
print("Best score: ", study.best_value)

# %%
X_train, X_test, y_train, y_test = preprocess_raw_data(
    data_file, TEST_SET)
# Out:
# Load the data
# Data shape : (2373, 274)
# Extract the feature and target data
# X shaped: (2373, 270)
# y shaped: (2373,)
# Apply filters and background substraction to the features dataset
# Splitting the data...
# Standardizing the data...

# %%
import optuna
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler
from rvfln.bls import BLSClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

def perform_bls_cv(X,y,n_z, n_z_features, n_h, alpha):

    bls = BLSClassifier(n_z=n_z, n_z_features=n_z_features, n_h=n_h, alpha=alpha)

    fold = 1
    n_splits = 5
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)
    scores = []
    # Initialize lists to store precision, recall, and F1 scores
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []

    for train_index, test_index in skf.split(X, y):
        # Split the data into training and validation sets
        print("=" * 40)
        print(f"Fold: {fold}")
        print("Splitting the data")
        X_train_full, X_test = X[train_index], X[test_index]
        y_train_full, y_test = y[train_index], y[test_index]

        # Split the training data into training and validation sets
        X_train, X_test, y_train, y_test = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=seed_value)
        
        print(f"X_train shape: {X_train.shape}")
        print(f"X_test shape: {X_test.shape}")
        print(f"y_train shape: {y_train.shape}")
        print(f"y_test shape: {y_test.shape}")
        
        # Fit the bls and compute the accuracy
        bls.fit(X_train, y_train)
        score = bls.score(X_test, y_test)
        y_pred = bls.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        
        # Calculate precision, recall, and F1 score
        precision = precision_score(y_test, y_pred, average='macro')
        recall = recall_score(y_test, y_pred, average='macro')
        f1 = f1_score(y_test, y_pred, average='macro')

        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")

        # Append the scores to the lists
        accuracies.append(accuracy)
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        scores.append(score)
        
        
        
        print(f"Fold {fold}, BLS Test Score: {score:.4f}")
        fold += 1
    
    scores = np.array(scores)
    accuracies = np.array(accuracies)
    precisions = np.array(precisions)
    recalls = np.array(recalls)
    f1_scores = np.array(f1_scores)
    
    # Calculate and print the mean and standard deviation of precision, recall, and F1 score
    print(f"Mean BLS Test score over stratified {n_splits}-fold cross-validation: {np.mean(scores):.4f}")
    print(f"Mean accuracies over stratified {n_splits}-fold cross-validation: {np.mean(accuracies):.4f}")
    print(f"Mean precision over stratified {n_splits}-fold cross-validation: {np.mean(precisions):.4f}")
    print(f"Mean recall over stratified {n_splits}-fold cross-validation: {np.mean(recalls):.4f}")
    print(f"Mean F1 score over stratified {n_splits}-fold cross-validation: {np.mean(f1_scores):.4f}")
    print("*" * 40)
    print(f"Standard deviation of BLS Test score over stratified {n_splits}-fold cross-validation: {np.std(scores):.4f}")
    print(f"Standard deviation of accuracies over stratified {n_splits}-fold cross-validation: {np.std(accuracies):.4f}")
    print(f"Standard deviation of precision over stratified {n_splits}-fold cross-validation: {np.std(precisions):.4f}")
    print(f"Standard deviation of recall over stratified {n_splits}-fold cross-validation: {np.std(recalls):.4f}")
    print(f"Standard deviation of F1 score over stratified {n_splits}-fold cross-validation: {np.std(f1_scores):.4f}")
    
    return np.mean(scores)

# %%
n_z=12
n_z_features=50
n_h=100
alpha=0.0001

perform_bls_cv(X_filtered,y,n_z, n_z_features, n_h, alpha)
# Out:
# ========================================
# Fold: 1
# Splitting the data
# X_train shape: (1518, 270)
# X_test shape: (380, 270)
# y_train shape: (1518,)
# y_test shape: (380,)
# Precision: 0.7508
# Recall: 0.7414
# F1 Score: 0.7419
# Fold 1, BLS Test Score: 0.7500
# ========================================
# Fold: 2
# Splitting the data
# X_train shape: (1518, 270)
# X_test shape: (380, 270)
# y_train shape: (1518,)
# y_test shape: (380,)
# Precision: 0.7587
# Recall: 0.7368
# F1 Score: 0.7384
# Fold 2, BLS Test Score: 0.7474
# ========================================
# Fold: 3
# Splitting the data
# X_train shape: (1518, 270)
# X_test shape: (380, 270)
# y_train shape: (1518,)
# y_test shape: (380,)
# Precision: 0.7587
# Recall: 0.7407
# F1 Score: 0.7452
# Fold 3, BLS Test Score: 0.7553
# ========================================
# Fold: 4
# Splitting the data
# X_train shape: (1519, 270)
# X_test shape: (380, 270)
# y_train shape: (1519,)
# y_test shape: (380,)
# Precision: 0.7660
# Recall: 0.7426
# F1 Score: 0.7486
# Fold 4, BLS Test Score: 0.7579
# ========================================
# Fold: 5
# Splitting the data
# X_train shape: (1519, 270)
# X_test shape: (380, 270)
# y_train shape: (1519,)
# y_test shape: (380,)
# Precision: 0.7386
# Recall: 0.7278
# F1 Score: 0.7304
# Fold 5, BLS Test Score: 0.7342
# Mean BLS Test score over stratified 5-fold cross-validation: 0.7489
# Mean accuracies over stratified 5-fold cross-validation: 0.7489
# Mean precision over stratified 5-fold cross-validation: 0.7545
# Mean recall over stratified 5-fold cross-validation: 0.7379
# Mean F1 score over stratified 5-fold cross-validation: 0.7409
# ****************************************
# Standard deviation of BLS Test score over stratified 5-fold cross-validation: 0.0083
# Standard deviation of accuracies over stratified 5-fold cross-validation: 0.0083
# Standard deviation of precision over stratified 5-fold cross-validation: 0.0093
# Standard deviation of recall over stratified 5-fold cross-validation: 0.0054
# Standard deviation of F1 score over stratified 5-fold cross-validation: 0.0062
# 0.7489473684210527

# %%
# Create a BLS classifier
bls = BLSClassifier(n_z=12, n_z_features=50, n_h=83, alpha=0.0002)

# Fit the classifier to the training data
bls.fit(X_train, y_train)
print(bls.score(X_test,y_test))
y_pred = np.argmax(bls.predict(X_test), axis=-1)
print(y_pred)
# Out:
# 0.7536842105263157
# 13

# %%
# Create a BLS classifier
bls = BLSClassifier(n_z=5, n_z_features=50, n_h=500, alpha=0.1)

# Fit the classifier to the training data
bls.fit(X_train, y_train)
print(bls.score(X_test,y_test))
# Out:
# 0.76

# %% [markdown]
# n_z is the number of feature nodes in the enhancement node layer. It should ideally be set considering the dimensionality of your input data. A larger n_z means the model can learn more complex representations, but it may also lead to overfitting if set too high. For your data with 270 features, a reasonable starting point might be around 10-50.
#
# n_z_features is the number of random features generated from each feature node. This parameter directly controls the model's complexity and its computational requirements. A higher number will allow the model to learn more complex representations, but it will also increase the computational cost and may lead to overfitting. A reasonable starting point might be 100-500.
#
# n_h is the number of enhancement nodes. This is another parameter controlling the model's complexity. A higher number will allow the model to learn more complex representations, but it will also increase the computational cost and may lead to overfitting. A reasonable starting point might be 500-2000.
#
# alpha is a regularization parameter. It helps prevent overfitting by adding a penalty to the loss function based on the weights' magnitude. It is typically a small positive value. Common choices are 0.1, 0.01, or 0.001.

# %%
# Print the scores of the classifier
print(bls.score(X_test,y_test))
# Out:
# 0.76

# %%
# Create a BLS classifier
bls = BLSClassifier(n_z=10, n_z_features=50, n_h=100, alpha=0.001)

# Fit the classifier to the training data
bls.fit(X_train, y_train)

# Print the scores of the classifier
print(bls.score(X_test,y_test))
# Out:
# 0.7642105263157895

# %%
# Create a BLS classifier
bls = BLSClassifier(n_z=10, n_z_features=50, n_h=100, alpha=0.0001)

# Fit the classifier to the training data
bls.fit(X_train, y_train)

# Print the scores of the classifier
print(bls.score(X_test,y_test))
# Out:
# 0.7663157894736842

# %%
# Create a BLS classifier
bls = BLSClassifier(n_z=10, n_z_features=50, n_h=100, alpha=0.0001)

# Fit the classifier to the training data
bls.fit(X_train, y_train)

# Print the scores of the classifier
print(bls.score(X_test,y_test))
# Out:
# 0.7305263157894737

# %%
from sklearn.model_selection import GridSearchCV
from rvfln.bls import BLSClassifier
import joblib

# Define the BLSClassifier model
bls = BLSClassifier(n_z=10, n_z_features=50, n_h=50, alpha=0.0001)

# Define the hyperparameters and the range of their values for the grid search
param_grid = {
    'n_z': [10, 20, 30, 40],
    'n_z_features': [50, 100, 150, 200],
    'n_h': [50, 100, 150,200],
    'alpha': [0.0001, 0.001, 0.01, 0.1]
}

# Create a GridSearchCV object
grid_search = GridSearchCV(bls, param_grid, cv=5, scoring='accuracy',verbose=3)

# Fit the GridSearchCV object to the data
grid_search.fit(X_train, y_train)

# Print the best parameters and the corresponding score
print("Best parameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)

# You can also retrieve the best estimator
best_bls = grid_search.best_estimator_

# Save it to a file
joblib.dump(best_bls, 'bls_model.pkl')
# Out:
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=50;, score=0.718 total time=   0.1s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=50;, score=0.700 total time=   0.1s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=50;, score=0.734 total time=   0.2s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=50;, score=0.747 total time=   0.2s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=50;, score=0.723 total time=   0.2s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=100;, score=0.629 total time=   0.2s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=100;, score=0.624 total time=   0.3s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=100;, score=0.621 total time=   0.2s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=100;, score=0.607 total time=   0.2s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=100;, score=0.609 total time=   0.3s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=150;, score=0.479 total time=   0.4s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=150;, score=0.439 total time=   0.4s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=150;, score=0.492 total time=   0.4s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=150;, score=0.430 total time=   0.4s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=150;, score=0.462 total time=   0.4s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=200;, score=0.426 total time=   0.5s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=200;, score=0.455 total time=   0.5s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=200;, score=0.413 total time=   0.5s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=200;, score=0.401 total time=   0.5s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=10, n_z_features=200;, score=0.427 total time=   0.5s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=50;, score=0.611 total time=   0.2s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=50;, score=0.639 total time=   0.3s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=50;, score=0.668 total time=   0.2s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=50;, score=0.665 total time=   0.3s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=50;, score=0.631 total time=   0.2s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=100;, score=0.424 total time=   0.5s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=100;, score=0.439 total time=   0.5s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=100;, score=0.421 total time=   0.5s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=100;, score=0.396 total time=   0.5s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=100;, score=0.372 total time=   0.5s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=150;, score=0.405 total time=   0.8s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=150;, score=0.511 total time=   0.6s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=150;, score=0.463 total time=   0.7s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=150;, score=0.441 total time=   0.7s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=150;, score=0.483 total time=   0.6s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=200;, score=0.463 total time=   0.8s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=200;, score=0.553 total time=   0.8s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=200;, score=0.495 total time=   0.8s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=200;, score=0.504 total time=   0.8s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=20, n_z_features=200;, score=0.557 total time=   0.8s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=50;, score=0.432 total time=   0.4s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=50;, score=0.455 total time=   0.4s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=50;, score=0.463 total time=   0.4s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=50;, score=0.435 total time=   0.4s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=50;, score=0.446 total time=   0.4s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=100;, score=0.479 total time=   0.7s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=100;, score=0.453 total time=   0.7s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=100;, score=0.516 total time=   0.6s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=100;, score=0.456 total time=   0.7s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=100;, score=0.491 total time=   0.7s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=150;, score=0.589 total time=   0.9s
#
# [CV 2/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=150;, score=0.534 total time=   0.9s
#
# [CV 3/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=150;, score=0.584 total time=   0.9s
#
# [CV 4/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=150;, score=0.565 total time=   0.9s
#
# [CV 5/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features=150;, score=0.536 total time=   0.9s
#
# [CV 1/5] END alpha=0.0001, n_h=50, n_z=30, n_z_features
5] END alpha=0.001, n_h=150, n_z=10, n_z_features=200;, score=0.462 total time=   0.5s
#
# [CV 5/5] END alpha=0.001, n_h=150, n_z=10, n_z_features=200;, score=0.480 total time=   0.6s
#
# [CV 1/5] END alpha=0.001, n_h=150, n_z=20, n_z_features=50;, score=0.611 total time=   0.2s
#
# [CV 2/5] END alpha=0.001, n_h=150, n_z=20, n_z_features=50;, score=0.713 total time=   0.2s
#
# [CV 3/5] END alpha=0.001, n_h=150, n_z=20, n_z_features=50;, score=0.674 total time=   0.2s
#
# [CV 4/5] END alpha=0.001, n_h=150, n_z=20, n_z_features=50;, score=0.612 total time=   0.2s
#
# [CV 5/5] END alpha=0.001, n_h=150, n_z=20, n_z_features=50;, score=0.646 total time=   0.3s
#
# [CV 1/5] END alpha=0.001, n_h=150, n_z=20, n_z_features=100;, score=0.439 total time=   0.5s
#
# [CV 2/5] END alpha=0.001, n_h=150, n_z=20, n_z_features=100;, score=0.445 total time=   0.5s
#
# [CV 3/5] END alpha=0.001, n_h=150, n_z=20, n_z_features=100;, score=0.463 total time=   0.5s
#
# [CV 4/5] END alpha=0.001, n_h=150, n_z=20, n_z_features=100;, score=0.449 total time=   0.8s
#
# ...
#
# [CV 1/5] END alpha=0.1, n_h=100, n_z=40, n_z_features=200;, score=0.661 total time=   1.5s
#
# [CV 2/5] END alpha=0.1, n_h=100, n_z=40, n_z_features=200;, score=0.632 total time=   1.8s
#
# [CV 3/5] END alpha=0.1, n_h=100, n_z=40, n_z_features=200;, score=0.713 total time=   1.5s
#
# [CV 4/5] END alpha=0.1, n_h=100, n_z=40, n_z_features=200;, score=0.697 total time=   1.3s
#
# [CV 5/5] END alpha=0.1, n_h=100, n_z=40, n_z_features=200;, score=0.631 total time=   1.3s
#
# [CV 1/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=50;, score=0.761 total time=   0.1s
#
# [CV 2/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=50;, score=0.787 total time=   0.1s
#
# [CV 3/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=50;, score=0.721 total time=   0.1s
#
# [CV 4/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=50;, score=0.765 total time=   0.1s
#
# [CV 5/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=50;, score=0.747 total time=   0.1s
#
# [CV 1/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=100;, score=0.621 total time=   0.3s
#
# [CV 2/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=100;, score=0.650 total time=   0.2s
#
# [CV 3/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=100;, score=0.676 total time=   0.3s
#
# [CV 4/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=100;, score=0.628 total time=   0.2s
#
# [CV 5/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=100;, score=0.644 total time=   0.3s
#
# [CV 1/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=150;, score=0.608 total time=   0.4s
#
# [CV 2/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=150;, score=0.634 total time=   0.4s
#
# [CV 3/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=150;, score=0.655 total time=   0.4s
#
# [CV 4/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=150;, score=0.615 total time=   0.4s
#
# [CV 5/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=150;, score=0.586 total time=   0.4s
#
# [CV 1/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=200;, score=0.597 total time=   0.5s
#
# [CV 2/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=200;, score=0.632 total time=   0.5s
#
# [CV 3/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=200;, score=0.558 total time=   0.5s
#
# [CV 4/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=200;, score=0.599 total time=   0.5s
#
# [CV 5/5] END alpha=0.1, n_h=150, n_z=10, n_z_features=200;, score=0.588 total time=   0.5s
#
# [CV 1/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=50;, score=0.647 total time=   0.2s
#
# [CV 2/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=50;, score=0.671 total time=   0.2s
#
# [CV 3/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=50;, score=0.713 total time=   0.3s
#
# [CV 4/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=50;, score=0.665 total time=   0.2s
#
# [CV 5/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=50;, score=0.668 total time=   0.3s
#
# [CV 1/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=100;, score=0.608 total time=   0.5s
#
# [CV 2/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=100;, score=0.597 total time=   0.5s
#
# [CV 3/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=100;, score=0.616 total time=   0.5s
#
# [CV 4/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=100;, score=0.588 total time=   0.5s
#
# [CV 5/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=100;, score=0.623 total time=   0.5s
#
# [CV 1/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=150;, score=0.584 total time=   0.7s
#
# [CV 2/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=150;, score=0.613 total time=   0.7s
#
# [CV 3/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=150;, score=0.632 total time=   0.6s
#
# [CV 4/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=150;, score=0.599 total time=   0.6s
#
# [CV 5/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=150;, score=0.546 total time=   0.6s
#
# [CV 1/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=200;, score=0.553 total time=   0.8s
#
# [CV 2/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=200;, score=0.582 total time=   1.0s
#
# [CV 3/5] END alpha=0.1, n_h=150, n_z=20, n_z_features=200;, score=0.595 total time=   0.8s
#
# [CV 4/5] END alpha=0.1, n_h=150, n_z=20, n_z_features

#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=20, n_z_features=150;, score=0.621 total time=   0.6s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=20, n_z_features=150;, score=0.586 total time=   0.6s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=20, n_z_features=150;, score=0.578 total time=   0.7s
#
# [CV 1/5] END alpha=0.1, n_h=200, n_z=20, n_z_features=200;, score=0.574 total time=   0.8s
#
# [CV 2/5] END alpha=0.1, n_h=200, n_z=20, n_z_features=200;, score=0.603 total time=   0.8s
#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=20, n_z_features=200;, score=0.595 total time=   0.8s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=20, n_z_features=200;, score=0.652 total time=   0.8s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=20, n_z_features=200;, score=0.586 total time=   0.8s
#
# [CV 1/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=50;, score=0.618 total time=   0.5s
#
# [CV 2/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=50;, score=0.668 total time=   0.5s
#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=50;, score=0.650 total time=   0.4s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=50;, score=0.594 total time=   0.4s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=50;, score=0.578 total time=   0.4s
#
# [CV 1/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=100;, score=0.589 total time=   0.7s
#
# [CV 2/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=100;, score=0.579 total time=   0.6s
#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=100;, score=0.571 total time=   0.6s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=100;, score=0.602 total time=   0.6s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=100;, score=0.586 total time=   0.6s
#
# [CV 1/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=150;, score=0.621 total time=   1.1s
#
# [CV 2/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=150;, score=0.589 total time=   0.9s
#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=150;, score=0.579 total time=   0.9s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=150;, score=0.607 total time=   0.8s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=150;, score=0.633 total time=   0.9s
#
# [CV 1/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=200;, score=0.621 total time=   1.1s
#
# [CV 2/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=200;, score=0.626 total time=   1.1s
#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=200;, score=0.658 total time=   1.1s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=200;, score=0.628 total time=   1.1s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=30, n_z_features=200;, score=0.646 total time=   1.1s
#
# [CV 1/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=50;, score=0.563 total time=   0.6s
#
# [CV 2/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=50;, score=0.582 total time=   0.5s
#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=50;, score=0.600 total time=   0.5s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=50;, score=0.612 total time=   0.5s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=50;, score=0.623 total time=   0.5s
#
# [CV 1/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=100;, score=0.550 total time=   0.8s
#
# [CV 2/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=100;, score=0.597 total time=   0.8s
#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=100;, score=0.539 total time=   0.8s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=100;, score=0.596 total time=   1.1s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=100;, score=0.583 total time=   1.0s
#
# [CV 1/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=150;, score=0.595 total time=   1.1s
#
# [CV 2/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=150;, score=0.632 total time=   1.1s
#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=150;, score=0.639 total time=   1.1s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=150;, score=0.652 total time=   1.1s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=150;, score=0.636 total time=   1.1s
#
# [CV 1/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=200;, score=0.695 total time=   1.4s
#
# [CV 2/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=200;, score=0.674 total time=   1.3s
#
# [CV 3/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=200;, score=0.724 total time=   1.3s
#
# [CV 4/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=200;, score=0.665 total time=   1.3s
#
# [CV 5/5] END alpha=0.1, n_h=200, n_z=40, n_z_features=200;, score=0.660 total time=   1.4s
#
# Best parameters:  {'alpha': 0.1, 'n_h': 150, 'n_z': 10, 'n_z_features': 50}
#
# Best score:  0.7560588807110123
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 30
#      27 best_bls = grid_search.best_estimator_
#      29 # Save it to a file
# ---> 30 joblib.dump(best_bls, 'bls_model.pkl')
#
# File /opt/conda/lib/python3.10/site-packages/joblib/numpy_pickle.py:552, in dump(value, filename, compress, protocol, cache_size)
#     550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
# --> 552     with open(filename, 'wb') as f:
#     553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#
# OSError: [Errno 30] Read-only file system: 'bls_model.pkl'

# %% [markdown]
# Best parameters:  {'alpha': 0.001, 'n_h': 50, 'n_z': 10, 'n_z_features': 50}
# Best score:  0.7470962366338009

# %%
# Create a BLS classifier
bls = BLSClassifier(n_z=10, n_z_features=50, n_h=50, alpha=0.001)

# Fit the classifier to the training data
bls.fit(X_train, y_train)

# Print the scores of the classifier
print(bls.score(X_test,y_test))
