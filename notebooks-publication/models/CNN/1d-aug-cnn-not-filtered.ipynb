# %%
# %cd /kaggle/input/chemcancer-v2/src/
# %mkdir /kaggle/working/Deep_Learning_metrics/
# %mkdir /kaggle/working/During_train/
# %mkdir /kaggle/working/CV_CNN_models
# %mkdir /kaggle/working/CV_CNN_results
# %mkdir /kaggle/working/CV_CNN_fold_data
# %mkdir /kaggle/working/CV_CNN_cm
# Out:
# /kaggle/input/chemcancer-v2/src

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tensorflow.keras.optimizers import Adam
from data import *
from machine_learning_models import *
from deep_learning_models import *
from vision_transformer import *
from utils_dl_model import *
from utils_ml_model import print_ml_results
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Set the seed value.
SEED = 7
np.random.seed(SEED)

# Deep Learning parameters
DL_EPOCH = 1
DL_BATCH_SIZE = 32
DL_CNN_VERSION = 3
DL_TRANSFORMER_VISION_VERSION = 14
DL_CV_FOLD = 5

DO_DL = True
CV_DL = True
OPT_DL = False

DO_CNN = True
DO_TRANSFORMER_VISION = False
DO_ML = False

# Percentage of test set out of the dataset.
TEST_SET = 0.2

# Percentage of validation set out of the training dataset.
VAL_SET = 0.2

# Folder path associated with deep learning models
dl_models_folder = "../Deep_Learning_models/"
dl_metrics_folder = "../Deep_Learning_metrics/"
dl_weights_folder = "../Deep_Learning_weights/"
dl_cv_models_folder = "../Deep_Learning_CV/"
dl_cv_results_folder = "../Deep_Learning_CV_results/"

# Folder path associated with machine learning models
ml_models_folder = "../Machine_Learning_models/"
ml_models_results_folder = "../Machine_Learning_models_results/"

# Model names (Saved in h5 format)
cnn_model_name = f"cnn_v{DL_CNN_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"
transformer_vis_model_name = f"transformer_vision_v{DL_TRANSFORMER_VISION_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"

# Metric filenames
cnn_metrics_filename = f"metrics_{cnn_model_name}.json"
transformer_vis_metrics_filename = f"metrics_{transformer_vis_model_name}.json"

# Weight filenames
cnn_weights_filename = f"weights_{cnn_model_name}.json"
transformer_vis_weights_filename = f"weights_{transformer_vis_model_name}.json"


# Deep Learning models path
if DO_CNN:
    dl_model_path = os.path.join(
        dl_models_folder, cnn_model_name)
elif DO_TRANSFORMER_VISION:
    dl_model_path = os.path.join(
        dl_models_folder, transformer_vis_model_name)


# Deep Learning metrics path
if DO_CNN:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, cnn_metrics_filename)
elif DO_TRANSFORMER_VISION:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, transformer_vis_metrics_filename)


# Deep Learning weights path
if DO_CNN:
    dl_weights_path = os.path.join(
        dl_weights_folder, cnn_weights_filename)

elif DO_TRANSFORMER_VISION:
    dl_weights_path = os.path.join(
        dl_weights_folder, transformer_vis_weights_filename)

# %% [markdown]
# ## Tested - with 0.85 test accuracy in the first fold

# %%
def cnn_model_3(input_shape, num_classes):
    model = Sequential()
    model.add(Conv1D(filters=8, kernel_size=3, activation='relu', kernel_regularizer=l2(0.002), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))
    model.add(Conv1D(filters=16, kernel_size=3, activation='relu', kernel_regularizer=l2(0.002), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', kernel_regularizer=l2(0.002), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', kernel_regularizer=l2(0.002), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.5))
    
    model.add(Flatten())
    model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate = 1e-4),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
       

    return model

# %% [markdown]
# ## Tested - 0.9 val accuracy - v4 Aug data

# %%
def cnn_model_3(input_shape, num_classes):
    model = Sequential()
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.5))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate = 1e-4),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
       

    return model

# %%
# Apply median filter and background subtraction to the data
def apply_filters_and_background_subtraction(X):
    # Reshape the input data to a 2D array if necessary
    if len(X.shape) == 1:
        X = X.reshape((1, -1))
    
    # Apply median filter
    datamedfilt = scipy.ndimage.median_filter(X, size=(1, 5))
    
    # Apply airPLS for background subtraction
    baseline = np.zeros_like(datamedfilt)
    cols = baseline.shape[1]
    for col in range(cols):
        baseline[:, col] = airPLS(datamedfilt[:, col], lambda_=150)
    
    data_bksb = datamedfilt - baseline
    return datamedfilt

# %%
import pickle

def perform_cnn_cv(X_original, y_original, X_augmented, y_augmented, learning_rate, dropout_rate, l2_regularizer, 
                             n_splits=5, epochs=100, batch_size=32, cnn_version = 1, val_set = 0.2,
                             do_opt = False,apply_filters_bg_subtraction= True, models_folder = "models", results_folder = "results"):
    
    if not os.path.exists(models_folder):
        os.makedirs(models_folder)

    if not os.path.exists(results_folder):
        os.makedirs(results_folder)
        
        # Initialize variables for tracking the best model
    best_val_accuracy = 0
    best_model_filepath = ""
        
    accuracies = []
    test_losses = []
    test_accuracies = []
    
    # Initialize lists to store precision, recall, and F1 scores
    precisions = []
    recalls = []
    f1_scores = []
    
    # Initialize lists to store losses and accuracies for each epoch
    mean_training_losses = []
    mean_training_accuracies = []
    mean_val_losses = []   
    mean_val_accuracies = []
    
    # Initialize lists to store losses and accuracies for each epoch
    all_training_losses = []
    all_training_accuracies = []
    all_val_losses = []   
    all_val_accuracies = []
    
    fold = 1
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)
    skf_augmented = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)
    
    for train_index, _ in skf_augmented.split(X_augmented, y_augmented):
        # We are only interested in the train index for augmented data
        # Select the augmented data for training
        print("=" * 40)
        print(f"Fold: {fold}")
        print("Selecting the augmented data")
        
        X_train = X_augmented[train_index]
        y_train = y_augmented[train_index]
        
        X_ori = X_original
        
        if apply_filters_bg_subtraction:
            print("Apply Filters")
            X_train =  apply_filters_and_background_subtraction(X_train)
            X_ori =  apply_filters_and_background_subtraction(X_ori)
        
        # Standardize the data
        print("Standardizing the data")
        X_train, X_ori = standardize_data(X_train, X_ori)
        
        # Reshape the data
        print("Reshaping the data for deep learning models")
        X_train, X_ori = reshape_data(X_train, X_ori)
        
        # Input shape and number of classes for the model
        input_shape = (X_train.shape[1], 1)
        num_classes = len(np.unique(y_original))
        
        # Split a portion of the original data for validation and testing (stratified based on y_original)
        X_val, X_test, y_val, y_test = train_test_split(X_ori, y_original, test_size = 0.7, random_state = seed_value, stratify = y_original)
        
        print(f"X_train shape: {X_train.shape}")
        print(f"X_test shape: {X_test.shape}")
        print(f"X_val shape: {X_val.shape}")
        
        try:
            if do_opt:
                model = cnn_model_3(input_shape, num_classes)
#                 model = cnn_model_3(input_shape, num_classes, learning_rate, dropout_rate, l2_regularizer)
            else:
                model = cnn_model_3(input_shape, num_classes)
            if model is not None:
                print("Building the model 3 with the following hyperparameters:")
                print(f"Learning rate: {learning_rate}")
                print(f"Dropout rate: {dropout_rate}") 
                print(f"L2 Regularizer: {l2_regularizer}")
                print(f"Number of epochs: {epochs}")
                print(f"Batch size: {batch_size}")
                # model.summary()
            else:
                print("Failed to build the CNN model.")
        except Exception as e:
            print(f"Error while building the CNN model: {e}")
        
        print("Saving the data")
        fold_data = {

            'X_train': X_train,
            'X_val': X_val,
            'X_test': X_test,
            'y_train': y_train,
            'y_val': y_val,
            'y_test': y_test
        }

        with open(f"/kaggle/working/CV_CNN_fold_data/fold_{fold}_data.pkl", 'wb') as f:
            pickle.dump(fold_data, f)
        
        filepath = f'/kaggle/working/CV_CNN_models/temp_best_fold_{fold}.h5'
        # the ModelCheckpoint callback to save the best model of the current fold
        model_checkpoint_callback = ModelCheckpoint(
            filepath=os.path.join(filepath),
            save_best_only=True,
            monitor='val_accuracy',
            mode='max'
        )

        
        
        print("Training the model")
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val),
                           callbacks=[model_checkpoint_callback])
         # Check if this model is the best so far
        max_val_accuracy_this_fold = max(history.history['val_accuracy'])
        if max_val_accuracy_this_fold > best_val_accuracy:
            best_val_accuracy = max_val_accuracy_this_fold
            best_model_filepath = filepath
            
        if best_model_filepath:
            best_model = tf.keras.models.load_model(
                best_model_filepath,
#                 custom_objects={'loss': weighted_sparse_categorical_crossentropy(class_weights)}
            )
            print(f"The best model was loaded and ready to be evaluated")
        
        y_pred = np.argmax(model.predict(X_test), axis=-1)
        accuracy = accuracy_score(y_test, y_pred)
        test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
        
            # Calculate precision, recall, and F1 score
        precision = precision_score(y_test, y_pred, average='macro')
        recall = recall_score(y_test, y_pred, average='macro')
        f1 = f1_score(y_test, y_pred, average='macro')

        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")

        # Append the scores to the lists
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        
        all_training_losses.extend(history.history['loss'])
        all_training_accuracies.extend(history.history['accuracy'])
        all_val_losses.extend(history.history['val_loss'])
        all_val_accuracies.extend(history.history['val_accuracy'])
        
        # Append the losses and accuracies for each epoch to the respective lists
        for epoch in range(epochs):
            if fold == 1:
                # For the first fold, initialize the lists with the first fold's values
                mean_training_losses.append(history.history['loss'][epoch])
                mean_training_accuracies.append(history.history['accuracy'][epoch])
                mean_val_losses.append(history.history['val_loss'][epoch])
                mean_val_accuracies.append(history.history['val_accuracy'][epoch])
            else:
                # For subsequent folds, add the fold's values to the running sum
                mean_training_losses[epoch] += history.history['loss'][epoch]
                mean_training_accuracies[epoch] += history.history['accuracy'][epoch]
                mean_val_losses[epoch] += history.history['val_loss'][epoch]
                mean_val_accuracies[epoch] += history.history['val_accuracy'][epoch]

        # Save the model
        if do_opt:
            model_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.h5"
        else:
            model_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.h5"
        model_filepath = os.path.join(models_folder, f"fold_{fold}_split_{n_splits}_{model_filename}")
        model.save(model_filepath)

        # Save the results as a JSON file
        if do_opt:
            results_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            results_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filepath = os.path.join(results_folder, f"fold_{fold}_split_{n_splits}_{results_filename}")

        results = {
            "fold": fold,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1_scores": f1_scores,
            "test_loss": test_loss,
            "test_accuracy": test_accuracy,
            "training_loss": history.history['loss'],
            "training_accuracy": history.history['accuracy'],
            "validation_loss": history.history['val_loss'],
            "validation_accuracy": history.history['val_accuracy'],
        }

        with open(results_filepath, "w") as results_file:
            json.dump(results, results_file, indent=4)
        
        # Append the results to the lists
        accuracies.append(accuracy)
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        
        print(f"Fold {fold}, Accuracy: {accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
        print("=" * 40)
        fold += 1

    # At the end, divide the sums by the number of folds to get the mean
    mean_training_losses = [loss / n_splits for loss in mean_training_losses]
    mean_training_accuracies = [acc / n_splits for acc in mean_training_accuracies]
    mean_val_losses = [loss / n_splits for loss in mean_val_losses]
    mean_val_accuracies = [acc / n_splits for acc in mean_val_accuracies]
    # Convert lists to numpy arrays for easier calculation of mean and standard deviation
    mean_accuracy = np.mean(accuracies)
    mean_test_loss = np.mean(test_losses)
    mean_test_accuracy = np.mean(test_accuracies)
    
    mean_training_loss = np.mean(all_training_losses)
    std_training_loss = np.std(all_training_losses)
    mean_training_accuracy = np.mean(all_training_accuracies)
    std_training_accuracy = np.std(all_training_accuracies)

    mean_val_loss = np.mean(all_val_losses)
    std_val_loss = np.std(all_val_losses)
    mean_val_accuracy = np.mean(all_val_accuracies)
    std_val_accuracy = np.std(all_val_accuracies)

    # Calculate standard deviations
    std_accuracy = np.std(accuracies)
    std_test_loss = np.std(test_losses)
    std_test_accuracy = np.std(test_accuracies)

    std_training_loss = np.std(mean_training_losses)
    std_training_accuracy = np.std(mean_training_accuracies)
    std_val_loss = np.std(mean_val_losses)
    std_val_accuracy = np.std(mean_val_accuracies)

    precisions = np.array(precisions)
    recalls = np.array(recalls)
    f1_scores = np.array(f1_scores)

      
    print(f"test losses: {test_losses}")
    print(f"test accuracy: {test_accuracies}")
    
    print("*" * 40)
    print(f"Mean training loss over {n_splits}-fold cross-validation: {mean_training_loss:.4f}")
    print(f"Mean training accuracy over {n_splits}-fold cross-validation: {mean_training_accuracy:.4f}")
    print(f"Mean validation loss over {n_splits}-fold cross-validation: {mean_val_loss:.4f}")
    print(f"Mean validation accuracy over {n_splits}-fold cross-validation: {mean_val_accuracy:.4f}")
    print("*" * 40)
    print(f"Mean accuracy over stratified {n_splits}-fold cross-validation: {mean_accuracy:.4f}")
    print(f"Mean test loss over stratified {n_splits}-fold cross-validation: {mean_test_loss:.4f}")
    print(f"Mean test accuracy over stratified {n_splits}-fold cross-validation: {mean_test_accuracy:.4f}")
    
    print("*" * 40)
    print(f"Standard deviation of training loss over {n_splits}-fold cross-validation: {std_training_loss:.4f}")
    print(f"Standard deviation of training accuracy over {n_splits}-fold cross-validation: {std_training_accuracy:.4f}")
    print(f"Standard deviation of validation loss over {n_splits}-fold cross-validation: {std_val_loss:.4f}")
    print(f"Standard deviation of validation accuracy over {n_splits}-fold cross-validation: {std_val_accuracy:.4f}")
        
    print("*" * 40)
    print(f"Standard deviation of accuracy over stratified {n_splits}-fold cross-validation: {std_accuracy:.4f}")
    print(f"Standard deviation of test loss over stratified {n_splits}-fold cross-validation: {std_test_loss:.4f}")
    print(f"Standard deviation of test accuracy over stratified {n_splits}-fold cross-validation: {std_test_accuracy:.4f}")
    print("*" * 40)
    
    # Calculate and print the mean and standard deviation of precision, recall, and F1 score
    print(f"Mean precision over stratified {n_splits}-fold cross-validation: {np.mean(precisions):.4f}")
    print(f"Standard deviation of precision over stratified {n_splits}-fold cross-validation: {np.std(precisions):.4f}")
    print(f"Mean recall over stratified {n_splits}-fold cross-validation: {np.mean(recalls):.4f}")
    print(f"Standard deviation of recall over stratified {n_splits}-fold cross-validation: {np.std(recalls):.4f}")
    print(f"Mean F1 score over stratified {n_splits}-fold cross-validation: {np.mean(f1_scores):.4f}")
    print(f"Standard deviation of F1 score over stratified {n_splits}-fold cross-validation: {np.std(f1_scores):.4f}")

    
# Define the directory where the JSON files are stored

    fig, axes = plt.subplots(2, n_splits, figsize=(20, 10))

    for fold in range(1, n_splits+1):
        # Load the JSON file for this fold
        if do_opt:
            cnn_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            cnn_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filename = f"fold_{fold}_split_{n_splits}_{cnn_filename}"
        
        results_filepath = os.path.join(results_folder, results_filename)
        
        with open(results_filepath, "r") as results_file:
            results = json.load(results_file)
        
        # Plot training and validation loss
        axes[0, fold-1].plot(results["training_loss"], label='Train')
        axes[0, fold-1].plot(results["validation_loss"], label='Validation')
        axes[0, fold-1].set_title(f'Fold {fold} Loss')
        axes[0, fold-1].set_xlabel('Epochs')
        axes[0, fold-1].set_ylabel('Loss')
        axes[0, fold-1].legend()

        # Plot training and validation accuracy
        axes[1, fold-1].plot(results["training_accuracy"], label='Train')
        axes[1, fold-1].plot(results["validation_accuracy"], label='Validation')
        axes[1, fold-1].set_title(f'Fold {fold} Accuracy')
        axes[1, fold-1].set_xlabel('Epochs')
        axes[1, fold-1].set_ylabel('Accuracy')
        axes[1, fold-1].legend()

    plt.tight_layout()
    plt.show()

    return mean_val_accuracies

# %%
def extract_data_from_csv(filename="generated_data.csv"):
    # Read the CSV file into a DataFrame
    df_extracted = pd.read_csv(filename)
    
    # Split the DataFrame into features and labels
    X_extracted = df_extracted.drop(columns=["labels"]).values
    y_extracted = df_extracted["labels"].values
    
    return X_extracted, y_extracted

# %%
# With bksb, slope and roll set to true
test_data= "/kaggle/input/test-gen-cc-10x-v4/test-gen-cc-10x-v4.csv"

# No bksb, slope and roll set to false
train_data = "/kaggle/input/gen-cc-10x-v4/gen-cc-10x-v4.csv"

# %%
X_augmented, y_augmented = extract_data_from_csv(train_data)
print(f"X_augmented shaped: {X_augmented.shape}")
print(f"y_augmented shaped: {y_augmented.shape}")

X_original, y_original = extract_data_from_csv(test_data)
print(f"X_original shaped: {X_original.shape}")
print(f"y_original shaped: {y_original.shape}")
# Out:
# X_augmented shaped: (18980, 270)
# y_augmented shaped: (18980,)
# X_original shaped: (475, 270)
# y_original shaped: (475,)

# %%
DL_EPOCH = 80

if DO_CNN:
    # Start the timer
    start_time = time.time()
    learning_rate = 1e-4
    dropout_rate = 0.5
    l2_regularizer = 0.001
    perform_cnn_cv(X_original, y_original, X_augmented, y_augmented, learning_rate, dropout_rate, l2_regularizer,
                            n_splits=DL_CV_FOLD, epochs=DL_EPOCH, batch_size=DL_BATCH_SIZE, cnn_version=DL_CNN_VERSION,
                            do_opt=True, apply_filters_bg_subtraction= False, models_folder="/kaggle/working/CV_CNN_models", results_folder= "/kaggle/working/CV_CNN_results")
    # End the timer
    end_time = time.time()
    # Calculate the elapsed time
    elapsed_time = end_time - start_time
    # Print the elapsed time
    print("Training time: {:.2f} seconds".format(elapsed_time))

# Train the model
print("Training and evaluating the model...")
# Start the timer
start_time = time.time()
model_history = model.fit(X_train, y_train, batch_size=DL_BATCH_SIZE,
                          epochs=DL_EPOCH, validation_data=(X_val, y_val), shuffle=True, callbacks=callbacks)
# End the timer
end_time = time.time()
# Calculate the elapsed time
elapsed_time = end_time - start_time
# Print the elapsed time
print("Training time: {:.2f} seconds".format(elapsed_time))
# Compile the model

# Save the deep learning model
print("Saving model to ", dl_model_path)
model.save(dl_model_path)

# Save the deep learning model's weights
print("Saving model weights to ", dl_weights_path)
model.save_weights(dl_weights_path)

# Evaluating the model
print("Evaluating the CNN model... ")
# Calculate model loss and accuracy
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_accuracy)

# Save the model's metrics
print("Saving the model metrics to ", dl_metrics_path)
save_dl_metrics(model_history, test_loss,
                test_accuracy, dl_metrics_path)

# Plot the model history
plot_dl_history(model_history)
# Out:
# ========================================
# Fold: 1
# Selecting the augmented data
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 8s 8ms/step - loss: 2.4353 - accuracy: 0.3641 - val_loss: 1.5818 - val_accuracy: 0.4859
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.8733 - accuracy: 0.3892 - val_loss: 1.5048 - val_accuracy: 0.5845
# Epoch 3/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.7233 - accuracy: 0.4025 - val_loss: 1.5079 - val_accuracy: 0.5915
# Epoch 4/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6577 - accuracy: 0.4152 - val_loss: 1.4977 - val_accuracy: 0.5845
# Epoch 5/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6175 - accuracy: 0.4249 - val_loss: 1.4869 - val_accuracy: 0.5704
# Epoch 6/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5909 - accuracy: 0.4333 - val_loss: 1.4662 - val_accuracy: 0.5634
# Epoch 7/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5580 - accuracy: 0.4548 - val_loss: 1.4373 - val_accuracy: 0.5282
# Epoch 8/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5327 - accuracy: 0.4682 - val_loss: 1.4050 - val_accuracy: 0.5423
# Epoch 9/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5052 - accuracy: 0.4813 - val_loss: 1.3740 - val_accuracy: 0.5634
# Epoch 10/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4544 - accuracy: 0.5101 - val_loss: 1.3148 - val_accuracy: 0.5986
# Epoch 11/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4035 - accuracy: 0.5371 - val_loss: 1.2789 - val_accuracy: 0.6056
# Epoch 12/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3516 - accuracy: 0.5664 - val_loss: 1.2701 - val_accuracy: 0.6056
# Epoch 13/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2960 - accuracy: 0.5829 - val_loss: 1.2566 - val_accuracy: 0.6479
# Epoch 14/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2532 - accuracy: 0.6048 - val_loss: 1.0825 - val_accuracy: 0.7254
# Epoch 15/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2055 - accuracy: 0.6187 - val_loss: 1.0602 - val_accuracy: 0.6972
# Epoch 16/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1637 - accuracy: 0.6340 - val_loss: 1.0569 - val_accuracy: 0.6831
# Epoch 17/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1340 - accuracy: 0.6476 - val_loss: 0.9750 - val_accuracy: 0.7394
# Epoch 18/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0854 - accuracy: 0.6610 - val_loss: 0.9970 - val_accuracy: 0.7183
# Epoch 19/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0482 - accuracy: 0.6833 - val_loss: 1.3321 - val_accuracy: 0.5634
# Epoch 20/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0045 - accuracy: 0.7001 - val_loss: 1.1681 - val_accuracy: 0.5915
# Epoch 21/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9671 - accuracy: 0.7162 - val_loss: 0.8488 - val_accuracy: 0.7254
# Epoch 22/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9404 - accuracy: 0.7230 - val_loss: 0.8413 - val_accuracy: 0.7606
# Epoch 23/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9057 - accuracy: 0.7304 - val_loss: 0.9515 - val_accuracy: 0.6761
# Epoch 24/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8840 - accuracy: 0.7416 - val_loss: 0.9172 - val_accuracy: 0.6972
# Epoch 25/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8561 - accuracy: 0.7546 - val_loss: 0.8340 - val_accuracy: 0.7183
# Epoch 26/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8244 - accuracy: 0.7573 - val_loss: 0.7221 - val_accuracy: 0.7746
# Epoch 27/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7987 - accuracy: 0.7692 - val_loss: 0.8585 - val_accuracy: 0.7254
# Epoch 28/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7851 - accuracy: 0.7750 - val_loss: 0.7252 - val_accuracy: 0.7887
# Epoch 29/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7607 - accuracy: 0.7796 - val_loss: 0.6707 - val_accuracy: 0.8239
# Epoch 30/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7319 - accuracy: 0.7920 - val_loss: 0.6463 - val_accuracy: 0.8310
# Epoch 31/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7130 - accuracy: 0.7925 - val_loss: 0.6651 - val_accuracy: 0.8099
# Epoch 32/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6963 - accuracy: 0.8016 - val_loss: 0.6022 - val_accuracy: 0.8380
# Epoch 33/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6896 - accuracy: 0.7990 - val_loss: 0.6009 - val_accuracy: 0.8239
# Epoch 34/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6623 - accuracy: 0.8131 - val_loss: 0.6022 - val_accuracy: 0.8310
# Epoch 35/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6537 - accuracy: 0.8124 - val_loss: 0.6181 - val_accuracy: 0.8239
# Epoch 36/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6332 - accuracy: 0.8184 - val_loss: 0.6186 - val_accuracy: 0.8239
# Epoch 37/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6174 - accuracy: 0.8237 - val_loss: 0.8139 - val_accuracy: 0.7465
# Epoch 38/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6156 - accuracy: 0.8221 - val_loss: 0.5795 - val_accuracy: 0.8310
# Epoch 39/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5941 - accuracy: 0.8302 - val_loss: 0.5437 - val_accuracy: 0.8451
# Epoch 40/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5769 - accuracy: 0.8346 - val_loss: 0.5522 - val_accuracy: 0.8451
# Epoch 41/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5676 - accuracy: 0.8366 - val_loss: 0.5455 - val_accuracy: 0.8310
# Epoch 42/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5636 - accuracy: 0.8368 - val_loss: 0.5409 - val_accuracy: 0.8310
# Epoch 43/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5316 - accuracy: 0.8509 - val_loss: 0.5931 - val_accuracy: 0.8169
# Epoch 44/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5305 - accuracy: 0.8511 - val_loss: 0.5544 - val_accuracy: 0.8592
# Epoch 45/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5223 - accuracy: 0.8533 - val_loss: 0.5182 - val_accuracy: 0.8451
# Epoch 46/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5003 - accuracy: 0.8625 - val_loss: 0.5505 - val_accuracy: 0.8169
# Epoch 47/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4997 - accuracy: 0.8618 - val_loss: 0.5151 - val_accuracy: 0.8662
# Epoch 48/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4863 - accuracy: 0.8648 - val_loss: 0.5170 - val_accuracy: 0.8592
# Epoch 49/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4814 - accuracy: 0.8666 - val_loss: 0.5234 - val_accuracy: 0.8732
# Epoch 50/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4725 - accuracy: 0.8709 - val_loss: 0.5260 - val_accuracy: 0.8592
# Epoch 51/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4598 - accuracy: 0.8740 - val_loss: 0.5116 - val_accuracy: 0.8592
# Epoch 52/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4534 - accuracy: 0.8775 - val_loss: 0.5177 - val_accuracy: 0.8662
# Epoch 53/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4425 - accuracy: 0.8821 - val_loss: 0.5266 - val_accuracy: 0.8239
# Epoch 54/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4317 - accuracy: 0.8842 - val_loss: 0.5161 - val_accuracy: 0.8521
# Epoch 55/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4287 - accuracy: 0.8871 - val_loss: 0.4927 - val_accuracy: 0.8451
# Epoch 56/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4144 - accuracy: 0.8907 - val_loss: 0.5313 - val_accuracy: 0.8592
# Epoch 57/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4079 - accuracy: 0.8907 - val_loss: 0.5362 - val_accuracy: 0.8451
# Epoch 58/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4058 - accuracy: 0.8944 - val_loss: 0.5315 - val_accuracy: 0.8380
# Epoch 59/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3979 - accuracy: 0.8971 - val_loss: 0.5330 - val_accuracy: 0.8662
# Epoch 60/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3933 - accuracy: 0.8974 - val_loss: 0.5843 - val_accuracy: 0.8380
# Epoch 61/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3921 - accuracy: 0.8995 - val_loss: 0.5345 - val_accuracy: 0.8592
# Epoch 62/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3788 - accuracy: 0.9019 - val_loss: 0.5567 - val_accuracy: 0.8310
# Epoch 63/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3721 - accuracy: 0.9057 - val_loss: 0.5731 - val_accuracy: 0.8451
# Epoch 64/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3766 - accuracy: 0.9041 - val_loss: 0.5445 - val_accuracy: 0.8521
# Epoch 65/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3614 - accuracy: 0.9090 - val_loss: 0.5422 - val_accuracy: 0.8451
# Epoch 66/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3503 - accuracy: 0.9123 - val_loss: 0.6109 - val_accuracy: 0.7958
# Epoch 67/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3481 - accuracy: 0.9159 - val_loss: 0.5365 - val_accuracy: 0.8662
# Epoch 68/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3416 - accuracy: 0.9183 - val_loss: 0.5401 - val_accuracy: 0.8803
# Epoch 69/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3362 - accuracy: 0.9177 - val_loss: 0.5414 - val_accuracy: 0.8873
# Epoch 70/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3379 - accuracy: 0.9177 - val_loss: 0.5400 - val_accuracy: 0.8662
# Epoch 71/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3249 - accuracy: 0.9242 - val_loss: 0.5289 - val_accuracy: 0.8521
# Epoch 72/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3253 - accuracy: 0.9231 - val_loss: 0.5897 - val_accuracy: 0.8521
# Epoch 73/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3190 - accuracy: 0.9249 - val_loss: 0.5434 - val_accuracy: 0.8521
# Epoch 74/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3126 - accuracy: 0.9259 - val_loss: 0.5473 - val_accuracy: 0.8662
# Epoch 75/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3155 - accuracy: 0.9250 - val_loss: 0.5565 - val_accuracy: 0.8451
# Epoch 76/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3007 - accuracy: 0.9298 - val_loss: 0.5436 - val_accuracy: 0.8521
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3079 - accuracy: 0.9289 - val_loss: 0.5520 - val_accuracy: 0.8521
# Epoch 78/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2987 - accuracy: 0.9307 - val_loss: 0.6120 - val_accuracy: 0.8451
# Epoch 79/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2907 - accuracy: 0.9358 - val_loss: 0.5727 - val_accuracy: 0.8662
# Epoch 80/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2897 - accuracy: 0.9338 - val_loss: 0.5856 - val_accuracy: 0.8592
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 12ms/step
# Precision: 0.8508
# Recall: 0.8473
# F1 Score: 0.8482
# Fold 1, Accuracy: 0.8619, Test Loss: 0.4656, Test Accuracy: 0.8619
# ========================================
# ========================================
# Fold: 2
# Selecting the augmented data
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 8s 7ms/step - loss: 2.4467 - accuracy: 0.3680 - val_loss: 1.5328 - val_accuracy: 0.5141
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.8608 - accuracy: 0.3876 - val_loss: 1.5091 - val_accuracy: 0.5282
# Epoch 3/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.7056 - accuracy: 0.4000 - val_loss: 1.4951 - val_accuracy: 0.5423
# Epoch 4/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6592 - accuracy: 0.4044 - val_loss: 1.4764 - val_accuracy: 0.5282
# Epoch 5/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6144 - accuracy: 0.4172 - val_loss: 1.4581 - val_accuracy: 0.5070
# Epoch 6/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5882 - accuracy: 0.4359 - val_loss: 1.4452 - val_accuracy: 0.5141
# Epoch 7/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5624 - accuracy: 0.4457 - val_loss: 1.4397 - val_accuracy: 0.5282
# Epoch 8/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5297 - accuracy: 0.4632 - val_loss: 1.3893 - val_accuracy: 0.5141
# Epoch 9/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5004 - accuracy: 0.4837 - val_loss: 1.4760 - val_accuracy: 0.5211
# Epoch 10/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4548 - accuracy: 0.5098 - val_loss: 1.2694 - val_accuracy: 0.6056
# Epoch 11/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3910 - accuracy: 0.5516 - val_loss: 1.2099 - val_accuracy: 0.6761
# Epoch 12/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3126 - accuracy: 0.5901 - val_loss: 1.3119 - val_accuracy: 0.6197
# Epoch 13/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2451 - accuracy: 0.6205 - val_loss: 1.4868 - val_accuracy: 0.5352
# Epoch 14/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1943 - accuracy: 0.6450 - val_loss: 1.4106 - val_accuracy: 0.5211
# Epoch 15/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1520 - accuracy: 0.6595 - val_loss: 1.0581 - val_accuracy: 0.7042
# Epoch 16/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0993 - accuracy: 0.6773 - val_loss: 1.1579 - val_accuracy: 0.6831
# Epoch 17/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0546 - accuracy: 0.6981 - val_loss: 0.9306 - val_accuracy: 0.7394
# Epoch 18/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0124 - accuracy: 0.7115 - val_loss: 0.9899 - val_accuracy: 0.7254
# Epoch 19/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9807 - accuracy: 0.7250 - val_loss: 0.9495 - val_accuracy: 0.7113
# Epoch 20/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9360 - accuracy: 0.7384 - val_loss: 0.8949 - val_accuracy: 0.7254
# Epoch 21/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9085 - accuracy: 0.7502 - val_loss: 0.8200 - val_accuracy: 0.7535
# Epoch 22/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8773 - accuracy: 0.7573 - val_loss: 0.8343 - val_accuracy: 0.7535
# Epoch 23/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8493 - accuracy: 0.7717 - val_loss: 0.9210 - val_accuracy: 0.7394
# Epoch 24/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8262 - accuracy: 0.7721 - val_loss: 0.7522 - val_accuracy: 0.7746
# Epoch 25/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7996 - accuracy: 0.7780 - val_loss: 0.7058 - val_accuracy: 0.8099
# Epoch 26/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7659 - accuracy: 0.7939 - val_loss: 0.6904 - val_accuracy: 0.8239
# Epoch 27/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7533 - accuracy: 0.7912 - val_loss: 0.7371 - val_accuracy: 0.7817
# Epoch 28/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7346 - accuracy: 0.7954 - val_loss: 0.6856 - val_accuracy: 0.8169
# Epoch 29/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7085 - accuracy: 0.8038 - val_loss: 0.7148 - val_accuracy: 0.7887
# Epoch 30/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6981 - accuracy: 0.8075 - val_loss: 0.6178 - val_accuracy: 0.8380
# Epoch 31/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6722 - accuracy: 0.8163 - val_loss: 0.6558 - val_accuracy: 0.8099
# Epoch 32/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6602 - accuracy: 0.8195 - val_loss: 0.6102 - val_accuracy: 0.8310
# Epoch 33/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6436 - accuracy: 0.8242 - val_loss: 0.5764 - val_accuracy: 0.8451
# Epoch 34/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6339 - accuracy: 0.8244 - val_loss: 0.5651 - val_accuracy: 0.8451
# Epoch 35/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6157 - accuracy: 0.8323 - val_loss: 0.5600 - val_accuracy: 0.8380
# Epoch 36/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5881 - accuracy: 0.8392 - val_loss: 0.5331 - val_accuracy: 0.8592
# Epoch 37/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5858 - accuracy: 0.8412 - val_loss: 0.5152 - val_accuracy: 0.8732
# Epoch 38/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5734 - accuracy: 0.8452 - val_loss: 0.5419 - val_accuracy: 0.8451
# Epoch 39/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5533 - accuracy: 0.8561 - val_loss: 0.5121 - val_accuracy: 0.8662
# Epoch 40/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5439 - accuracy: 0.8546 - val_loss: 0.5087 - val_accuracy: 0.8380
# Epoch 41/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5368 - accuracy: 0.8583 - val_loss: 0.4785 - val_accuracy: 0.8944
# Epoch 42/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5303 - accuracy: 0.8577 - val_loss: 0.5362 - val_accuracy: 0.8239
# Epoch 43/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5144 - accuracy: 0.8647 - val_loss: 0.4713 - val_accuracy: 0.8732
# Epoch 44/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5021 - accuracy: 0.8672 - val_loss: 0.4850 - val_accuracy: 0.8803
# Epoch 45/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4938 - accuracy: 0.8705 - val_loss: 0.4756 - val_accuracy: 0.8873
# Epoch 46/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4770 - accuracy: 0.8759 - val_loss: 0.4653 - val_accuracy: 0.8873
# Epoch 47/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4692 - accuracy: 0.8772 - val_loss: 0.4819 - val_accuracy: 0.8732
# Epoch 48/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4576 - accuracy: 0.8821 - val_loss: 0.4878 - val_accuracy: 0.8803
# Epoch 49/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4492 - accuracy: 0.8835 - val_loss: 0.4909 - val_accuracy: 0.8662
# Epoch 50/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4455 - accuracy: 0.8863 - val_loss: 0.4796 - val_accuracy: 0.8732
# Epoch 51/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4362 - accuracy: 0.8874 - val_loss: 0.4679 - val_accuracy: 0.8873
# Epoch 52/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4215 - accuracy: 0.8920 - val_loss: 0.4818 - val_accuracy: 0.8662
# Epoch 53/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4190 - accuracy: 0.8921 - val_loss: 0.6320 - val_accuracy: 0.8028
# Epoch 54/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4174 - accuracy: 0.8927 - val_loss: 0.5064 - val_accuracy: 0.8592
# Epoch 55/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3994 - accuracy: 0.9010 - val_loss: 0.4621 - val_accuracy: 0.8873
# Epoch 56/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4030 - accuracy: 0.8998 - val_loss: 0.4480 - val_accuracy: 0.8803
# Epoch 57/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3890 - accuracy: 0.9067 - val_loss: 0.4498 - val_accuracy: 0.8732
# Epoch 58/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3823 - accuracy: 0.9071 - val_loss: 0.4227 - val_accuracy: 0.9014
# Epoch 59/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3763 - accuracy: 0.9087 - val_loss: 0.4596 - val_accuracy: 0.8803
# Epoch 60/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3689 - accuracy: 0.9127 - val_loss: 0.4634 - val_accuracy: 0.8662
# Epoch 61/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3652 - accuracy: 0.9135 - val_loss: 0.4567 - val_accuracy: 0.8662
# Epoch 62/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3637 - accuracy: 0.9118 - val_loss: 0.4941 - val_accuracy: 0.8592
# Epoch 63/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3547 - accuracy: 0.9149 - val_loss: 0.4561 - val_accuracy: 0.8662
# Epoch 64/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3454 - accuracy: 0.9178 - val_loss: 0.5045 - val_accuracy: 0.8662
# Epoch 65/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3456 - accuracy: 0.9181 - val_loss: 0.4661 - val_accuracy: 0.8662
# Epoch 66/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3316 - accuracy: 0.9217 - val_loss: 0.4666 - val_accuracy: 0.8592
# Epoch 67/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3262 - accuracy: 0.9224 - val_loss: 0.4745 - val_accuracy: 0.8662
# Epoch 68/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3296 - accuracy: 0.9243 - val_loss: 0.4708 - val_accuracy: 0.8592
# Epoch 69/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3195 - accuracy: 0.9258 - val_loss: 0.4707 - val_accuracy: 0.8732
# Epoch 70/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3174 - accuracy: 0.9292 - val_loss: 0.4676 - val_accuracy: 0.8873
# Epoch 71/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3174 - accuracy: 0.9260 - val_loss: 0.4865 - val_accuracy: 0.8662
# Epoch 72/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3080 - accuracy: 0.9324 - val_loss: 0.4727 - val_accuracy: 0.8662
# Epoch 73/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3104 - accuracy: 0.9302 - val_loss: 0.5490 - val_accuracy: 0.8310
# Epoch 74/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3012 - accuracy: 0.9335 - val_loss: 0.4661 - val_accuracy: 0.8803
# Epoch 75/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3016 - accuracy: 0.9325 - val_loss: 0.4748 - val_accuracy: 0.8732
# Epoch 76/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3030 - accuracy: 0.9310 - val_loss: 0.4567 - val_accuracy: 0.8732
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2922 - accuracy: 0.9376 - val_loss: 0.4808 - val_accuracy: 0.8732
# Epoch 78/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2903 - accuracy: 0.9372 - val_loss: 0.5016 - val_accuracy: 0.8732
# Epoch 79/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2883 - accuracy: 0.9382 - val_loss: 0.5320 - val_accuracy: 0.8732
# Epoch 80/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2859 - accuracy: 0.9388 - val_loss: 0.4842 - val_accuracy: 0.8592
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 2ms/step
# Precision: 0.8475
# Recall: 0.8400
# F1 Score: 0.8406
# Fold 2, Accuracy: 0.8559, Test Loss: 0.4645, Test Accuracy: 0.8559
# ========================================
# ========================================
# Fold: 3
# Selecting the augmented data
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 7s 7ms/step - loss: 2.3862 - accuracy: 0.3659 - val_loss: 1.6395 - val_accuracy: 0.4718
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.8464 - accuracy: 0.3732 - val_loss: 1.6170 - val_accuracy: 0.5141
# Epoch 3/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.7134 - accuracy: 0.3942 - val_loss: 1.5933 - val_accuracy: 0.5000
# Epoch 4/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6635 - accuracy: 0.3981 - val_loss: 1.5715 - val_accuracy: 0.5493
# Epoch 5/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6285 - accuracy: 0.4009 - val_loss: 1.5257 - val_accuracy: 0.4930
# Epoch 6/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5962 - accuracy: 0.4149 - val_loss: 1.5118 - val_accuracy: 0.4366
# Epoch 7/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5738 - accuracy: 0.4307 - val_loss: 1.4703 - val_accuracy: 0.5070
# Epoch 8/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5485 - accuracy: 0.4384 - val_loss: 1.4481 - val_accuracy: 0.4930
# Epoch 9/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5266 - accuracy: 0.4486 - val_loss: 1.4484 - val_accuracy: 0.4718
# Epoch 10/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4953 - accuracy: 0.4619 - val_loss: 1.4083 - val_accuracy: 0.5141
# Epoch 11/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4661 - accuracy: 0.4840 - val_loss: 1.3955 - val_accuracy: 0.5000
# Epoch 12/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4151 - accuracy: 0.5132 - val_loss: 1.4152 - val_accuracy: 0.4930
# Epoch 13/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3590 - accuracy: 0.5439 - val_loss: 1.2374 - val_accuracy: 0.5986
# Epoch 14/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2861 - accuracy: 0.5711 - val_loss: 1.1495 - val_accuracy: 0.6479
# Epoch 15/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2244 - accuracy: 0.6034 - val_loss: 1.0308 - val_accuracy: 0.7465
# Epoch 16/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1778 - accuracy: 0.6210 - val_loss: 1.0162 - val_accuracy: 0.6761
# Epoch 17/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1398 - accuracy: 0.6373 - val_loss: 0.9774 - val_accuracy: 0.7042
# Epoch 18/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0982 - accuracy: 0.6540 - val_loss: 0.9604 - val_accuracy: 0.6972
# Epoch 19/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0490 - accuracy: 0.6761 - val_loss: 0.9998 - val_accuracy: 0.6972
# Epoch 20/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0175 - accuracy: 0.6838 - val_loss: 0.9539 - val_accuracy: 0.7113
# Epoch 21/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9708 - accuracy: 0.7077 - val_loss: 0.8625 - val_accuracy: 0.7324
# Epoch 22/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9435 - accuracy: 0.7188 - val_loss: 0.9299 - val_accuracy: 0.7113
# Epoch 23/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9064 - accuracy: 0.7334 - val_loss: 0.8697 - val_accuracy: 0.7324
# Epoch 24/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8746 - accuracy: 0.7401 - val_loss: 1.0816 - val_accuracy: 0.6338
# Epoch 25/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8533 - accuracy: 0.7526 - val_loss: 0.8108 - val_accuracy: 0.7746
# Epoch 26/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8252 - accuracy: 0.7587 - val_loss: 0.8006 - val_accuracy: 0.7394
# Epoch 27/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7988 - accuracy: 0.7684 - val_loss: 0.7161 - val_accuracy: 0.7746
# Epoch 28/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7660 - accuracy: 0.7759 - val_loss: 0.7233 - val_accuracy: 0.7676
# Epoch 29/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7516 - accuracy: 0.7806 - val_loss: 0.7239 - val_accuracy: 0.7465
# Epoch 30/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7414 - accuracy: 0.7815 - val_loss: 0.7223 - val_accuracy: 0.7817
# Epoch 31/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7160 - accuracy: 0.7904 - val_loss: 0.6726 - val_accuracy: 0.7887
# Epoch 32/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6895 - accuracy: 0.8045 - val_loss: 0.6691 - val_accuracy: 0.7817
# Epoch 33/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6777 - accuracy: 0.7991 - val_loss: 0.8406 - val_accuracy: 0.7254
# Epoch 34/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6627 - accuracy: 0.8037 - val_loss: 0.6081 - val_accuracy: 0.8310
# Epoch 35/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6482 - accuracy: 0.8099 - val_loss: 0.7412 - val_accuracy: 0.7676
# Epoch 36/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6334 - accuracy: 0.8111 - val_loss: 0.5978 - val_accuracy: 0.8310
# Epoch 37/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6200 - accuracy: 0.8199 - val_loss: 0.6258 - val_accuracy: 0.8099
# Epoch 38/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6084 - accuracy: 0.8246 - val_loss: 0.5719 - val_accuracy: 0.8521
# Epoch 39/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5862 - accuracy: 0.8319 - val_loss: 0.5512 - val_accuracy: 0.8451
# Epoch 40/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5758 - accuracy: 0.8321 - val_loss: 0.5494 - val_accuracy: 0.8592
# Epoch 41/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5601 - accuracy: 0.8376 - val_loss: 0.5468 - val_accuracy: 0.8380
# Epoch 42/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5530 - accuracy: 0.8445 - val_loss: 0.5480 - val_accuracy: 0.8451
# Epoch 43/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5412 - accuracy: 0.8498 - val_loss: 0.6209 - val_accuracy: 0.8169
# Epoch 44/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5309 - accuracy: 0.8473 - val_loss: 0.5801 - val_accuracy: 0.8169
# Epoch 45/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5164 - accuracy: 0.8550 - val_loss: 0.6364 - val_accuracy: 0.7746
# Epoch 46/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5046 - accuracy: 0.8614 - val_loss: 0.5460 - val_accuracy: 0.8521
# Epoch 47/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5054 - accuracy: 0.8602 - val_loss: 0.5179 - val_accuracy: 0.8521
# Epoch 48/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4807 - accuracy: 0.8709 - val_loss: 0.4996 - val_accuracy: 0.8662
# Epoch 49/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4779 - accuracy: 0.8699 - val_loss: 0.4953 - val_accuracy: 0.8803
# Epoch 50/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4650 - accuracy: 0.8690 - val_loss: 0.4901 - val_accuracy: 0.8732
# Epoch 51/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4517 - accuracy: 0.8770 - val_loss: 0.4927 - val_accuracy: 0.8662
# Epoch 52/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4465 - accuracy: 0.8797 - val_loss: 0.4961 - val_accuracy: 0.8732
# Epoch 53/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4357 - accuracy: 0.8828 - val_loss: 0.5234 - val_accuracy: 0.8239
# Epoch 54/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4236 - accuracy: 0.8865 - val_loss: 0.4918 - val_accuracy: 0.8521
# Epoch 55/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4215 - accuracy: 0.8879 - val_loss: 0.5317 - val_accuracy: 0.8380
# Epoch 56/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4106 - accuracy: 0.8919 - val_loss: 0.4991 - val_accuracy: 0.8592
# Epoch 57/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4049 - accuracy: 0.8954 - val_loss: 0.5039 - val_accuracy: 0.8732
# Epoch 58/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4019 - accuracy: 0.8979 - val_loss: 0.4903 - val_accuracy: 0.8873
# Epoch 59/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3882 - accuracy: 0.9018 - val_loss: 0.5191 - val_accuracy: 0.8521
# Epoch 60/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3877 - accuracy: 0.9008 - val_loss: 0.4991 - val_accuracy: 0.8592
# Epoch 61/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3811 - accuracy: 0.9009 - val_loss: 0.5013 - val_accuracy: 0.8662
# Epoch 62/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3702 - accuracy: 0.9054 - val_loss: 0.4875 - val_accuracy: 0.8732
# Epoch 63/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3689 - accuracy: 0.9074 - val_loss: 0.4771 - val_accuracy: 0.8732
# Epoch 64/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3662 - accuracy: 0.9073 - val_loss: 0.4723 - val_accuracy: 0.8732
# Epoch 65/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3522 - accuracy: 0.9146 - val_loss: 0.5022 - val_accuracy: 0.8592
# Epoch 66/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3483 - accuracy: 0.9158 - val_loss: 0.4676 - val_accuracy: 0.8873
# Epoch 67/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3441 - accuracy: 0.9157 - val_loss: 0.4806 - val_accuracy: 0.8451
# Epoch 68/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3456 - accuracy: 0.9163 - val_loss: 0.4537 - val_accuracy: 0.8732
# Epoch 69/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3349 - accuracy: 0.9189 - val_loss: 0.4917 - val_accuracy: 0.8662
# Epoch 70/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3338 - accuracy: 0.9200 - val_loss: 0.4660 - val_accuracy: 0.8873
# Epoch 71/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3272 - accuracy: 0.9212 - val_loss: 0.4877 - val_accuracy: 0.8521
# Epoch 72/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3172 - accuracy: 0.9248 - val_loss: 0.4760 - val_accuracy: 0.8451
# Epoch 73/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3174 - accuracy: 0.9277 - val_loss: 0.5158 - val_accuracy: 0.8380
# Epoch 74/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3132 - accuracy: 0.9272 - val_loss: 0.4843 - val_accuracy: 0.8592
# Epoch 75/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3055 - accuracy: 0.9288 - val_loss: 0.4989 - val_accuracy: 0.8521
# Epoch 76/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3048 - accuracy: 0.9286 - val_loss: 0.4608 - val_accuracy: 0.8873
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3007 - accuracy: 0.9321 - val_loss: 0.4826 - val_accuracy: 0.8732
# Epoch 78/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2947 - accuracy: 0.9324 - val_loss: 0.4710 - val_accuracy: 0.8662
# Epoch 79/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2931 - accuracy: 0.9346 - val_loss: 0.4754 - val_accuracy: 0.8803
# Epoch 80/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2815 - accuracy: 0.9389 - val_loss: 0.5059 - val_accuracy: 0.8732
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 2ms/step
# Precision: 0.8516
# Recall: 0.8531
# F1 Score: 0.8516
# Fold 3, Accuracy: 0.8589, Test Loss: 0.4980, Test Accuracy: 0.8589
# ========================================
# ========================================
# Fold: 4
# Selecting the augmented data
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 7s 7ms/step - loss: 2.4819 - accuracy: 0.3537 - val_loss: 1.7035 - val_accuracy: 0.4507
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.9062 - accuracy: 0.3734 - val_loss: 1.6065 - val_accuracy: 0.4648
# Epoch 3/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.7302 - accuracy: 0.3961 - val_loss: 1.5655 - val_accuracy: 0.5423
# Epoch 4/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6722 - accuracy: 0.3961 - val_loss: 1.5331 - val_accuracy: 0.5986
# Epoch 5/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6336 - accuracy: 0.4127 - val_loss: 1.5049 - val_accuracy: 0.5704
# Epoch 6/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6097 - accuracy: 0.4241 - val_loss: 1.4873 - val_accuracy: 0.5352
# Epoch 7/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5820 - accuracy: 0.4381 - val_loss: 1.4661 - val_accuracy: 0.5282
# Epoch 8/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.5575 - accuracy: 0.4451 - val_loss: 1.4361 - val_accuracy: 0.5282
# Epoch 9/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5266 - accuracy: 0.4606 - val_loss: 1.4091 - val_accuracy: 0.5423
# Epoch 10/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5048 - accuracy: 0.4694 - val_loss: 1.4055 - val_accuracy: 0.5282
# Epoch 11/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4731 - accuracy: 0.4851 - val_loss: 1.3685 - val_accuracy: 0.5704
# Epoch 12/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4329 - accuracy: 0.5124 - val_loss: 1.3334 - val_accuracy: 0.5915
# Epoch 13/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3973 - accuracy: 0.5291 - val_loss: 1.3032 - val_accuracy: 0.5634
# Epoch 14/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3507 - accuracy: 0.5566 - val_loss: 1.2637 - val_accuracy: 0.5775
# Epoch 15/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3136 - accuracy: 0.5728 - val_loss: 1.2006 - val_accuracy: 0.5915
# Epoch 16/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2625 - accuracy: 0.5961 - val_loss: 1.1812 - val_accuracy: 0.5845
# Epoch 17/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2193 - accuracy: 0.6183 - val_loss: 1.1411 - val_accuracy: 0.5845
# Epoch 18/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1828 - accuracy: 0.6325 - val_loss: 1.0966 - val_accuracy: 0.6197
# Epoch 19/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1405 - accuracy: 0.6484 - val_loss: 1.1209 - val_accuracy: 0.6127
# Epoch 20/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0950 - accuracy: 0.6728 - val_loss: 0.9887 - val_accuracy: 0.6901
# Epoch 21/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0563 - accuracy: 0.6819 - val_loss: 0.9893 - val_accuracy: 0.7254
# Epoch 22/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0073 - accuracy: 0.7081 - val_loss: 0.9207 - val_accuracy: 0.7324
# Epoch 23/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9644 - accuracy: 0.7219 - val_loss: 0.8660 - val_accuracy: 0.7606
# Epoch 24/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9222 - accuracy: 0.7354 - val_loss: 0.8669 - val_accuracy: 0.7535
# Epoch 25/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8848 - accuracy: 0.7514 - val_loss: 0.7660 - val_accuracy: 0.7887
# Epoch 26/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8458 - accuracy: 0.7664 - val_loss: 0.7771 - val_accuracy: 0.7887
# Epoch 27/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8126 - accuracy: 0.7754 - val_loss: 0.7376 - val_accuracy: 0.8099
# Epoch 28/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7897 - accuracy: 0.7823 - val_loss: 0.7206 - val_accuracy: 0.8169
# Epoch 29/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7609 - accuracy: 0.7927 - val_loss: 0.7139 - val_accuracy: 0.8028
# Epoch 30/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7313 - accuracy: 0.7976 - val_loss: 0.6466 - val_accuracy: 0.8310
# Epoch 31/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7152 - accuracy: 0.7995 - val_loss: 0.7309 - val_accuracy: 0.7887
# Epoch 32/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.6982 - accuracy: 0.8082 - val_loss: 0.6538 - val_accuracy: 0.8169
# Epoch 33/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6843 - accuracy: 0.8118 - val_loss: 0.6173 - val_accuracy: 0.8380
# Epoch 34/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6639 - accuracy: 0.8166 - val_loss: 0.6951 - val_accuracy: 0.7817
# Epoch 35/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6430 - accuracy: 0.8269 - val_loss: 0.6525 - val_accuracy: 0.8099
# Epoch 36/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6307 - accuracy: 0.8286 - val_loss: 0.5766 - val_accuracy: 0.8451
# Epoch 37/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6137 - accuracy: 0.8326 - val_loss: 0.5746 - val_accuracy: 0.8451
# Epoch 38/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5988 - accuracy: 0.8371 - val_loss: 0.5580 - val_accuracy: 0.8451
# Epoch 39/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5820 - accuracy: 0.8465 - val_loss: 0.5408 - val_accuracy: 0.8451
# Epoch 40/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5789 - accuracy: 0.8458 - val_loss: 0.6188 - val_accuracy: 0.8028
# Epoch 41/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5616 - accuracy: 0.8465 - val_loss: 0.5477 - val_accuracy: 0.8521
# Epoch 42/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5489 - accuracy: 0.8562 - val_loss: 0.5264 - val_accuracy: 0.8592
# Epoch 43/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5391 - accuracy: 0.8551 - val_loss: 0.5209 - val_accuracy: 0.8944
# Epoch 44/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5242 - accuracy: 0.8641 - val_loss: 0.5188 - val_accuracy: 0.8592
# Epoch 45/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5137 - accuracy: 0.8636 - val_loss: 0.6866 - val_accuracy: 0.8028
# Epoch 46/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5064 - accuracy: 0.8691 - val_loss: 0.5016 - val_accuracy: 0.8732
# Epoch 47/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4897 - accuracy: 0.8703 - val_loss: 0.5435 - val_accuracy: 0.8380
# Epoch 48/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4782 - accuracy: 0.8753 - val_loss: 0.5080 - val_accuracy: 0.8662
# Epoch 49/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4743 - accuracy: 0.8789 - val_loss: 0.4855 - val_accuracy: 0.8732
# Epoch 50/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4607 - accuracy: 0.8828 - val_loss: 0.4947 - val_accuracy: 0.8732
# Epoch 51/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4530 - accuracy: 0.8834 - val_loss: 0.4859 - val_accuracy: 0.8662
# Epoch 52/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4455 - accuracy: 0.8877 - val_loss: 0.4814 - val_accuracy: 0.9014
# Epoch 53/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4337 - accuracy: 0.8933 - val_loss: 0.4776 - val_accuracy: 0.8944
# Epoch 54/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4307 - accuracy: 0.8914 - val_loss: 0.4935 - val_accuracy: 0.8803
# Epoch 55/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4256 - accuracy: 0.8927 - val_loss: 0.4859 - val_accuracy: 0.8592
# Epoch 56/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4122 - accuracy: 0.8986 - val_loss: 0.5648 - val_accuracy: 0.8169
# Epoch 57/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4049 - accuracy: 0.9002 - val_loss: 0.4816 - val_accuracy: 0.8662
# Epoch 58/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3940 - accuracy: 0.9015 - val_loss: 0.4668 - val_accuracy: 0.8873
# Epoch 59/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3917 - accuracy: 0.9033 - val_loss: 0.4947 - val_accuracy: 0.8732
# Epoch 60/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3865 - accuracy: 0.9061 - val_loss: 0.4892 - val_accuracy: 0.8873
# Epoch 61/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3768 - accuracy: 0.9096 - val_loss: 0.5124 - val_accuracy: 0.8803
# Epoch 62/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3687 - accuracy: 0.9137 - val_loss: 0.4989 - val_accuracy: 0.8662
# Epoch 63/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3738 - accuracy: 0.9120 - val_loss: 0.5629 - val_accuracy: 0.8169
# Epoch 64/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3656 - accuracy: 0.9122 - val_loss: 0.5184 - val_accuracy: 0.8380
# Epoch 65/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3540 - accuracy: 0.9170 - val_loss: 0.4741 - val_accuracy: 0.8944
# Epoch 66/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3442 - accuracy: 0.9229 - val_loss: 0.4836 - val_accuracy: 0.8732
# Epoch 67/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3520 - accuracy: 0.9166 - val_loss: 0.5998 - val_accuracy: 0.7958
# Epoch 68/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3322 - accuracy: 0.9231 - val_loss: 0.5170 - val_accuracy: 0.8803
# Epoch 69/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3352 - accuracy: 0.9225 - val_loss: 0.4958 - val_accuracy: 0.8592
# Epoch 70/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3317 - accuracy: 0.9236 - val_loss: 0.4582 - val_accuracy: 0.8944
# Epoch 71/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3255 - accuracy: 0.9272 - val_loss: 0.4959 - val_accuracy: 0.8732
# Epoch 72/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3350 - accuracy: 0.9210 - val_loss: 0.5444 - val_accuracy: 0.8521
# Epoch 73/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3184 - accuracy: 0.9239 - val_loss: 0.4711 - val_accuracy: 0.9014
# Epoch 74/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3220 - accuracy: 0.9246 - val_loss: 0.4669 - val_accuracy: 0.8803
# Epoch 75/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3095 - accuracy: 0.9292 - val_loss: 0.5066 - val_accuracy: 0.8451
# Epoch 76/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3049 - accuracy: 0.9324 - val_loss: 0.4882 - val_accuracy: 0.9014
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2966 - accuracy: 0.9341 - val_loss: 0.4820 - val_accuracy: 0.8873
# Epoch 78/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3044 - accuracy: 0.9317 - val_loss: 0.5081 - val_accuracy: 0.8944
# Epoch 79/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2923 - accuracy: 0.9356 - val_loss: 0.4915 - val_accuracy: 0.9085
# Epoch 80/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2879 - accuracy: 0.9382 - val_loss: 0.4800 - val_accuracy: 0.9014
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 2ms/step
# Precision: 0.8674
# Recall: 0.8649
# F1 Score: 0.8643
# Fold 4, Accuracy: 0.8739, Test Loss: 0.4544, Test Accuracy: 0.8739
# ========================================
# ========================================
# Fold: 5
# Selecting the augmented data
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 7s 7ms/step - loss: 2.5381 - accuracy: 0.3585 - val_loss: 1.5140 - val_accuracy: 0.5282
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.8728 - accuracy: 0.3836 - val_loss: 1.5099 - val_accuracy: 0.5352
# Epoch 3/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.7269 - accuracy: 0.3840 - val_loss: 1.5112 - val_accuracy: 0.5211
# Epoch 4/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6675 - accuracy: 0.3986 - val_loss: 1.5102 - val_accuracy: 0.5352
# Epoch 5/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6172 - accuracy: 0.4201 - val_loss: 1.5130 - val_accuracy: 0.5070
# Epoch 6/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5938 - accuracy: 0.4362 - val_loss: 1.4801 - val_accuracy: 0.5423
# Epoch 7/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5620 - accuracy: 0.4577 - val_loss: 1.4899 - val_accuracy: 0.5352
# Epoch 8/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5158 - accuracy: 0.4864 - val_loss: 1.3591 - val_accuracy: 0.5915
# Epoch 9/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4390 - accuracy: 0.5393 - val_loss: 1.3986 - val_accuracy: 0.6338
# Epoch 10/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3570 - accuracy: 0.5701 - val_loss: 1.1858 - val_accuracy: 0.6408
# Epoch 11/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2988 - accuracy: 0.5848 - val_loss: 1.1376 - val_accuracy: 0.6761
# Epoch 12/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2634 - accuracy: 0.5996 - val_loss: 1.1000 - val_accuracy: 0.6901
# Epoch 13/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2161 - accuracy: 0.6135 - val_loss: 1.2153 - val_accuracy: 0.6197
# Epoch 14/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1781 - accuracy: 0.6252 - val_loss: 1.0949 - val_accuracy: 0.7113
# Epoch 15/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1471 - accuracy: 0.6465 - val_loss: 1.3569 - val_accuracy: 0.5775
# Epoch 16/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1031 - accuracy: 0.6584 - val_loss: 1.0006 - val_accuracy: 0.7113
# Epoch 17/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0659 - accuracy: 0.6779 - val_loss: 0.9485 - val_accuracy: 0.7183
# Epoch 18/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0350 - accuracy: 0.6887 - val_loss: 1.3765 - val_accuracy: 0.5775
# Epoch 19/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9938 - accuracy: 0.7061 - val_loss: 0.9419 - val_accuracy: 0.7183
# Epoch 20/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9496 - accuracy: 0.7288 - val_loss: 1.2631 - val_accuracy: 0.6408
# Epoch 21/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9305 - accuracy: 0.7260 - val_loss: 0.8928 - val_accuracy: 0.7394
# Epoch 22/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8986 - accuracy: 0.7366 - val_loss: 0.8287 - val_accuracy: 0.7958
# Epoch 23/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8789 - accuracy: 0.7511 - val_loss: 0.7969 - val_accuracy: 0.7746
# Epoch 24/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8442 - accuracy: 0.7622 - val_loss: 0.7623 - val_accuracy: 0.7817
# Epoch 25/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8207 - accuracy: 0.7734 - val_loss: 0.7453 - val_accuracy: 0.8310
# Epoch 26/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7966 - accuracy: 0.7750 - val_loss: 0.7155 - val_accuracy: 0.7817
# Epoch 27/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7666 - accuracy: 0.7856 - val_loss: 0.8070 - val_accuracy: 0.7465
# Epoch 28/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7526 - accuracy: 0.7907 - val_loss: 0.7829 - val_accuracy: 0.7746
# Epoch 29/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7407 - accuracy: 0.7901 - val_loss: 0.6753 - val_accuracy: 0.8099
# Epoch 30/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7161 - accuracy: 0.7970 - val_loss: 0.7906 - val_accuracy: 0.7606
# Epoch 31/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6929 - accuracy: 0.8050 - val_loss: 0.6717 - val_accuracy: 0.8099
# Epoch 32/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6844 - accuracy: 0.8124 - val_loss: 0.6512 - val_accuracy: 0.8310
# Epoch 33/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6709 - accuracy: 0.8064 - val_loss: 0.6201 - val_accuracy: 0.8310
# Epoch 34/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6524 - accuracy: 0.8159 - val_loss: 0.6742 - val_accuracy: 0.7887
# Epoch 35/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6423 - accuracy: 0.8178 - val_loss: 0.6326 - val_accuracy: 0.8239
# Epoch 36/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6165 - accuracy: 0.8259 - val_loss: 0.5941 - val_accuracy: 0.8380
# Epoch 37/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6149 - accuracy: 0.8274 - val_loss: 0.5944 - val_accuracy: 0.8521
# Epoch 38/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5956 - accuracy: 0.8329 - val_loss: 0.5984 - val_accuracy: 0.8239
# Epoch 39/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5832 - accuracy: 0.8383 - val_loss: 0.5569 - val_accuracy: 0.8380
# Epoch 40/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5726 - accuracy: 0.8396 - val_loss: 0.6755 - val_accuracy: 0.7887
# Epoch 41/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5547 - accuracy: 0.8440 - val_loss: 0.5479 - val_accuracy: 0.8451
# Epoch 42/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5616 - accuracy: 0.8381 - val_loss: 0.6550 - val_accuracy: 0.7887
# Epoch 43/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5371 - accuracy: 0.8506 - val_loss: 0.5436 - val_accuracy: 0.8451
# Epoch 44/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5250 - accuracy: 0.8547 - val_loss: 0.5224 - val_accuracy: 0.8592
# Epoch 45/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5119 - accuracy: 0.8567 - val_loss: 0.5133 - val_accuracy: 0.8521
# Epoch 46/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.5032 - accuracy: 0.8616 - val_loss: 0.5298 - val_accuracy: 0.8521
# Epoch 47/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4937 - accuracy: 0.8633 - val_loss: 0.5054 - val_accuracy: 0.8803
# Epoch 48/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4780 - accuracy: 0.8686 - val_loss: 0.5115 - val_accuracy: 0.8732
# Epoch 49/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4773 - accuracy: 0.8710 - val_loss: 0.5158 - val_accuracy: 0.8662
# Epoch 50/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4716 - accuracy: 0.8730 - val_loss: 0.5389 - val_accuracy: 0.8592
# Epoch 51/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4624 - accuracy: 0.8773 - val_loss: 0.5030 - val_accuracy: 0.8662
# Epoch 52/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4474 - accuracy: 0.8799 - val_loss: 0.5328 - val_accuracy: 0.8803
# Epoch 53/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4406 - accuracy: 0.8814 - val_loss: 0.5028 - val_accuracy: 0.8803
# Epoch 54/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4305 - accuracy: 0.8866 - val_loss: 0.5061 - val_accuracy: 0.8662
# Epoch 55/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4232 - accuracy: 0.8896 - val_loss: 0.4890 - val_accuracy: 0.8803
# Epoch 56/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4261 - accuracy: 0.8904 - val_loss: 0.4808 - val_accuracy: 0.8873
# Epoch 57/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4054 - accuracy: 0.8954 - val_loss: 0.5221 - val_accuracy: 0.8380
# Epoch 58/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4091 - accuracy: 0.8950 - val_loss: 0.4723 - val_accuracy: 0.8944
# Epoch 59/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4019 - accuracy: 0.8980 - val_loss: 0.4614 - val_accuracy: 0.9014
# Epoch 60/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3894 - accuracy: 0.8996 - val_loss: 0.4895 - val_accuracy: 0.8732
# Epoch 61/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3875 - accuracy: 0.9021 - val_loss: 0.4708 - val_accuracy: 0.8803
# Epoch 62/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3754 - accuracy: 0.9064 - val_loss: 0.4861 - val_accuracy: 0.8732
# Epoch 63/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3600 - accuracy: 0.9097 - val_loss: 0.4889 - val_accuracy: 0.8732
# Epoch 64/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3591 - accuracy: 0.9137 - val_loss: 0.4356 - val_accuracy: 0.9085
# Epoch 65/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3565 - accuracy: 0.9129 - val_loss: 0.4415 - val_accuracy: 0.9014
# Epoch 66/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3500 - accuracy: 0.9158 - val_loss: 0.4400 - val_accuracy: 0.8873
# Epoch 67/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3452 - accuracy: 0.9166 - val_loss: 0.4746 - val_accuracy: 0.8662
# Epoch 68/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3387 - accuracy: 0.9165 - val_loss: 0.4187 - val_accuracy: 0.8873
# Epoch 69/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3364 - accuracy: 0.9215 - val_loss: 0.4483 - val_accuracy: 0.8732
# Epoch 70/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3334 - accuracy: 0.9206 - val_loss: 0.4136 - val_accuracy: 0.8944
# Epoch 71/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3192 - accuracy: 0.9243 - val_loss: 0.4320 - val_accuracy: 0.9085
# Epoch 72/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3248 - accuracy: 0.9212 - val_loss: 0.4321 - val_accuracy: 0.8944
# Epoch 73/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3181 - accuracy: 0.9264 - val_loss: 0.4346 - val_accuracy: 0.8803
# Epoch 74/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3175 - accuracy: 0.9256 - val_loss: 0.4701 - val_accuracy: 0.8732
# Epoch 75/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3118 - accuracy: 0.9243 - val_loss: 0.4735 - val_accuracy: 0.8873
# Epoch 76/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3060 - accuracy: 0.9292 - val_loss: 0.4483 - val_accuracy: 0.8944
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3074 - accuracy: 0.9301 - val_loss: 0.4796 - val_accuracy: 0.8732
# Epoch 78/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2951 - accuracy: 0.9336 - val_loss: 0.4129 - val_accuracy: 0.8873
# Epoch 79/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2909 - accuracy: 0.9367 - val_loss: 0.4440 - val_accuracy: 0.8732
# Epoch 80/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.2866 - accuracy: 0.9356 - val_loss: 0.4290 - val_accuracy: 0.8803
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 2ms/step
# Precision: 0.8713
# Recall: 0.8687
# F1 Score: 0.8698
# Fold 5, Accuracy: 0.8799, Test Loss: 0.4070, Test Accuracy: 0.8799
# ========================================
# test losses: [0.46561989188194275, 0.4645007252693176, 0.49802571535110474, 0.4543772339820862, 0.4069834351539612]
# test accuracy: [0.8618618845939636, 0.8558558821678162, 0.8588588833808899, 0.8738738894462585, 0.879879891872406]
# ****************************************
# Mean training loss over 5-fold cross-validation: 0.7429
# Mean training accuracy over 5-fold cross-validation: 0.7793
# Mean validation loss over 5-fold cross-validation: 0.7562
# Mean validation accuracy over 5-fold cross-validation: 0.7788
# ****************************************
# Mean accuracy over stratified 5-fold cross-validation: 0.8661
# Mean test loss over stratified 5-fold cross-validation: 0.4579
# Mean test accuracy over stratified 5-fold cross-validation: 0.8661
# ****************************************
# Standard deviation of training loss over 5-fold cross-validation: 0.4671
# Standard deviation of training accuracy over 5-fold cross-validation: 0.1645
# Standard deviation of validation loss over 5-fold cross-validation: 0.3492
# Standard deviation of validation accuracy over 5-fold cross-validation: 0.1183
# ****************************************
# Standard deviation of accuracy over stratified 5-fold cross-validation: 0.0092
# Standard deviation of test loss over stratified 5-fold cross-validation: 0.0294
# Standard deviation of test accuracy over stratified 5-fold cross-validation: 0.0092
# ****************************************
# Mean precision over stratified 5-fold cross-validation: 0.8577
# Standard deviation of precision over stratified 5-fold cross-validation: 0.0097
# Mean recall over stratified 5-fold cross-validation: 0.8548
# Standard deviation of recall over stratified 5-fold cross-validation: 0.0107
# Mean F1 score over stratified 5-fold cross-validation: 0.8549
# Standard deviation of F1 score over stratified 5-fold cross-validation: 0.0107
# Training time: 1314.17 seconds
# Training and evaluating the model...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 23
#      21 # Start the timer
#      22 start_time = time.time()
# ---> 23 model_history = model.fit(X_train, y_train, batch_size=DL_BATCH_SIZE,
#      24                           epochs=DL_EPOCH, validation_data=(X_val, y_val), shuffle=True, callbacks=callbacks)
#      25 # End the timer
#      26 end_time = time.time()
#
# NameError: name 'model' is not defined
