# %%
# %cd /kaggle/input/chemcancer-v2/src/
# %mkdir /kaggle/working/Deep_Learning_metrics/
# %mkdir /kaggle/working/During_train/
# %mkdir /kaggle/working/CV_CNN_models
# %mkdir /kaggle/working/CV_CNN_results
# %mkdir /kaggle/working/CV_CNN_fold_data
# %mkdir /kaggle/working/CV_CNN_cm
# Out:
# /kaggle/input/chemcancer-v2/src
# mkdir: cannot create directory '/kaggle/working/Deep_Learning_metrics/': File exists
# mkdir: cannot create directory '/kaggle/working/During_train/': File exists
# mkdir: cannot create directory '/kaggle/working/CV_CNN_models': File exists
# mkdir: cannot create directory '/kaggle/working/CV_CNN_results': File exists
# mkdir: cannot create directory '/kaggle/working/CV_CNN_fold_data': File exists
# mkdir: cannot create directory '/kaggle/working/CV_CNN_cm': File exists

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tensorflow.keras.optimizers import Adam
from data import *
from machine_learning_models import *
from deep_learning_models import *
from vision_transformer import *
from utils_dl_model import *
from utils_ml_model import print_ml_results
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint

# %%
# Set the seed value.
SEED = 7
np.random.seed(SEED)

# Deep Learning parameters
DL_EPOCH = 800
DL_BATCH_SIZE = 32
DL_CNN_VERSION = 3
DL_TRANSFORMER_VISION_VERSION = 14
DL_CV_FOLD = 5

DO_DL = True
CV_DL = True
OPT_DL = False

DO_CNN = True
DO_TRANSFORMER_VISION = False
DO_ML = False

# Percentage of test set out of the dataset.
TEST_SET = 0.2

# Percentage of validation set out of the training dataset.
VAL_SET = 0.2

# Folder path associated with deep learning models
dl_models_folder = "../Deep_Learning_models/"
dl_metrics_folder = "../Deep_Learning_metrics/"
dl_weights_folder = "../Deep_Learning_weights/"
dl_cv_models_folder = "../Deep_Learning_CV/"
dl_cv_results_folder = "../Deep_Learning_CV_results/"

# Folder path associated with machine learning models
ml_models_folder = "../Machine_Learning_models/"
ml_models_results_folder = "../Machine_Learning_models_results/"

# Model names (Saved in h5 format)
cnn_model_name = f"cnn_v{DL_CNN_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"
transformer_vis_model_name = f"transformer_vision_v{DL_TRANSFORMER_VISION_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"

# Metric filenames
cnn_metrics_filename = f"metrics_{cnn_model_name}.json"
transformer_vis_metrics_filename = f"metrics_{transformer_vis_model_name}.json"

# Weight filenames
cnn_weights_filename = f"weights_{cnn_model_name}.json"
transformer_vis_weights_filename = f"weights_{transformer_vis_model_name}.json"


# Deep Learning models path
if DO_CNN:
    dl_model_path = os.path.join(
        dl_models_folder, cnn_model_name)
elif DO_TRANSFORMER_VISION:
    dl_model_path = os.path.join(
        dl_models_folder, transformer_vis_model_name)


# Deep Learning metrics path
if DO_CNN:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, cnn_metrics_filename)
elif DO_TRANSFORMER_VISION:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, transformer_vis_metrics_filename)


# Deep Learning weights path
if DO_CNN:
    dl_weights_path = os.path.join(
        dl_weights_folder, cnn_weights_filename)

elif DO_TRANSFORMER_VISION:
    dl_weights_path = os.path.join(
        dl_weights_folder, transformer_vis_weights_filename)

# %% [markdown]
# # Tested 0.8 Test accuracy with low evidence of overfitting.

# %%
# from tensorflow.keras.layers import AveragePooling1D

# def cnn_model_3(input_shape, num_classes):
#     model = Sequential()

#     # Layer C1: Convolutional layer with 6 filters, each of size 5.
#     model.add(Conv1D(6, kernel_size=5, strides=1, activation='relu', input_shape=input_shape, padding="same"))

#     # Layer S2: Subsampling/Average Pooling layer with pool size 2 and stride 2
#     model.add(AveragePooling1D(pool_size=2, strides=2, padding='valid'))

#     # Layer C3: Convolutional layer with 16 filters, each of size 5.
#     model.add(Conv1D(16, kernel_size=5, strides=1, activation='relu', padding='valid'))

#     # Layer S4: Subsampling/Average Pooling layer with pool size 2 and stride 2
#     model.add(AveragePooling1D(pool_size=2, strides=2, padding='valid'))
    
#     # Layer C3: Convolutional layer with 16 filters, each of size 5.
#     model.add(Conv1D(32, kernel_size=5, strides=1, activation='relu', padding='valid'))
    
#     # Layer S4: Subsampling/Average Pooling layer with pool size 2 and stride 2
#     model.add(AveragePooling1D(pool_size=2, strides=2, padding='valid'))
    
#     model.add(Dropout(0.5))

#     # Flattening the output from previous layer before feeding it into the fully connected layers
#     model.add(Flatten())

#     # Layer F5: Fully connected layer with 120 units
#     model.add(Dense(120, activation='relu'))

#     # Layer F6: Fully connected layer with 84 units
#     model.add(Dense(64, activation='relu'))
    
#     # Layer F6: Fully connected layer with 84 units
#     model.add(Dense(32, activation='relu'))
    
#     model.add(Dropout(0.5))

#     # Output layer with 'num_classes' units
#     model.add(Dense(num_classes, activation='softmax'))
    
#     model.compile(optimizer=Adam(learning_rate = 1e-4),
#               loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#     return model

# %%
def cnn_model_3(input_shape, num_classes):
    model = Sequential()
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.5))
    
    model.add(Flatten())
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate = 1e-4),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
       

    return model

# %%
import pickle

def perform_cnn_cv(X, y, learning_rate, dropout_rate, l2_regularizer, 
                             n_splits=5, epochs=100, batch_size=32, cnn_version = 1, val_set = 0.2,
                             do_opt = False,models_folder = "models", results_folder = "results"):
    
    if not os.path.exists(models_folder):
        os.makedirs(models_folder)

    if not os.path.exists(results_folder):
        os.makedirs(results_folder)
        
    # Initialize variables for tracking the best model
    best_val_accuracy = 0
    best_model_filepath = ""
    
    
    accuracies = []
    test_losses = []
    test_accuracies = []
    
    # Initialize lists to store precision, recall, and F1 scores
    precisions = []
    recalls = []
    f1_scores = []
    
    # Initialize lists to store losses and accuracies for each epoch
    mean_training_losses = []
    mean_training_accuracies = []
    mean_val_losses = []   
    mean_val_accuracies = []
    
    # Initialize lists to store losses and accuracies for each epoch
    all_training_losses = []
    all_training_accuracies = []
    all_val_losses = []   
    all_val_accuracies = []
    
    fold = 1
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)
    
    for train_index, test_index in skf.split(X, y):
        # Split the data into training and validation sets
        print("=" * 40)
        print(f"Fold: {fold}")
        print("Splitting the data")
        X_train_full, X_test = X[train_index], X[test_index]
        y_train_full, y_test = y[train_index], y[test_index]
        
        # Standardize the data
        print("Standardizing the data")
        X_train_full, X_test = standardize_data(X_train_full, X_test)
        
        # Reshape the data
        print("Reshaping the data for deep learning models")
        X_train_full, X_test = reshape_data(X_train_full, X_test)
        
        # Input shape and number of classes for the model
        input_shape = (X_train_full.shape[1], 1)
        num_classes = len(np.unique(y))
        
        X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size = 0.2, random_state = seed_value, stratify = y_train_full)
        
        try:
            if do_opt:
                model = cnn_model_3(input_shape, num_classes)
#                 model = cnn_model_3_opt(input_shape, num_classes, learning_rate, dropout_rate, l2_regularizer)
            else:
                model = cnn_model_3(input_shape, num_classes)
            if model is not None:
                print("Building the model 3 with the following hyperparameters:")
                print(f"Learning rate: {learning_rate}")
                print(f"Dropout rate: {dropout_rate}") 
                print(f"L2 Regularizer: {l2_regularizer}")
                print(f"Number of epochs: {epochs}")
                print(f"Batch size: {batch_size}")
                # model.summary()
            else:
                print("Failed to build the CNN model.")
        except Exception as e:
            print(f"Error while building the CNN model: {e}")
        
        print("Saving the data")
        fold_data = {

            'X_train': X_train,
            'X_val': X_val,
            'X_test': X_test,
            'y_train': y_train,
            'y_val': y_val,
            'y_test': y_test
        }

        with open(f"/kaggle/working/CV_CNN_fold_data/fold_{fold}_data.pkl", 'wb') as f:
            pickle.dump(fold_data, f)
        
        filepath = f'/kaggle/working/CV_CNN_models/temp_best_fold_{fold}.h5'
        # the ModelCheckpoint callback to save the best model of the current fold
        model_checkpoint_callback = ModelCheckpoint(
            filepath=os.path.join(filepath),
            save_best_only=True,
            monitor='val_accuracy',
            mode='max'
        )
        
        print("Training the model")
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val),
                           callbacks=[model_checkpoint_callback])
        
         # Check if this model is the best so far
        max_val_accuracy_this_fold = max(history.history['val_accuracy'])
        if max_val_accuracy_this_fold > best_val_accuracy:
            best_val_accuracy = max_val_accuracy_this_fold
            best_model_filepath = filepath
            
        if best_model_filepath:
            best_model = tf.keras.models.load_model(
                best_model_filepath
            )
        print(f"The best model was loaded and ready to be evaluated")
        
        y_pred = np.argmax(model.predict(X_test), axis=-1)
        accuracy = accuracy_score(y_test, y_pred)
        test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
        
            # Calculate precision, recall, and F1 score
        precision = precision_score(y_test, y_pred, average='macro')
        recall = recall_score(y_test, y_pred, average='macro')
        f1 = f1_score(y_test, y_pred, average='macro')

        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")

        # Append the scores to the lists
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        
        all_training_losses.extend(history.history['loss'])
        all_training_accuracies.extend(history.history['accuracy'])
        all_val_losses.extend(history.history['val_loss'])
        all_val_accuracies.extend(history.history['val_accuracy'])
        
        # Append the losses and accuracies for each epoch to the respective lists
        for epoch in range(epochs):
            if fold == 1:
                # For the first fold, initialize the lists with the first fold's values
                mean_training_losses.append(history.history['loss'][epoch])
                mean_training_accuracies.append(history.history['accuracy'][epoch])
                mean_val_losses.append(history.history['val_loss'][epoch])
                mean_val_accuracies.append(history.history['val_accuracy'][epoch])
            else:
                # For subsequent folds, add the fold's values to the running sum
                mean_training_losses[epoch] += history.history['loss'][epoch]
                mean_training_accuracies[epoch] += history.history['accuracy'][epoch]
                mean_val_losses[epoch] += history.history['val_loss'][epoch]
                mean_val_accuracies[epoch] += history.history['val_accuracy'][epoch]

        # Save the model
        if do_opt:
            model_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.h5"
        else:
            model_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.h5"
        model_filepath = os.path.join(models_folder, f"fold_{fold}_split_{n_splits}_{model_filename}")
        model.save(model_filepath)

        # Save the results as a JSON file
        if do_opt:
            results_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            results_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filepath = os.path.join(results_folder, f"fold_{fold}_split_{n_splits}_{results_filename}")

        results = {
            "fold": fold,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1_scores": f1_scores,
            "test_loss": test_loss,
            "test_accuracy": test_accuracy,
            "training_loss": history.history['loss'],
            "training_accuracy": history.history['accuracy'],
            "validation_loss": history.history['val_loss'],
            "validation_accuracy": history.history['val_accuracy'],
        }

        with open(results_filepath, "w") as results_file:
            json.dump(results, results_file, indent=4)
        
        # Append the results to the lists
        accuracies.append(accuracy)
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        
        print(f"Fold {fold}, Accuracy: {accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
        print("=" * 40)
        fold += 1

    # At the end, divide the sums by the number of folds to get the mean
    mean_training_losses = [loss / n_splits for loss in mean_training_losses]
    mean_training_accuracies = [acc / n_splits for acc in mean_training_accuracies]
    mean_val_losses = [loss / n_splits for loss in mean_val_losses]
    mean_val_accuracies = [acc / n_splits for acc in mean_val_accuracies]
    # Convert lists to numpy arrays for easier calculation of mean and standard deviation
    mean_accuracy = np.mean(accuracies)
    mean_test_loss = np.mean(test_losses)
    mean_test_accuracy = np.mean(test_accuracies)
    
    mean_training_loss = np.mean(all_training_losses)
    std_training_loss = np.std(all_training_losses)
    mean_training_accuracy = np.mean(all_training_accuracies)
    std_training_accuracy = np.std(all_training_accuracies)

    mean_val_loss = np.mean(all_val_losses)
    std_val_loss = np.std(all_val_losses)
    mean_val_accuracy = np.mean(all_val_accuracies)
    std_val_accuracy = np.std(all_val_accuracies)

    # Calculate standard deviations
    std_accuracy = np.std(accuracies)
    std_test_loss = np.std(test_losses)
    std_test_accuracy = np.std(test_accuracies)

    std_training_loss = np.std(mean_training_losses)
    std_training_accuracy = np.std(mean_training_accuracies)
    std_val_loss = np.std(mean_val_losses)
    std_val_accuracy = np.std(mean_val_accuracies)

    precisions = np.array(precisions)
    recalls = np.array(recalls)
    f1_scores = np.array(f1_scores)

      
    print(f"test losses: {test_losses}")
    print(f"test accuracy: {test_accuracies}")
    
    print("*" * 40)
    print(f"Mean training loss over {n_splits}-fold cross-validation: {mean_training_loss:.4f}")
    print(f"Mean training accuracy over {n_splits}-fold cross-validation: {mean_training_accuracy:.4f}")
    print(f"Mean validation loss over {n_splits}-fold cross-validation: {mean_val_loss:.4f}")
    print(f"Mean validation accuracy over {n_splits}-fold cross-validation: {mean_val_accuracy:.4f}")
    print("*" * 40)
    print(f"Mean accuracy over stratified {n_splits}-fold cross-validation: {mean_accuracy:.4f}")
    print(f"Mean test loss over stratified {n_splits}-fold cross-validation: {mean_test_loss:.4f}")
    print(f"Mean test accuracy over stratified {n_splits}-fold cross-validation: {mean_test_accuracy:.4f}")
    
    print("*" * 40)
    print(f"Standard deviation of training loss over {n_splits}-fold cross-validation: {std_training_loss:.4f}")
    print(f"Standard deviation of training accuracy over {n_splits}-fold cross-validation: {std_training_accuracy:.4f}")
    print(f"Standard deviation of validation loss over {n_splits}-fold cross-validation: {std_val_loss:.4f}")
    print(f"Standard deviation of validation accuracy over {n_splits}-fold cross-validation: {std_val_accuracy:.4f}")
        
    print("*" * 40)
    print(f"Standard deviation of accuracy over stratified {n_splits}-fold cross-validation: {std_accuracy:.4f}")
    print(f"Standard deviation of test loss over stratified {n_splits}-fold cross-validation: {std_test_loss:.4f}")
    print(f"Standard deviation of test accuracy over stratified {n_splits}-fold cross-validation: {std_test_accuracy:.4f}")
    print("*" * 40)
    
    # Calculate and print the mean and standard deviation of precision, recall, and F1 score
    print(f"Mean precision over stratified {n_splits}-fold cross-validation: {np.mean(precisions):.4f}")
    print(f"Standard deviation of precision over stratified {n_splits}-fold cross-validation: {np.std(precisions):.4f}")
    print(f"Mean recall over stratified {n_splits}-fold cross-validation: {np.mean(recalls):.4f}")
    print(f"Standard deviation of recall over stratified {n_splits}-fold cross-validation: {np.std(recalls):.4f}")
    print(f"Mean F1 score over stratified {n_splits}-fold cross-validation: {np.mean(f1_scores):.4f}")
    print(f"Standard deviation of F1 score over stratified {n_splits}-fold cross-validation: {np.std(f1_scores):.4f}")

    
# Define the directory where the JSON files are stored

    fig, axes = plt.subplots(2, n_splits, figsize=(20, 10))

    for fold in range(1, n_splits+1):
        # Load the JSON file for this fold
        if do_opt:
            cnn_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            cnn_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filename = f"fold_{fold}_split_{n_splits}_{cnn_filename}"
        
        results_filepath = os.path.join(results_folder, results_filename)
        
        with open(results_filepath, "r") as results_file:
            results = json.load(results_file)
        
        # Plot training and validation loss
        axes[0, fold-1].plot(results["training_loss"], label='Train')
        axes[0, fold-1].plot(results["validation_loss"], label='Validation')
        axes[0, fold-1].set_title(f'Fold {fold} Loss')
        axes[0, fold-1].set_xlabel('Epochs')
        axes[0, fold-1].set_ylabel('Loss')
        axes[0, fold-1].legend()

        # Plot training and validation accuracy
        axes[1, fold-1].plot(results["training_accuracy"], label='Train')
        axes[1, fold-1].plot(results["validation_accuracy"], label='Validation')
        axes[1, fold-1].set_title(f'Fold {fold} Accuracy')
        axes[1, fold-1].set_xlabel('Epochs')
        axes[1, fold-1].set_ylabel('Accuracy')
        axes[1, fold-1].legend()

    plt.tight_layout()
    plt.show()

    return mean_val_accuracies

# %%
# Original data
data_file = "../Data/HC05_HC07.csv"

# %%
# Load the data
print("Load the data")
data = load_data(data_file)
print(f"Data shape : {data.shape}")

# Extract the feature and target data
print("Extract the feature and target data")
X, y = extract_data(data)
print(f"X shaped: {X.shape}")
print(f"y shaped: {y.shape}")
# Out:
# Load the data
# Data shape : (2373, 274)
# Extract the feature and target data
# X shaped: (2373, 270)
# y shaped: (2373,)

# %%
if CV_DL:
    if DO_CNN:
        learning_rate = 0.0001
        dropout_rate = 0.4
        l2_regularizer = 0.0001
        # Start the timer
        start_time = time.time()
        perform_cnn_cv(X, y, learning_rate, dropout_rate, l2_regularizer,
                                n_splits=DL_CV_FOLD, epochs=DL_EPOCH, batch_size=DL_BATCH_SIZE, cnn_version=DL_CNN_VERSION,
                                do_opt=True, models_folder="/kaggle/working/CV_CNN_models", results_folder= "/kaggle/working/CV_CNN_results")
        # End the timer
        end_time = time.time()
        # Calculate the elapsed time
        elapsed_time = end_time - start_time
        # Print the elapsed time
        print("Training time: {:.2f} seconds".format(elapsed_time))
# Out:
# ========================================
# Fold: 1
# Splitting the data
# Standardizing the data
# Reshaping the data for deep learning models
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.4
# L2 Regularizer: 0.0001
# Number of epochs: 800
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/800
# 48/48 [==============================] - 4s 13ms/step - loss: 2.5933 - accuracy: 0.3617 - val_loss: 1.2638 - val_accuracy: 0.3816
# Epoch 2/800
# 19/48 [==========>...................] - ETA: 0s - loss: 2.1666 - accuracy: 0.3832
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 48/48 [==============================] - 0s 8ms/step - loss: 2.3270 - accuracy: 0.3689 - val_loss: 1.2583 - val_accuracy: 0.3868
# Epoch 3/800
# 48/48 [==============================] - 0s 8ms/step - loss: 2.2607 - accuracy: 0.3597 - val_loss: 1.2557 - val_accuracy: 0.4079
# Epoch 4/800
# 48/48 [==============================] - 0s 7ms/step - loss: 2.1683 - accuracy: 0.3485 - val_loss: 1.3099 - val_accuracy: 0.3868
# Epoch 5/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.9300 - accuracy: 0.3709 - val_loss: 1.3285 - val_accuracy: 0.3868
# Epoch 6/800
# 48/48 [==============================] - 0s 7ms/step - loss: 2.0410 - accuracy: 0.3663 - val_loss: 1.3785 - val_accuracy: 0.3868
# Epoch 7/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.8737 - accuracy: 0.3860 - val_loss: 1.4260 - val_accuracy: 0.3895
# Epoch 8/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.7923 - accuracy: 0.3801 - val_loss: 1.3776 - val_accuracy: 0.4316
# Epoch 9/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.7225 - accuracy: 0.4137 - val_loss: 1.4735 - val_accuracy: 0.4289
# Epoch 10/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.7237 - accuracy: 0.3722 - val_loss: 1.5229 - val_accuracy: 0.4263
# Epoch 11/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.6993 - accuracy: 0.3577 - val_loss: 1.4705 - val_accuracy: 0.4395
# Epoch 12/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.5750 - accuracy: 0.4058 - val_loss: 1.5667 - val_accuracy: 0.4342
# Epoch 13/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.5747 - accuracy: 0.3979 - val_loss: 1.5556 - val_accuracy: 0.4395
# Epoch 14/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.5847 - accuracy: 0.4111 - val_loss: 1.5154 - val_accuracy: 0.4368
# Epoch 15/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.5765 - accuracy: 0.3946 - val_loss: 1.5354 - val_accuracy: 0.4368
# Epoch 16/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.4641 - accuracy: 0.4203 - val_loss: 1.5197 - val_accuracy: 0.4474
# Epoch 17/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.4877 - accuracy: 0.4183 - val_loss: 1.5911 - val_accuracy: 0.4395
# Epoch 18/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.4369 - accuracy: 0.4170 - val_loss: 1.5830 - val_accuracy: 0.4447
# Epoch 19/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.4416 - accuracy: 0.4058 - val_loss: 1.5459 - val_accuracy: 0.4500
# Epoch 20/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3998 - accuracy: 0.4269 - val_loss: 1.6160 - val_accuracy: 0.4526
# Epoch 21/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.4054 - accuracy: 0.4223 - val_loss: 1.6082 - val_accuracy: 0.4605
# Epoch 22/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3747 - accuracy: 0.4447 - val_loss: 1.6234 - val_accuracy: 0.4605
# Epoch 23/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.4040 - accuracy: 0.4124 - val_loss: 1.6198 - val_accuracy: 0.4553
# Epoch 24/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.3689 - accuracy: 0.4203 - val_loss: 1.6626 - val_accuracy: 0.4605
# Epoch 25/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.3652 - accuracy: 0.4170 - val_loss: 1.6672 - val_accuracy: 0.4605
# Epoch 26/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3159 - accuracy: 0.4611 - val_loss: 1.7623 - val_accuracy: 0.4579
# Epoch 27/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.3325 - accuracy: 0.4348 - val_loss: 1.6828 - val_accuracy: 0.4553
# Epoch 28/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3104 - accuracy: 0.4493 - val_loss: 1.8165 - val_accuracy: 0.4447
# Epoch 29/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3283 - accuracy: 0.4289 - val_loss: 1.7997 - val_accuracy: 0.4421
# Epoch 30/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3296 - accuracy: 0.4374 - val_loss: 1.7942 - val_accuracy: 0.4526
# Epoch 31/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.3202 - accuracy: 0.4249 - val_loss: 1.8326 - val_accuracy: 0.4395
# Epoch 32/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2822 - accuracy: 0.4486 - val_loss: 1.8156 - val_accuracy: 0.4447
# Epoch 33/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2741 - accuracy: 0.4486 - val_loss: 1.8209 - val_accuracy: 0.4553
# Epoch 34/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2921 - accuracy: 0.4361 - val_loss: 1.8454 - val_accuracy: 0.4605
# Epoch 35/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2712 - accuracy: 0.4578 - val_loss: 1.8103 - val_accuracy: 0.4684
# Epoch 36/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2473 - accuracy: 0.4506 - val_loss: 1.7000 - val_accuracy: 0.4737
# Epoch 37/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2868 - accuracy: 0.4559 - val_loss: 1.8879 - val_accuracy: 0.4737
# Epoch 38/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2357 - accuracy: 0.4526 - val_loss: 1.9389 - val_accuracy: 0.4658
# Epoch 39/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2380 - accuracy: 0.4513 - val_loss: 1.8700 - val_accuracy: 0.4711
# Epoch 40/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2403 - accuracy: 0.4572 - val_loss: 1.9038 - val_accuracy: 0.4658
# Epoch 41/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2536 - accuracy: 0.4644 - val_loss: 1.8275 - val_accuracy: 0.4684
# Epoch 42/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2359 - accuracy: 0.4717 - val_loss: 1.8828 - val_accuracy: 0.4684
# Epoch 43/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2475 - accuracy: 0.4598 - val_loss: 2.0037 - val_accuracy: 0.4684
# Epoch 44/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2245 - accuracy: 0.4809 - val_loss: 1.9203 - val_accuracy: 0.4711
# Epoch 45/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2323 - accuracy: 0.4578 - val_loss: 1.8891 - val_accuracy: 0.4711
# Epoch 46/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2434 - accuracy: 0.4638 - val_loss: 1.8175 - val_accuracy: 0.4763
# Epoch 47/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2388 - accuracy: 0.4743 - val_loss: 1.9657 - val_accuracy: 0.4737
# Epoch 48/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2341 - accuracy: 0.4723 - val_loss: 1.9629 - val_accuracy: 0.4684
# Epoch 49/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2365 - accuracy: 0.4545 - val_loss: 1.9149 - val_accuracy: 0.4684
# Epoch 50/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2171 - accuracy: 0.4618 - val_loss: 1.9195 - val_accuracy: 0.4711
# Epoch 51/800
# 48/48 [==============================] - 0s 9ms/step - loss: 1.2223 - accuracy: 0.4697 - val_loss: 2.0204 - val_accuracy: 0.4737
# Epoch 52/800
# 48/48 [==============================] - 0s 9ms/step - loss: 1.1889 - accuracy: 0.4947 - val_loss: 1.9754 - val_accuracy: 0.4737
# Epoch 53/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2014 - accuracy: 0.4723 - val_loss: 2.0311 - val_accuracy: 0.4737
# Epoch 54/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2023 - accuracy: 0.4730 - val_loss: 2.0520 - val_accuracy: 0.4579
# Epoch 55/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2018 - accuracy: 0.4895 - val_loss: 1.8846 - val_accuracy: 0.4763
# Epoch 56/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2021 - accuracy: 0.4822 - val_loss: 2.0352 - val_accuracy: 0.4711
# Epoch 57/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.2200 - accuracy: 0.4736 - val_loss: 2.0150 - val_accuracy: 0.4789
# Epoch 58/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1854 - accuracy: 0.4809 - val_loss: 2.0292 - val_accuracy: 0.4711
# Epoch 59/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1778 - accuracy: 0.4875 - val_loss: 1.8062 - val_accuracy: 0.4816
# Epoch 60/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.2125 - accuracy: 0.4769 - val_loss: 1.8641 - val_accuracy: 0.4711
# Epoch 61/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1857 - accuracy: 0.4974 - val_loss: 1.9224 - val_accuracy: 0.4684
# Epoch 62/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1782 - accuracy: 0.4974 - val_loss: 2.1102 - val_accuracy: 0.4711
# Epoch 63/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1724 - accuracy: 0.4802 - val_loss: 1.9207 - val_accuracy: 0.4711
# Epoch 64/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1689 - accuracy: 0.4895 - val_loss: 2.0354 - val_accuracy: 0.4763
# Epoch 65/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1816 - accuracy: 0.5007 - val_loss: 1.9576 - val_accuracy: 0.4737
# Epoch 66/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1672 - accuracy: 0.4881 - val_loss: 1.9736 - val_accuracy: 0.4737
# Epoch 67/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1752 - accuracy: 0.4954 - val_loss: 1.8079 - val_accuracy: 0.4763
# Epoch 68/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1663 - accuracy: 0.4974 - val_loss: 1.9543 - val_accuracy: 0.4684
# Epoch 69/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1518 - accuracy: 0.5040 - val_loss: 1.8921 - val_accuracy: 0.4711
# Epoch 70/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1700 - accuracy: 0.4934 - val_loss: 2.0298 - val_accuracy: 0.4684
# Epoch 71/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1774 - accuracy: 0.5033 - val_loss: 2.0506 - val_accuracy: 0.4711
# Epoch 72/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1686 - accuracy: 0.5020 - val_loss: 1.7852 - val_accuracy: 0.4711
# Epoch 73/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1581 - accuracy: 0.4974 - val_loss: 1.9992 - val_accuracy: 0.4684
# Epoch 74/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1608 - accuracy: 0.4967 - val_loss: 1.8987 - val_accuracy: 0.4711
# Epoch 75/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1526 - accuracy: 0.5007 - val_loss: 1.7102 - val_accuracy: 0.4895
# Epoch 76/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1427 - accuracy: 0.5099 - val_loss: 2.2059 - val_accuracy: 0.4711
# Epoch 77/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1415 - accuracy: 0.5072 - val_loss: 2.0642 - val_accuracy: 0.4711
# Epoch 78/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1457 - accuracy: 0.5171 - val_loss: 2.1247 - val_accuracy: 0.4658
# Epoch 79/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1570 - accuracy: 0.5079 - val_loss: 2.1309 - val_accuracy: 0.4658
# Epoch 80/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1380 - accuracy: 0.5171 - val_loss: 2.2018 - val_accuracy: 0.4684
# Epoch 81/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1379 - accuracy: 0.5224 - val_loss: 2.2161 - val_accuracy: 0.4711
# Epoch 82/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.1315 - accuracy: 0.5204 - val_loss: 2.1504 - val_accuracy: 0.4658
# Epoch 83/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1411 - accuracy: 0.5092 - val_loss: 1.9979 - val_accuracy: 0.4763
# Epoch 84/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1387 - accuracy: 0.5020 - val_loss: 2.0683 - val_accuracy: 0.4737
# Epoch 85/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1368 - accuracy: 0.5329 - val_loss: 2.1029 - val_accuracy: 0.4737
# Epoch 86/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1273 - accuracy: 0.5244 - val_loss: 2.0870 - val_accuracy: 0.4868
# Epoch 87/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1221 - accuracy: 0.5395 - val_loss: 2.0359 - val_accuracy: 0.4842
# Epoch 88/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1232 - accuracy: 0.5382 - val_loss: 2.3233 - val_accuracy: 0.4553
# Epoch 89/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1327 - accuracy: 0.5158 - val_loss: 2.2245 - val_accuracy: 0.4632
# Epoch 90/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0842 - accuracy: 0.5422 - val_loss: 2.3332 - val_accuracy: 0.4658
# Epoch 91/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1107 - accuracy: 0.5336 - val_loss: 2.3114 - val_accuracy: 0.4711
# Epoch 92/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0830 - accuracy: 0.5461 - val_loss: 2.1313 - val_accuracy: 0.4711
# Epoch 93/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1200 - accuracy: 0.5343 - val_loss: 2.1514 - val_accuracy: 0.4737
# Epoch 94/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1051 - accuracy: 0.5356 - val_loss: 2.0262 - val_accuracy: 0.4763
# Epoch 95/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1166 - accuracy: 0.5382 - val_loss: 2.3367 - val_accuracy: 0.4763
# Epoch 96/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1055 - accuracy: 0.5356 - val_loss: 2.3762 - val_accuracy: 0.4658
# Epoch 97/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0890 - accuracy: 0.5547 - val_loss: 1.9834 - val_accuracy: 0.4789
# Epoch 98/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.1022 - accuracy: 0.5422 - val_loss: 1.8291 - val_accuracy: 0.4895
# Epoch 99/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0796 - accuracy: 0.5540 - val_loss: 1.6537 - val_accuracy: 0.5105
# Epoch 100/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0810 - accuracy: 0.5553 - val_loss: 1.4797 - val_accuracy: 0.5184
# Epoch 101/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0796 - accuracy: 0.5547 - val_loss: 1.6443 - val_accuracy: 0.5132
# Epoch 102/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0784 - accuracy: 0.5751 - val_loss: 1.3244 - val_accuracy: 0.5658
# Epoch 103/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0671 - accuracy: 0.5573 - val_loss: 1.4851 - val_accuracy: 0.5289
# Epoch 104/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0646 - accuracy: 0.5632 - val_loss: 1.7105 - val_accuracy: 0.5132
# Epoch 105/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0466 - accuracy: 0.5935 - val_loss: 1.4990 - val_accuracy: 0.5289
# Epoch 106/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0552 - accuracy: 0.5810 - val_loss: 1.7137 - val_accuracy: 0.5237
# Epoch 107/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0731 - accuracy: 0.5679 - val_loss: 1.7964 - val_accuracy: 0.5079
# Epoch 108/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0419 - accuracy: 0.5744 - val_loss: 1.6255 - val_accuracy: 0.5158
# Epoch 109/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0593 - accuracy: 0.5922 - val_loss: 1.5683 - val_accuracy: 0.5342
# Epoch 110/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0369 - accuracy: 0.5817 - val_loss: 1.5838 - val_accuracy: 0.5342
# Epoch 111/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0138 - accuracy: 0.6008 - val_loss: 1.4543 - val_accuracy: 0.5632
# Epoch 112/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0236 - accuracy: 0.5725 - val_loss: 1.2083 - val_accuracy: 0.6342
# Epoch 113/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0425 - accuracy: 0.5883 - val_loss: 1.3436 - val_accuracy: 0.6105
# Epoch 114/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0228 - accuracy: 0.5949 - val_loss: 1.7779 - val_accuracy: 0.5237
# Epoch 115/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0290 - accuracy: 0.5935 - val_loss: 1.2291 - val_accuracy: 0.6237
# Epoch 116/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0172 - accuracy: 0.6173 - val_loss: 1.7826 - val_accuracy: 0.5474
# Epoch 117/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0074 - accuracy: 0.5916 - val_loss: 1.0594 - val_accuracy: 0.6368
# Epoch 118/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0149 - accuracy: 0.6100 - val_loss: 1.2655 - val_accuracy: 0.6105
# Epoch 119/800
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0093 - accuracy: 0.6021 - val_loss: 1.1466 - val_accuracy: 0.6474
# Epoch 120/800
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0065 - accuracy: 0.5988 - val_loss: 1.2631 - val_accuracy: 0.6158
# Epoch 121/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9765 - accuracy: 0.6199 - val_loss: 1.1370 - val_accuracy: 0.6395
# Epoch 122/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9634 - accuracy: 0.6265 - val_loss: 1.4367 - val_accuracy: 0.6000
# Epoch 123/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9908 - accuracy: 0.6126 - val_loss: 1.2129 - val_accuracy: 0.6316
# Epoch 124/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9579 - accuracy: 0.6219 - val_loss: 1.2367 - val_accuracy: 0.6395
# Epoch 125/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9646 - accuracy: 0.6252 - val_loss: 1.3386 - val_accuracy: 0.6211
# Epoch 126/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9771 - accuracy: 0.6232 - val_loss: 1.2335 - val_accuracy: 0.6368
# Epoch 127/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9687 - accuracy: 0.6166 - val_loss: 1.0260 - val_accuracy: 0.6816
# Epoch 128/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9502 - accuracy: 0.6331 - val_loss: 1.0409 - val_accuracy: 0.6763
# Epoch 129/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9469 - accuracy: 0.6383 - val_loss: 1.3222 - val_accuracy: 0.6474
# Epoch 130/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9322 - accuracy: 0.6416 - val_loss: 1.0041 - val_accuracy: 0.6947
# Epoch 131/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9221 - accuracy: 0.6337 - val_loss: 0.9733 - val_accuracy: 0.6974
# Epoch 132/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9360 - accuracy: 0.6469 - val_loss: 0.9371 - val_accuracy: 0.6895
# Epoch 133/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9202 - accuracy: 0.6449 - val_loss: 0.8930 - val_accuracy: 0.7026
# Epoch 134/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9383 - accuracy: 0.6357 - val_loss: 0.9156 - val_accuracy: 0.7053
# Epoch 135/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9181 - accuracy: 0.6555 - val_loss: 1.0396 - val_accuracy: 0.6974
# Epoch 136/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9394 - accuracy: 0.6225 - val_loss: 0.9428 - val_accuracy: 0.7184
# Epoch 137/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9001 - accuracy: 0.6542 - val_loss: 0.9431 - val_accuracy: 0.6816
# Epoch 138/800
# 48/48 [==============================] - 0s 9ms/step - loss: 0.9124 - accuracy: 0.6759 - val_loss: 0.9067 - val_accuracy: 0.7316
# Epoch 139/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9003 - accuracy: 0.6634 - val_loss: 0.9631 - val_accuracy: 0.6658
# Epoch 140/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8989 - accuracy: 0.6535 - val_loss: 0.9568 - val_accuracy: 0.7132
# Epoch 141/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9220 - accuracy: 0.6456 - val_loss: 0.8511 - val_accuracy: 0.7263
# Epoch 142/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.9150 - accuracy: 0.6647 - val_loss: 0.8839 - val_accuracy: 0.7342
# Epoch 143/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9015 - accuracy: 0.6568 - val_loss: 0.9594 - val_accuracy: 0.6868
# Epoch 144/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9363 - accuracy: 0.6509 - val_loss: 0.8616 - val_accuracy: 0.7053
# Epoch 145/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9056 - accuracy: 0.6548 - val_loss: 0.9298 - val_accuracy: 0.6895
# Epoch 146/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8866 - accuracy: 0.6706 - val_loss: 0.8837 - val_accuracy: 0.7263
# Epoch 147/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8920 - accuracy: 0.6581 - val_loss: 0.9564 - val_accuracy: 0.7079
# Epoch 148/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.9079 - accuracy: 0.6581 - val_loss: 0.9803 - val_accuracy: 0.7158
# Epoch 149/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8686 - accuracy: 0.6765 - val_loss: 1.0102 - val_accuracy: 0.6500
# Epoch 150/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8975 - accuracy: 0.6667 - val_loss: 0.8461 - val_accuracy: 0.7263
# Epoch 151/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8665 - accuracy: 0.6706 - val_loss: 0.9452 - val_accuracy: 0.6947
# Epoch 152/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8767 - accuracy: 0.6970 - val_loss: 0.8516 - val_accuracy: 0.7263
# Epoch 153/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8671 - accuracy: 0.6555 - val_loss: 0.9054 - val_accuracy: 0.7263
# Epoch 154/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8713 - accuracy: 0.6746 - val_loss: 0.9261 - val_accuracy: 0.7316
# Epoch 155/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8720 - accuracy: 0.6917 - val_loss: 1.0283 - val_accuracy: 0.6605
# Epoch 156/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8537 - accuracy: 0.6798 - val_loss: 0.8936 - val_accuracy: 0.7395
# Epoch 157/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8710 - accuracy: 0.6772 - val_loss: 0.8920 - val_accuracy: 0.7368
# Epoch 158/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8676 - accuracy: 0.6739 - val_loss: 0.8380 - val_accuracy: 0.7289
# Epoch 159/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8593 - accuracy: 0.6897 - val_loss: 0.9895 - val_accuracy: 0.6605
# Epoch 160/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8547 - accuracy: 0.6653 - val_loss: 0.8867 - val_accuracy: 0.6974
# Epoch 161/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8776 - accuracy: 0.6627 - val_loss: 0.9656 - val_accuracy: 0.6868
# Epoch 162/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8525 - accuracy: 0.6937 - val_loss: 0.9127 - val_accuracy: 0.7132
# Epoch 163/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8459 - accuracy: 0.6739 - val_loss: 0.8897 - val_accuracy: 0.7026
# Epoch 164/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8660 - accuracy: 0.6739 - val_loss: 0.8256 - val_accuracy: 0.7421
# Epoch 165/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8397 - accuracy: 0.6831 - val_loss: 0.8100 - val_accuracy: 0.7316
# Epoch 166/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8392 - accuracy: 0.6904 - val_loss: 0.8570 - val_accuracy: 0.7184
# Epoch 167/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8321 - accuracy: 0.6963 - val_loss: 0.9659 - val_accuracy: 0.7053
# Epoch 168/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8489 - accuracy: 0.6845 - val_loss: 0.7824 - val_accuracy: 0.7474
# Epoch 169/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8226 - accuracy: 0.6825 - val_loss: 0.8173 - val_accuracy: 0.7316
# Epoch 170/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8327 - accuracy: 0.6930 - val_loss: 0.8369 - val_accuracy: 0.7289
# Epoch 171/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8370 - accuracy: 0.6950 - val_loss: 0.8490 - val_accuracy: 0.7263
# Epoch 172/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8267 - accuracy: 0.6805 - val_loss: 0.9642 - val_accuracy: 0.6763
# Epoch 173/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8144 - accuracy: 0.6983 - val_loss: 0.8094 - val_accuracy: 0.7447
# Epoch 174/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7990 - accuracy: 0.7042 - val_loss: 0.8131 - val_accuracy: 0.7500
# Epoch 175/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8160 - accuracy: 0.6983 - val_loss: 0.7965 - val_accuracy: 0.7526
# Epoch 176/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8066 - accuracy: 0.6792 - val_loss: 0.8130 - val_accuracy: 0.7421
# Epoch 177/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8057 - accuracy: 0.6989 - val_loss: 0.8279 - val_accuracy: 0.7421
# Epoch 178/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8337 - accuracy: 0.6943 - val_loss: 0.8345 - val_accuracy: 0.7447
# Epoch 179/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7963 - accuracy: 0.7088 - val_loss: 0.7870 - val_accuracy: 0.7684
# Epoch 180/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7856 - accuracy: 0.7220 - val_loss: 0.8143 - val_accuracy: 0.7289
# Epoch 181/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8015 - accuracy: 0.7082 - val_loss: 0.7863 - val_accuracy: 0.7526
# Epoch 182/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8173 - accuracy: 0.7069 - val_loss: 0.7793 - val_accuracy: 0.7421
# Epoch 183/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7986 - accuracy: 0.6983 - val_loss: 0.8215 - val_accuracy: 0.7158
# Epoch 184/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8191 - accuracy: 0.6943 - val_loss: 0.8079 - val_accuracy: 0.7289
# Epoch 185/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7877 - accuracy: 0.7115 - val_loss: 0.7809 - val_accuracy: 0.7500
# Epoch 186/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7886 - accuracy: 0.7016 - val_loss: 0.7946 - val_accuracy: 0.7579
# Epoch 187/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7897 - accuracy: 0.7049 - val_loss: 0.7496 - val_accuracy: 0.7526
# Epoch 188/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7793 - accuracy: 0.7200 - val_loss: 0.7676 - val_accuracy: 0.7474
# Epoch 189/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7814 - accuracy: 0.7108 - val_loss: 0.8908 - val_accuracy: 0.7158
# Epoch 190/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7787 - accuracy: 0.7154 - val_loss: 0.8504 - val_accuracy: 0.7263
# Epoch 191/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7950 - accuracy: 0.6910 - val_loss: 0.7795 - val_accuracy: 0.7474
# Epoch 192/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7715 - accuracy: 0.7095 - val_loss: 0.8228 - val_accuracy: 0.7158
# Epoch 193/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7874 - accuracy: 0.7082 - val_loss: 0.8403 - val_accuracy: 0.7395
# Epoch 194/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.8125 - accuracy: 0.7128 - val_loss: 0.8278 - val_accuracy: 0.7316
# Epoch 195/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7706 - accuracy: 0.7161 - val_loss: 0.7838 - val_accuracy: 0.7500
# Epoch 196/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7860 - accuracy: 0.7233 - val_loss: 0.7995 - val_accuracy: 0.7474
# Epoch 197/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7602 - accuracy: 0.7286 - val_loss: 0.8042 - val_accuracy: 0.7474
# Epoch 198/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7641 - accuracy: 0.7227 - val_loss: 0.7863 - val_accuracy: 0.7526
# Epoch 199/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7499 - accuracy: 0.7213 - val_loss: 0.8438 - val_accuracy: 0.7316
# Epoch 200/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7792 - accuracy: 0.7095 - val_loss: 0.7579 - val_accuracy: 0.7474
# Epoch 201/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7586 - accuracy: 0.7240 - val_loss: 0.8206 - val_accuracy: 0.7342
# Epoch 202/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7623 - accuracy: 0.7372 - val_loss: 0.7499 - val_accuracy: 0.7368
# Epoch 203/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7472 - accuracy: 0.7253 - val_loss: 0.7506 - val_accuracy: 0.7447
# Epoch 204/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7426 - accuracy: 0.7378 - val_loss: 0.7324 - val_accuracy: 0.7474
# Epoch 205/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7614 - accuracy: 0.7121 - val_loss: 0.7682 - val_accuracy: 0.7289
# Epoch 206/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7554 - accuracy: 0.7246 - val_loss: 1.0868 - val_accuracy: 0.6526
# Epoch 207/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7292 - accuracy: 0.7319 - val_loss: 0.7825 - val_accuracy: 0.7447
# Epoch 208/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7626 - accuracy: 0.7187 - val_loss: 0.7286 - val_accuracy: 0.7632
# Epoch 209/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7500 - accuracy: 0.7358 - val_loss: 0.7114 - val_accuracy: 0.7579
# Epoch 210/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7575 - accuracy: 0.7233 - val_loss: 0.7141 - val_accuracy: 0.7605
# Epoch 211/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7591 - accuracy: 0.7108 - val_loss: 0.7235 - val_accuracy: 0.7526
# Epoch 212/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7334 - accuracy: 0.7365 - val_loss: 0.7131 - val_accuracy: 0.7658
# Epoch 213/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7610 - accuracy: 0.7227 - val_loss: 0.7399 - val_accuracy: 0.7553
# Epoch 214/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7373 - accuracy: 0.7431 - val_loss: 0.7419 - val_accuracy: 0.7553
# Epoch 215/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7346 - accuracy: 0.7286 - val_loss: 0.7445 - val_accuracy: 0.7605
# Epoch 216/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7513 - accuracy: 0.7194 - val_loss: 0.8053 - val_accuracy: 0.7289
# Epoch 217/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7491 - accuracy: 0.7213 - val_loss: 0.9570 - val_accuracy: 0.6842
# Epoch 218/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7601 - accuracy: 0.7194 - val_loss: 0.9350 - val_accuracy: 0.6816
# Epoch 219/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7406 - accuracy: 0.7358 - val_loss: 0.7376 - val_accuracy: 0.7474
# Epoch 220/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7480 - accuracy: 0.7253 - val_loss: 0.7150 - val_accuracy: 0.7684
# Epoch 221/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7139 - accuracy: 0.7372 - val_loss: 0.7622 - val_accuracy: 0.7579
# Epoch 222/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7511 - accuracy: 0.7220 - val_loss: 0.7375 - val_accuracy: 0.7447
# Epoch 223/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7428 - accuracy: 0.7477 - val_loss: 0.7572 - val_accuracy: 0.7474
# Epoch 224/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7091 - accuracy: 0.7477 - val_loss: 0.7088 - val_accuracy: 0.7553
# Epoch 225/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7202 - accuracy: 0.7332 - val_loss: 0.7009 - val_accuracy: 0.7632
# Epoch 226/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7250 - accuracy: 0.7306 - val_loss: 0.7104 - val_accuracy: 0.7684
# Epoch 227/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7196 - accuracy: 0.7490 - val_loss: 0.7316 - val_accuracy: 0.7474
# Epoch 228/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7263 - accuracy: 0.7404 - val_loss: 0.7938 - val_accuracy: 0.7500
# Epoch 229/800
# 48/48 [==============================] - 0s 9ms/step - loss: 0.7163 - accuracy: 0.7451 - val_loss: 0.8479 - val_accuracy: 0.7211
# Epoch 230/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7169 - accuracy: 0.7339 - val_loss: 0.7326 - val_accuracy: 0.7500
# Epoch 231/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7113 - accuracy: 0.7437 - val_loss: 0.7158 - val_accuracy: 0.7579
# Epoch 232/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6923 - accuracy: 0.7398 - val_loss: 0.6954 - val_accuracy: 0.7526
# Epoch 233/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6840 - accuracy: 0.7424 - val_loss: 0.7501 - val_accuracy: 0.7500
# Epoch 234/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7028 - accuracy: 0.7451 - val_loss: 0.7064 - val_accuracy: 0.7553
# Epoch 235/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7022 - accuracy: 0.7385 - val_loss: 0.6992 - val_accuracy: 0.7368
# Epoch 236/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7022 - accuracy: 0.7484 - val_loss: 0.8026 - val_accuracy: 0.7263
# Epoch 237/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7099 - accuracy: 0.7391 - val_loss: 0.7513 - val_accuracy: 0.7500
# Epoch 238/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7112 - accuracy: 0.7292 - val_loss: 0.6910 - val_accuracy: 0.7500
# Epoch 239/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7098 - accuracy: 0.7536 - val_loss: 0.7238 - val_accuracy: 0.7553
# Epoch 240/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7019 - accuracy: 0.7470 - val_loss: 0.7384 - val_accuracy: 0.7526
# Epoch 241/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7039 - accuracy: 0.7451 - val_loss: 0.7132 - val_accuracy: 0.7605
# Epoch 242/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6796 - accuracy: 0.7556 - val_loss: 0.6739 - val_accuracy: 0.7605
# Epoch 243/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6924 - accuracy: 0.7497 - val_loss: 0.6865 - val_accuracy: 0.7684
# Epoch 244/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6768 - accuracy: 0.7536 - val_loss: 0.7074 - val_accuracy: 0.7500
# Epoch 245/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7165 - accuracy: 0.7345 - val_loss: 0.6814 - val_accuracy: 0.7605
# Epoch 246/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7155 - accuracy: 0.7398 - val_loss: 0.7102 - val_accuracy: 0.7605
# Epoch 247/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6920 - accuracy: 0.7536 - val_loss: 0.6791 - val_accuracy: 0.7526
# Epoch 248/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6885 - accuracy: 0.7523 - val_loss: 0.6764 - val_accuracy: 0.7684
# Epoch 249/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6871 - accuracy: 0.7510 - val_loss: 0.6592 - val_accuracy: 0.7579
# Epoch 250/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6968 - accuracy: 0.7306 - val_loss: 0.7337 - val_accuracy: 0.7500
# Epoch 251/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7063 - accuracy: 0.7503 - val_loss: 0.8155 - val_accuracy: 0.7316
# Epoch 252/800
# 48/48 [==============================] - 0s 9ms/step - loss: 0.6863 - accuracy: 0.7385 - val_loss: 0.6824 - val_accuracy: 0.7763
# Epoch 253/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6863 - accuracy: 0.7352 - val_loss: 0.6725 - val_accuracy: 0.7658
# Epoch 254/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6734 - accuracy: 0.7477 - val_loss: 0.6935 - val_accuracy: 0.7711
# Epoch 255/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6783 - accuracy: 0.7582 - val_loss: 0.6900 - val_accuracy: 0.7579
# Epoch 256/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6724 - accuracy: 0.7556 - val_loss: 0.7296 - val_accuracy: 0.7474
# Epoch 257/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6647 - accuracy: 0.7708 - val_loss: 0.7012 - val_accuracy: 0.7421
# Epoch 258/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7045 - accuracy: 0.7503 - val_loss: 0.7458 - val_accuracy: 0.7474
# Epoch 259/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6622 - accuracy: 0.7582 - val_loss: 0.6654 - val_accuracy: 0.7816
# Epoch 260/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6831 - accuracy: 0.7470 - val_loss: 0.7033 - val_accuracy: 0.7658
# Epoch 261/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6868 - accuracy: 0.7549 - val_loss: 0.7075 - val_accuracy: 0.7711
# Epoch 262/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6723 - accuracy: 0.7549 - val_loss: 0.6788 - val_accuracy: 0.7605
# Epoch 263/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6748 - accuracy: 0.7569 - val_loss: 0.7284 - val_accuracy: 0.7684
# Epoch 264/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6984 - accuracy: 0.7510 - val_loss: 0.7366 - val_accuracy: 0.7553
# Epoch 265/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6782 - accuracy: 0.7490 - val_loss: 0.6762 - val_accuracy: 0.7711
# Epoch 266/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6820 - accuracy: 0.7549 - val_loss: 0.6744 - val_accuracy: 0.7632
# Epoch 267/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6359 - accuracy: 0.7793 - val_loss: 0.7189 - val_accuracy: 0.7579
# Epoch 268/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6571 - accuracy: 0.7747 - val_loss: 0.6669 - val_accuracy: 0.7684
# Epoch 269/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6880 - accuracy: 0.7418 - val_loss: 0.6464 - val_accuracy: 0.7605
# Epoch 270/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6730 - accuracy: 0.7648 - val_loss: 0.6706 - val_accuracy: 0.7632
# Epoch 271/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6618 - accuracy: 0.7622 - val_loss: 0.6822 - val_accuracy: 0.7684
# Epoch 272/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6445 - accuracy: 0.7655 - val_loss: 0.6588 - val_accuracy: 0.7553
# Epoch 273/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6811 - accuracy: 0.7556 - val_loss: 0.7037 - val_accuracy: 0.7579
# Epoch 274/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6605 - accuracy: 0.7754 - val_loss: 0.6385 - val_accuracy: 0.7658
# Epoch 275/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6650 - accuracy: 0.7549 - val_loss: 0.6934 - val_accuracy: 0.7711
# Epoch 276/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6515 - accuracy: 0.7773 - val_loss: 0.6635 - val_accuracy: 0.7658
# Epoch 277/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6492 - accuracy: 0.7576 - val_loss: 0.6562 - val_accuracy: 0.7684
# Epoch 278/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6268 - accuracy: 0.7826 - val_loss: 0.7069 - val_accuracy: 0.7763
# Epoch 279/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6733 - accuracy: 0.7510 - val_loss: 0.6952 - val_accuracy: 0.7711
# Epoch 280/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6437 - accuracy: 0.7727 - val_loss: 0.6783 - val_accuracy: 0.7711
# Epoch 281/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6437 - accuracy: 0.7701 - val_loss: 0.6735 - val_accuracy: 0.7632
# Epoch 282/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6302 - accuracy: 0.7675 - val_loss: 0.6734 - val_accuracy: 0.7632
# Epoch 283/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6356 - accuracy: 0.7833 - val_loss: 0.6702 - val_accuracy: 0.7658
# Epoch 284/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6654 - accuracy: 0.7628 - val_loss: 0.6491 - val_accuracy: 0.7684
# Epoch 285/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6505 - accuracy: 0.7668 - val_loss: 0.6255 - val_accuracy: 0.7737
# Epoch 286/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6173 - accuracy: 0.7879 - val_loss: 0.6466 - val_accuracy: 0.7711
# Epoch 287/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6424 - accuracy: 0.7754 - val_loss: 0.6685 - val_accuracy: 0.7711
# Epoch 288/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6158 - accuracy: 0.7740 - val_loss: 0.6532 - val_accuracy: 0.7816
# Epoch 289/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6173 - accuracy: 0.7773 - val_loss: 0.6789 - val_accuracy: 0.7842
# Epoch 290/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6303 - accuracy: 0.7767 - val_loss: 0.6373 - val_accuracy: 0.7789
# Epoch 291/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6191 - accuracy: 0.7760 - val_loss: 0.6309 - val_accuracy: 0.7816
# Epoch 292/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6203 - accuracy: 0.7819 - val_loss: 1.2060 - val_accuracy: 0.6500
# Epoch 293/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6356 - accuracy: 0.7688 - val_loss: 0.7529 - val_accuracy: 0.7632
# Epoch 294/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6168 - accuracy: 0.7839 - val_loss: 0.6274 - val_accuracy: 0.7816
# Epoch 295/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6311 - accuracy: 0.7675 - val_loss: 0.6570 - val_accuracy: 0.7684
# Epoch 296/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6285 - accuracy: 0.7596 - val_loss: 0.6444 - val_accuracy: 0.7816
# Epoch 297/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6479 - accuracy: 0.7727 - val_loss: 0.6428 - val_accuracy: 0.7763
# Epoch 298/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6012 - accuracy: 0.7806 - val_loss: 0.6287 - val_accuracy: 0.7789
# Epoch 299/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6113 - accuracy: 0.7747 - val_loss: 0.6291 - val_accuracy: 0.7789
# Epoch 300/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6307 - accuracy: 0.7635 - val_loss: 0.6394 - val_accuracy: 0.7711
# Epoch 301/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6004 - accuracy: 0.7978 - val_loss: 0.7307 - val_accuracy: 0.7632
# Epoch 302/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6363 - accuracy: 0.7681 - val_loss: 0.6585 - val_accuracy: 0.7711
# Epoch 303/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6225 - accuracy: 0.7767 - val_loss: 0.6783 - val_accuracy: 0.7737
# Epoch 304/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6282 - accuracy: 0.7754 - val_loss: 0.6578 - val_accuracy: 0.7763
# Epoch 305/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6002 - accuracy: 0.7852 - val_loss: 0.6138 - val_accuracy: 0.7711
# Epoch 306/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6059 - accuracy: 0.7773 - val_loss: 0.6065 - val_accuracy: 0.7684
# Epoch 307/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6368 - accuracy: 0.7694 - val_loss: 0.6349 - val_accuracy: 0.7711
# Epoch 308/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6079 - accuracy: 0.7826 - val_loss: 0.6150 - val_accuracy: 0.7711
# Epoch 309/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6275 - accuracy: 0.7582 - val_loss: 0.5986 - val_accuracy: 0.7658
# Epoch 310/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6132 - accuracy: 0.7813 - val_loss: 0.6368 - val_accuracy: 0.7553
# Epoch 311/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6226 - accuracy: 0.7754 - val_loss: 0.6725 - val_accuracy: 0.7842
# Epoch 312/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6271 - accuracy: 0.7787 - val_loss: 0.6709 - val_accuracy: 0.7632
# Epoch 313/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5989 - accuracy: 0.7826 - val_loss: 0.6307 - val_accuracy: 0.7737
# Epoch 314/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6159 - accuracy: 0.7780 - val_loss: 0.6497 - val_accuracy: 0.7816
# Epoch 315/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6029 - accuracy: 0.7951 - val_loss: 0.6341 - val_accuracy: 0.7763
# Epoch 316/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5928 - accuracy: 0.7826 - val_loss: 0.6211 - val_accuracy: 0.7711
# Epoch 317/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5760 - accuracy: 0.7892 - val_loss: 0.6335 - val_accuracy: 0.7789
# Epoch 318/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6047 - accuracy: 0.7806 - val_loss: 0.6466 - val_accuracy: 0.7789
# Epoch 319/800
# 48/48 [==============================] - 0s 10ms/step - loss: 0.5854 - accuracy: 0.7819 - val_loss: 0.5848 - val_accuracy: 0.7868
# Epoch 320/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5934 - accuracy: 0.7819 - val_loss: 0.6383 - val_accuracy: 0.7632
# Epoch 321/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6176 - accuracy: 0.7813 - val_loss: 0.6115 - val_accuracy: 0.7842
# Epoch 322/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5944 - accuracy: 0.7833 - val_loss: 0.6139 - val_accuracy: 0.7868
# Epoch 323/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5901 - accuracy: 0.7852 - val_loss: 0.6073 - val_accuracy: 0.7763
# Epoch 324/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5884 - accuracy: 0.7839 - val_loss: 0.6706 - val_accuracy: 0.7632
# Epoch 325/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5901 - accuracy: 0.7931 - val_loss: 0.6052 - val_accuracy: 0.7737
# Epoch 326/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5791 - accuracy: 0.7997 - val_loss: 0.6202 - val_accuracy: 0.7763
# Epoch 327/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5757 - accuracy: 0.7872 - val_loss: 0.6413 - val_accuracy: 0.7737
# Epoch 328/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6045 - accuracy: 0.7866 - val_loss: 0.5835 - val_accuracy: 0.7816
# Epoch 329/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5598 - accuracy: 0.8017 - val_loss: 0.6413 - val_accuracy: 0.7763
# Epoch 330/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6072 - accuracy: 0.7859 - val_loss: 0.6471 - val_accuracy: 0.7605
# Epoch 331/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5796 - accuracy: 0.7958 - val_loss: 0.6876 - val_accuracy: 0.7711
# Epoch 332/800
# ...
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2920 - accuracy: 0.9164 - val_loss: 0.4477 - val_accuracy: 0.8421
# Epoch 707/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2697 - accuracy: 0.9256 - val_loss: 0.4611 - val_accuracy: 0.8395
# Epoch 708/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2895 - accuracy: 0.9217 - val_loss: 0.4471 - val_accuracy: 0.8447
# Epoch 709/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2928 - accuracy: 0.9157 - val_loss: 0.4696 - val_accuracy: 0.8447
# Epoch 710/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2738 - accuracy: 0.9250 - val_loss: 0.4387 - val_accuracy: 0.8553
# Epoch 711/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.3150 - accuracy: 0.9118 - val_loss: 0.4452 - val_accuracy: 0.8500
# Epoch 712/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2849 - accuracy: 0.9243 - val_loss: 0.4710 - val_accuracy: 0.8447
# Epoch 713/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2702 - accuracy: 0.9263 - val_loss: 0.4522 - val_accuracy: 0.8500
# Epoch 714/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.3020 - accuracy: 0.9171 - val_loss: 0.4750 - val_accuracy: 0.8526
# Epoch 715/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2766 - accuracy: 0.9302 - val_loss: 0.4973 - val_accuracy: 0.8368
# Epoch 716/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2914 - accuracy: 0.9164 - val_loss: 0.4707 - val_accuracy: 0.8474
# Epoch 717/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2897 - accuracy: 0.9177 - val_loss: 0.4691 - val_accuracy: 0.8447
# Epoch 718/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2896 - accuracy: 0.9223 - val_loss: 0.4344 - val_accuracy: 0.8553
# Epoch 719/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2832 - accuracy: 0.9144 - val_loss: 0.4634 - val_accuracy: 0.8421
# Epoch 720/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2776 - accuracy: 0.9263 - val_loss: 0.4635 - val_accuracy: 0.8447
# Epoch 721/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2862 - accuracy: 0.9190 - val_loss: 0.4911 - val_accuracy: 0.8474
# Epoch 722/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.3003 - accuracy: 0.9243 - val_loss: 0.4660 - val_accuracy: 0.8421
# Epoch 723/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.3050 - accuracy: 0.9151 - val_loss: 0.5075 - val_accuracy: 0.8447
# Epoch 724/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2749 - accuracy: 0.9217 - val_loss: 0.4856 - val_accuracy: 0.8368
# Epoch 725/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2779 - accuracy: 0.9177 - val_loss: 0.4704 - val_accuracy: 0.8395
# Epoch 726/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2838 - accuracy: 0.9243 - val_loss: 0.4694 - val_accuracy: 0.8395
# Epoch 727/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2835 - accuracy: 0.9256 - val_loss: 0.4560 - val_accuracy: 0.8500
# Epoch 728/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2746 - accuracy: 0.9250 - val_loss: 0.4613 - val_accuracy: 0.8605
# Epoch 729/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2838 - accuracy: 0.9177 - val_loss: 0.4550 - val_accuracy: 0.8474
# Epoch 730/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2754 - accuracy: 0.9296 - val_loss: 0.4614 - val_accuracy: 0.8316
# Epoch 731/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2864 - accuracy: 0.9203 - val_loss: 0.4611 - val_accuracy: 0.8553
# Epoch 732/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2671 - accuracy: 0.9322 - val_loss: 0.4631 - val_accuracy: 0.8474
# Epoch 733/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2627 - accuracy: 0.9250 - val_loss: 0.4844 - val_accuracy: 0.8421
# Epoch 734/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2984 - accuracy: 0.9118 - val_loss: 0.4796 - val_accuracy: 0.8395
# Epoch 735/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2727 - accuracy: 0.9236 - val_loss: 0.4619 - val_accuracy: 0.8368
# Epoch 736/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2827 - accuracy: 0.9131 - val_loss: 0.4728 - val_accuracy: 0.8289
# Epoch 737/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.3105 - accuracy: 0.9105 - val_loss: 0.4655 - val_accuracy: 0.8368
# Epoch 738/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2781 - accuracy: 0.9243 - val_loss: 0.4492 - val_accuracy: 0.8447
# Epoch 739/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2744 - accuracy: 0.9223 - val_loss: 0.4495 - val_accuracy: 0.8500
# Epoch 740/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2739 - accuracy: 0.9296 - val_loss: 0.4460 - val_accuracy: 0.8553
# Epoch 741/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2717 - accuracy: 0.9322 - val_loss: 0.4445 - val_accuracy: 0.8553
# Epoch 742/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2808 - accuracy: 0.9296 - val_loss: 0.4641 - val_accuracy: 0.8395
# Epoch 743/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2836 - accuracy: 0.9223 - val_loss: 0.4740 - val_accuracy: 0.8447
# Epoch 744/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2669 - accuracy: 0.9348 - val_loss: 0.4559 - val_accuracy: 0.8421
# Epoch 745/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2655 - accuracy: 0.9348 - val_loss: 0.4650 - val_accuracy: 0.8500
# Epoch 746/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2783 - accuracy: 0.9184 - val_loss: 0.4825 - val_accuracy: 0.8368
# Epoch 747/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2589 - accuracy: 0.9381 - val_loss: 0.4586 - val_accuracy: 0.8500
# Epoch 748/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2656 - accuracy: 0.9302 - val_loss: 0.4745 - val_accuracy: 0.8368
# Epoch 749/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2421 - accuracy: 0.9401 - val_loss: 0.4442 - val_accuracy: 0.8553
# Epoch 750/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2875 - accuracy: 0.9223 - val_loss: 0.4689 - val_accuracy: 0.8500
# Epoch 751/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2717 - accuracy: 0.9230 - val_loss: 0.4669 - val_accuracy: 0.8474
# Epoch 752/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2835 - accuracy: 0.9250 - val_loss: 0.4571 - val_accuracy: 0.8579
# Epoch 753/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2765 - accuracy: 0.9118 - val_loss: 0.4457 - val_accuracy: 0.8553
# Epoch 754/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2831 - accuracy: 0.9177 - val_loss: 0.4805 - val_accuracy: 0.8500
# Epoch 755/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2778 - accuracy: 0.9302 - val_loss: 0.4507 - val_accuracy: 0.8500
# Epoch 756/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2725 - accuracy: 0.9197 - val_loss: 0.4586 - val_accuracy: 0.8447
# Epoch 757/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2516 - accuracy: 0.9322 - val_loss: 0.4399 - val_accuracy: 0.8553
# Epoch 758/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2799 - accuracy: 0.9217 - val_loss: 0.5550 - val_accuracy: 0.8395
# Epoch 759/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2910 - accuracy: 0.9197 - val_loss: 0.4583 - val_accuracy: 0.8500
# Epoch 760/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2830 - accuracy: 0.9276 - val_loss: 0.4424 - val_accuracy: 0.8474
# Epoch 761/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2767 - accuracy: 0.9282 - val_loss: 0.4508 - val_accuracy: 0.8553
# Epoch 762/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2396 - accuracy: 0.9408 - val_loss: 0.4509 - val_accuracy: 0.8605
# Epoch 763/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2714 - accuracy: 0.9210 - val_loss: 0.4489 - val_accuracy: 0.8526
# Epoch 764/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2682 - accuracy: 0.9210 - val_loss: 0.4607 - val_accuracy: 0.8263
# Epoch 765/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2660 - accuracy: 0.9269 - val_loss: 0.4458 - val_accuracy: 0.8553
# Epoch 766/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2718 - accuracy: 0.9203 - val_loss: 0.4615 - val_accuracy: 0.8395
# Epoch 767/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2793 - accuracy: 0.9282 - val_loss: 0.4316 - val_accuracy: 0.8632
# Epoch 768/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.3033 - accuracy: 0.9164 - val_loss: 0.4664 - val_accuracy: 0.8553
# Epoch 769/800
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2612 - accuracy: 0.9296 - val_loss: 0.4668 - val_accuracy: 0.8526
# Epoch 770/800
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2745 - accuracy: 0.9269 - val_loss: 0.4492 - val_accuracy: 0.8447
# Epoch 771/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2692 - accuracy: 0.9250 - val_loss: 0.4413 - val_accuracy: 0.8447
# Epoch 772/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2700 - accuracy: 0.9282 - val_loss: 0.4349 - val_accuracy: 0.8579
# Epoch 773/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2634 - accuracy: 0.9269 - val_loss: 0.4668 - val_accuracy: 0.8447
# Epoch 774/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2601 - accuracy: 0.9289 - val_loss: 0.4430 - val_accuracy: 0.8553
# Epoch 775/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2659 - accuracy: 0.9335 - val_loss: 0.4931 - val_accuracy: 0.8474
# Epoch 776/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2607 - accuracy: 0.9276 - val_loss: 0.4471 - val_accuracy: 0.8526
# Epoch 777/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2676 - accuracy: 0.9236 - val_loss: 0.4507 - val_accuracy: 0.8526
# Epoch 778/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2534 - accuracy: 0.9296 - val_loss: 0.4521 - val_accuracy: 0.8447
# Epoch 779/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2616 - accuracy: 0.9269 - val_loss: 0.4528 - val_accuracy: 0.8447
# Epoch 780/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2579 - accuracy: 0.9263 - val_loss: 0.4452 - val_accuracy: 0.8579
# Epoch 781/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2747 - accuracy: 0.9164 - val_loss: 0.4977 - val_accuracy: 0.8474
# Epoch 782/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2590 - accuracy: 0.9355 - val_loss: 0.5213 - val_accuracy: 0.8421
# Epoch 783/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2628 - accuracy: 0.9230 - val_loss: 0.4528 - val_accuracy: 0.8500
# Epoch 784/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2641 - accuracy: 0.9282 - val_loss: 0.4638 - val_accuracy: 0.8395
# Epoch 785/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2633 - accuracy: 0.9282 - val_loss: 0.4482 - val_accuracy: 0.8474
# Epoch 786/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2562 - accuracy: 0.9289 - val_loss: 0.4274 - val_accuracy: 0.8632
# Epoch 787/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2556 - accuracy: 0.9335 - val_loss: 0.4354 - val_accuracy: 0.8553
# Epoch 788/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2517 - accuracy: 0.9315 - val_loss: 0.4419 - val_accuracy: 0.8605
# Epoch 789/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2528 - accuracy: 0.9329 - val_loss: 0.4438 - val_accuracy: 0.8553
# Epoch 790/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2535 - accuracy: 0.9322 - val_loss: 0.4550 - val_accuracy: 0.8526
# Epoch 791/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2650 - accuracy: 0.9263 - val_loss: 0.4561 - val_accuracy: 0.8474
# Epoch 792/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2591 - accuracy: 0.9289 - val_loss: 0.4662 - val_accuracy: 0.8526
# Epoch 793/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.3540 - accuracy: 0.9072 - val_loss: 0.5818 - val_accuracy: 0.8211
# Epoch 794/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2651 - accuracy: 0.9296 - val_loss: 0.4516 - val_accuracy: 0.8474
# Epoch 795/800
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2521 - accuracy: 0.9355 - val_loss: 0.4533 - val_accuracy: 0.8526
# Epoch 796/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2505 - accuracy: 0.9348 - val_loss: 0.4313 - val_accuracy: 0.8553
# Epoch 797/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2549 - accuracy: 0.9315 - val_loss: 0.4428 - val_accuracy: 0.8500
# Epoch 798/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2519 - accuracy: 0.9388 - val_loss: 0.4861 - val_accuracy: 0.8263
# Epoch 799/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2540 - accuracy: 0.9348 - val_loss: 0.4668 - val_accuracy: 0.8500
# Epoch 800/800
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2812 - accuracy: 0.9223 - val_loss: 0.4445 - val_accuracy: 0.8500
# The best model was loaded and ready to be evaluated
# 15/15 [==============================] - 0s 2ms/step
# Precision: 0.8530
# Recall: 0.8469
# F1 Score: 0.8469
# Fold 5, Accuracy: 0.8544, Test Loss: 0.4998, Test Accuracy: 0.8544
# ========================================
# test losses: [0.465254008769989, 0.4364667534828186, 0.348713219165802, 0.46288180351257324, 0.4997667968273163]
# test accuracy: [0.8736842274665833, 0.8652631640434265, 0.8947368264198303, 0.8649789094924927, 0.8544303774833679]
# ****************************************
# Mean training loss over 5-fold cross-validation: 0.5888
# Mean training accuracy over 5-fold cross-validation: 0.7931
# Mean validation loss over 5-fold cross-validation: 0.7030
# Mean validation accuracy over 5-fold cross-validation: 0.7632
# ****************************************
# Mean accuracy over stratified 5-fold cross-validation: 0.8706
# Mean test loss over stratified 5-fold cross-validation: 0.4426
# Mean test accuracy over stratified 5-fold cross-validation: 0.8706
# ****************************************
# Standard deviation of training loss over 5-fold cross-validation: 0.3240
# Standard deviation of training accuracy over 5-fold cross-validation: 0.1337
# Standard deviation of validation loss over 5-fold cross-validation: 0.3145
# Standard deviation of validation accuracy over 5-fold cross-validation: 0.1072
# ****************************************
# Standard deviation of accuracy over stratified 5-fold cross-validation: 0.0135
# Standard deviation of test loss over stratified 5-fold cross-validation: 0.0511
# Standard deviation of test accuracy over stratified 5-fold cross-validation: 0.0135
# ****************************************
# Mean precision over stratified 5-fold cross-validation: 0.8661
# Standard deviation of precision over stratified 5-fold cross-validation: 0.0127
# Mean recall over stratified 5-fold cross-validation: 0.8624
# Standard deviation of recall over stratified 5-fold cross-validation: 0.0135
# Mean F1 score over stratified 5-fold cross-validation: 0.8625
# Standard deviation of F1 score over stratified 5-fold cross-validation: 0.0136
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Training time: 1511.69 seconds

# %%
# Given the paths you provided, let's generate confusion matrices for the VIT models:
cnn_model_path = "/kaggle/working/CV_CNN_models/"
data_model_path = "/kaggle/working/CV_CNN_fold_data/"
cm_model_path = "/kaggle/working/CV_CNN_cm/"

# Lists to store metrics
accuracies = []
precisions = []
recalls = []
f1_scores = []
confusion_matrices_cnn = []

# Loop through each fold
for fold in range(1, 6):
    # Load datasets for this fold
    with open(f"{data_model_path}fold_{fold}_data.pkl", 'rb') as f:
        fold_data = pickle.load(f)
        
    X_test = fold_data['X_test']
    y_test = fold_data['y_test']
    
    # Load the model for this fold
    model_file = f"fold_{fold}_split_5_cnn_v3_opt_32_800_seed7.h5"
    model_path = os.path.join(cnn_model_path, model_file)
    model = tf.keras.models.load_model(model_path)
    
    # Predict and evaluate
    y_pred = np.argmax(model.predict(X_test), axis=-1)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='macro')
    recall = recall_score(y_test, y_pred, average='macro')
    f1 = f1_score(y_test, y_pred, average='macro')
    cm = confusion_matrix(y_test, y_pred)
    
    # Save the confusion matrix
    with open(f"{cm_model_path}cnn_cm_fold_{fold}.pkl", 'wb') as cm_file:
        pickle.dump(cm, cm_file)
    
    # Store metrics
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)
    confusion_matrices_cnn.append(cm)
    
    # Print metrics for this fold
    print(f"Fold {fold}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print("-" * 40)

# This will give you a list of confusion matrices for each fold of the VIT models
confusion_matrices_cnn
