# %%
# %cd /kaggle/input/chemcancer-v2/src/
# %mkdir /kaggle/working/Deep_Learning_metrics/
# %mkdir /kaggle/working/During_train/
# %mkdir /kaggle/working/CV_CNN_models
# %mkdir /kaggle/working/CV_CNN_results
# %mkdir /kaggle/working/CV_CNN_fold_data
# %mkdir /kaggle/working/CV_CNN_cm
# Out:
# /kaggle/input/chemcancer-v2/src

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tensorflow.keras.optimizers import Adam
from data import *
from machine_learning_models import *
from deep_learning_models import *
from vision_transformer import *
from utils_dl_model import *
from utils_ml_model import print_ml_results
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Set the seed value.
SEED = 7
np.random.seed(SEED)

# Deep Learning parameters
DL_EPOCH = 1
DL_BATCH_SIZE = 32
DL_CNN_VERSION = 3
DL_TRANSFORMER_VISION_VERSION = 14
DL_CV_FOLD = 5

DO_DL = True
CV_DL = True
OPT_DL = False

DO_CNN = True
DO_TRANSFORMER_VISION = False
DO_ML = False

# Percentage of test set out of the dataset.
TEST_SET = 0.2

# Percentage of validation set out of the training dataset.
VAL_SET = 0.2

# Folder path associated with deep learning models
dl_models_folder = "../Deep_Learning_models/"
dl_metrics_folder = "../Deep_Learning_metrics/"
dl_weights_folder = "../Deep_Learning_weights/"
dl_cv_models_folder = "../Deep_Learning_CV/"
dl_cv_results_folder = "../Deep_Learning_CV_results/"

# Folder path associated with machine learning models
ml_models_folder = "../Machine_Learning_models/"
ml_models_results_folder = "../Machine_Learning_models_results/"

# Model names (Saved in h5 format)
cnn_model_name = f"cnn_v{DL_CNN_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"
transformer_vis_model_name = f"transformer_vision_v{DL_TRANSFORMER_VISION_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"

# Metric filenames
cnn_metrics_filename = f"metrics_{cnn_model_name}.json"
transformer_vis_metrics_filename = f"metrics_{transformer_vis_model_name}.json"

# Weight filenames
cnn_weights_filename = f"weights_{cnn_model_name}.json"
transformer_vis_weights_filename = f"weights_{transformer_vis_model_name}.json"


# Deep Learning models path
if DO_CNN:
    dl_model_path = os.path.join(
        dl_models_folder, cnn_model_name)
elif DO_TRANSFORMER_VISION:
    dl_model_path = os.path.join(
        dl_models_folder, transformer_vis_model_name)


# Deep Learning metrics path
if DO_CNN:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, cnn_metrics_filename)
elif DO_TRANSFORMER_VISION:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, transformer_vis_metrics_filename)


# Deep Learning weights path
if DO_CNN:
    dl_weights_path = os.path.join(
        dl_weights_folder, cnn_weights_filename)

elif DO_TRANSFORMER_VISION:
    dl_weights_path = os.path.join(
        dl_weights_folder, transformer_vis_weights_filename)

# %% [markdown]
# ## Tested - 0.9 val accuracy - v4 Aug data

# %%
def cnn_model_3(input_shape, num_classes):
    model = Sequential()
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu', kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.5))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate = 1e-4),
                  loss='sparse_categorical_crossentropy', metrics=['accuracy'])
       

    return model

# %%
# Apply median filter and background subtraction to the data
def apply_filters_and_background_subtraction(X):
    # Reshape the input data to a 2D array if necessary
    if len(X.shape) == 1:
        X = X.reshape((1, -1))
    
    # Apply median filter
    datamedfilt = scipy.ndimage.median_filter(X, size=(1, 5))
    
    # Apply airPLS for background subtraction
    baseline = np.zeros_like(datamedfilt)
    cols = baseline.shape[1]
    for col in range(cols):
        baseline[:, col] = airPLS(datamedfilt[:, col], lambda_=150)
    
    data_bksb = datamedfilt - baseline
    return datamedfilt

# %%
import pickle

def perform_cnn_cv(X_original, y_original, X_augmented, y_augmented, learning_rate, dropout_rate, l2_regularizer, 
                             n_splits=5, epochs=100, batch_size=32, cnn_version = 1, val_set = 0.2,
                             do_opt = False,apply_filters_bg_subtraction= True, models_folder = "models", results_folder = "results"):
    
    if not os.path.exists(models_folder):
        os.makedirs(models_folder)

    if not os.path.exists(results_folder):
        os.makedirs(results_folder)
        
        # Initialize variables for tracking the best model
    best_val_accuracy = 0
    best_model_filepath = ""
        
    accuracies = []
    test_losses = []
    test_accuracies = []
    
    # Initialize lists to store precision, recall, and F1 scores
    precisions = []
    recalls = []
    f1_scores = []
    
    # Initialize lists to store losses and accuracies for each epoch
    mean_training_losses = []
    mean_training_accuracies = []
    mean_val_losses = []   
    mean_val_accuracies = []
    
    # Initialize lists to store losses and accuracies for each epoch
    all_training_losses = []
    all_training_accuracies = []
    all_val_losses = []   
    all_val_accuracies = []
    
    fold = 1
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)
    skf_augmented = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)
    
    for train_index, _ in skf_augmented.split(X_augmented, y_augmented):
        # We are only interested in the train index for augmented data
        # Select the augmented data for training
        print("=" * 40)
        print(f"Fold: {fold}")
        print("Selecting the augmented data")
        
        X_train = X_augmented[train_index]
        y_train = y_augmented[train_index]
        
        X_ori = X_original
        
        if apply_filters_bg_subtraction:
            print("Apply Filters")
            X_train =  apply_filters_and_background_subtraction(X_train)
            X_ori =  apply_filters_and_background_subtraction(X_ori)
        
        # Standardize the data
        print("Standardizing the data")
        X_train, X_ori = standardize_data(X_train, X_ori)
        
        # Reshape the data
        print("Reshaping the data for deep learning models")
        X_train, X_ori = reshape_data(X_train, X_ori)
        
        # Input shape and number of classes for the model
        input_shape = (X_train.shape[1], 1)
        num_classes = len(np.unique(y_original))
        
        # Split a portion of the original data for validation and testing (stratified based on y_original)
        X_val, X_test, y_val, y_test = train_test_split(X_ori, y_original, test_size = 0.7, random_state = seed_value, stratify = y_original)
        
        print(f"X_train shape: {X_train.shape}")
        print(f"X_test shape: {X_test.shape}")
        print(f"X_val shape: {X_val.shape}")
        
        try:
            if do_opt:
                model = cnn_model_3(input_shape, num_classes)
#                 model = cnn_model_3(input_shape, num_classes, learning_rate, dropout_rate, l2_regularizer)
            else:
                model = cnn_model_3(input_shape, num_classes)
            if model is not None:
                print("Building the model 3 with the following hyperparameters:")
                print(f"Learning rate: {learning_rate}")
                print(f"Dropout rate: {dropout_rate}") 
                print(f"L2 Regularizer: {l2_regularizer}")
                print(f"Number of epochs: {epochs}")
                print(f"Batch size: {batch_size}")
                # model.summary()
            else:
                print("Failed to build the CNN model.")
        except Exception as e:
            print(f"Error while building the CNN model: {e}")
        
        print("Saving the data")
        fold_data = {

            'X_train': X_train,
            'X_val': X_val,
            'X_test': X_test,
            'y_train': y_train,
            'y_val': y_val,
            'y_test': y_test
        }

        with open(f"/kaggle/working/CV_CNN_fold_data/fold_{fold}_data.pkl", 'wb') as f:
            pickle.dump(fold_data, f)
        
        filepath = f'/kaggle/working/CV_CNN_models/temp_best_fold_{fold}.h5'
        # the ModelCheckpoint callback to save the best model of the current fold
        model_checkpoint_callback = ModelCheckpoint(
            filepath=os.path.join(filepath),
            save_best_only=True,
            monitor='val_accuracy',
            mode='max'
        )

        
        
        print("Training the model")
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val),
                           callbacks=[model_checkpoint_callback])
         # Check if this model is the best so far
        max_val_accuracy_this_fold = max(history.history['val_accuracy'])
        if max_val_accuracy_this_fold > best_val_accuracy:
            best_val_accuracy = max_val_accuracy_this_fold
            best_model_filepath = filepath
            
        if best_model_filepath:
            best_model = tf.keras.models.load_model(
                best_model_filepath,
#                 custom_objects={'loss': weighted_sparse_categorical_crossentropy(class_weights)}
            )
            print(f"The best model was loaded and ready to be evaluated")
        
        y_pred = np.argmax(model.predict(X_test), axis=-1)
        accuracy = accuracy_score(y_test, y_pred)
        test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
        
            # Calculate precision, recall, and F1 score
        precision = precision_score(y_test, y_pred, average='macro')
        recall = recall_score(y_test, y_pred, average='macro')
        f1 = f1_score(y_test, y_pred, average='macro')

        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")

        # Append the scores to the lists
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        
        all_training_losses.extend(history.history['loss'])
        all_training_accuracies.extend(history.history['accuracy'])
        all_val_losses.extend(history.history['val_loss'])
        all_val_accuracies.extend(history.history['val_accuracy'])
        
        # Append the losses and accuracies for each epoch to the respective lists
        for epoch in range(epochs):
            if fold == 1:
                # For the first fold, initialize the lists with the first fold's values
                mean_training_losses.append(history.history['loss'][epoch])
                mean_training_accuracies.append(history.history['accuracy'][epoch])
                mean_val_losses.append(history.history['val_loss'][epoch])
                mean_val_accuracies.append(history.history['val_accuracy'][epoch])
            else:
                # For subsequent folds, add the fold's values to the running sum
                mean_training_losses[epoch] += history.history['loss'][epoch]
                mean_training_accuracies[epoch] += history.history['accuracy'][epoch]
                mean_val_losses[epoch] += history.history['val_loss'][epoch]
                mean_val_accuracies[epoch] += history.history['val_accuracy'][epoch]

        # Save the model
        if do_opt:
            model_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.h5"
        else:
            model_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.h5"
        model_filepath = os.path.join(models_folder, f"fold_{fold}_split_{n_splits}_{model_filename}")
        model.save(model_filepath)

        # Save the results as a JSON file
        if do_opt:
            results_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            results_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filepath = os.path.join(results_folder, f"fold_{fold}_split_{n_splits}_{results_filename}")

        results = {
            "fold": fold,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1_scores": f1_scores,
            "test_loss": test_loss,
            "test_accuracy": test_accuracy,
            "training_loss": history.history['loss'],
            "training_accuracy": history.history['accuracy'],
            "validation_loss": history.history['val_loss'],
            "validation_accuracy": history.history['val_accuracy'],
        }

        with open(results_filepath, "w") as results_file:
            json.dump(results, results_file, indent=4)
        
        # Append the results to the lists
        accuracies.append(accuracy)
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        
        print(f"Fold {fold}, Accuracy: {accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
        print("=" * 40)
        fold += 1

    # At the end, divide the sums by the number of folds to get the mean
    mean_training_losses = [loss / n_splits for loss in mean_training_losses]
    mean_training_accuracies = [acc / n_splits for acc in mean_training_accuracies]
    mean_val_losses = [loss / n_splits for loss in mean_val_losses]
    mean_val_accuracies = [acc / n_splits for acc in mean_val_accuracies]
    # Convert lists to numpy arrays for easier calculation of mean and standard deviation
    mean_accuracy = np.mean(accuracies)
    mean_test_loss = np.mean(test_losses)
    mean_test_accuracy = np.mean(test_accuracies)
    
    mean_training_loss = np.mean(all_training_losses)
    std_training_loss = np.std(all_training_losses)
    mean_training_accuracy = np.mean(all_training_accuracies)
    std_training_accuracy = np.std(all_training_accuracies)

    mean_val_loss = np.mean(all_val_losses)
    std_val_loss = np.std(all_val_losses)
    mean_val_accuracy = np.mean(all_val_accuracies)
    std_val_accuracy = np.std(all_val_accuracies)

    # Calculate standard deviations
    std_accuracy = np.std(accuracies)
    std_test_loss = np.std(test_losses)
    std_test_accuracy = np.std(test_accuracies)

    std_training_loss = np.std(mean_training_losses)
    std_training_accuracy = np.std(mean_training_accuracies)
    std_val_loss = np.std(mean_val_losses)
    std_val_accuracy = np.std(mean_val_accuracies)

    precisions = np.array(precisions)
    recalls = np.array(recalls)
    f1_scores = np.array(f1_scores)

      
    print(f"test losses: {test_losses}")
    print(f"test accuracy: {test_accuracies}")
    
    print("*" * 40)
    print(f"Mean training loss over {n_splits}-fold cross-validation: {mean_training_loss:.4f}")
    print(f"Mean training accuracy over {n_splits}-fold cross-validation: {mean_training_accuracy:.4f}")
    print(f"Mean validation loss over {n_splits}-fold cross-validation: {mean_val_loss:.4f}")
    print(f"Mean validation accuracy over {n_splits}-fold cross-validation: {mean_val_accuracy:.4f}")
    print("*" * 40)
    print(f"Mean accuracy over stratified {n_splits}-fold cross-validation: {mean_accuracy:.4f}")
    print(f"Mean test loss over stratified {n_splits}-fold cross-validation: {mean_test_loss:.4f}")
    print(f"Mean test accuracy over stratified {n_splits}-fold cross-validation: {mean_test_accuracy:.4f}")
    
    print("*" * 40)
    print(f"Standard deviation of training loss over {n_splits}-fold cross-validation: {std_training_loss:.4f}")
    print(f"Standard deviation of training accuracy over {n_splits}-fold cross-validation: {std_training_accuracy:.4f}")
    print(f"Standard deviation of validation loss over {n_splits}-fold cross-validation: {std_val_loss:.4f}")
    print(f"Standard deviation of validation accuracy over {n_splits}-fold cross-validation: {std_val_accuracy:.4f}")
        
    print("*" * 40)
    print(f"Standard deviation of accuracy over stratified {n_splits}-fold cross-validation: {std_accuracy:.4f}")
    print(f"Standard deviation of test loss over stratified {n_splits}-fold cross-validation: {std_test_loss:.4f}")
    print(f"Standard deviation of test accuracy over stratified {n_splits}-fold cross-validation: {std_test_accuracy:.4f}")
    print("*" * 40)
    
    # Calculate and print the mean and standard deviation of precision, recall, and F1 score
    print(f"Mean precision over stratified {n_splits}-fold cross-validation: {np.mean(precisions):.4f}")
    print(f"Standard deviation of precision over stratified {n_splits}-fold cross-validation: {np.std(precisions):.4f}")
    print(f"Mean recall over stratified {n_splits}-fold cross-validation: {np.mean(recalls):.4f}")
    print(f"Standard deviation of recall over stratified {n_splits}-fold cross-validation: {np.std(recalls):.4f}")
    print(f"Mean F1 score over stratified {n_splits}-fold cross-validation: {np.mean(f1_scores):.4f}")
    print(f"Standard deviation of F1 score over stratified {n_splits}-fold cross-validation: {np.std(f1_scores):.4f}")

    
# Define the directory where the JSON files are stored

    fig, axes = plt.subplots(2, n_splits, figsize=(20, 10))

    for fold in range(1, n_splits+1):
        # Load the JSON file for this fold
        if do_opt:
            cnn_filename = f"cnn_v{cnn_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            cnn_filename = f"cnn_v{cnn_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filename = f"fold_{fold}_split_{n_splits}_{cnn_filename}"
        
        results_filepath = os.path.join(results_folder, results_filename)
        
        with open(results_filepath, "r") as results_file:
            results = json.load(results_file)
        
        # Plot training and validation loss
        axes[0, fold-1].plot(results["training_loss"], label='Train')
        axes[0, fold-1].plot(results["validation_loss"], label='Validation')
        axes[0, fold-1].set_title(f'Fold {fold} Loss')
        axes[0, fold-1].set_xlabel('Epochs')
        axes[0, fold-1].set_ylabel('Loss')
        axes[0, fold-1].legend()

        # Plot training and validation accuracy
        axes[1, fold-1].plot(results["training_accuracy"], label='Train')
        axes[1, fold-1].plot(results["validation_accuracy"], label='Validation')
        axes[1, fold-1].set_title(f'Fold {fold} Accuracy')
        axes[1, fold-1].set_xlabel('Epochs')
        axes[1, fold-1].set_ylabel('Accuracy')
        axes[1, fold-1].legend()

    plt.tight_layout()
    plt.show()

    return mean_val_accuracies

# %%
def extract_data_from_csv(filename="generated_data.csv"):
    # Read the CSV file into a DataFrame
    df_extracted = pd.read_csv(filename)
    
    # Split the DataFrame into features and labels
    X_extracted = df_extracted.drop(columns=["labels"]).values
    y_extracted = df_extracted["labels"].values
    
    return X_extracted, y_extracted

# %%
# With bksb, slope and roll set to true
test_data= "/kaggle/input/test-gen-cc-10x-v4/test-gen-cc-10x-v4.csv"

# No bksb, slope and roll set to false
train_data = "/kaggle/input/gen-cc-10x-v4/gen-cc-10x-v4.csv"

# %%
X_augmented, y_augmented = extract_data_from_csv(train_data)
print(f"X_augmented shaped: {X_augmented.shape}")
print(f"y_augmented shaped: {y_augmented.shape}")

X_original, y_original = extract_data_from_csv(test_data)
print(f"X_original shaped: {X_original.shape}")
print(f"y_original shaped: {y_original.shape}")
# Out:
# X_augmented shaped: (18980, 270)
# y_augmented shaped: (18980,)
# X_original shaped: (475, 270)
# y_original shaped: (475,)

# %%
DL_EPOCH = 80

if DO_CNN:
    # Start the timer
    start_time = time.time()
    learning_rate = 1e-4
    dropout_rate = 0.5
    l2_regularizer = 0.001
    perform_cnn_cv(X_original, y_original, X_augmented, y_augmented, learning_rate, dropout_rate, l2_regularizer,
                            n_splits=DL_CV_FOLD, epochs=DL_EPOCH, batch_size=DL_BATCH_SIZE, cnn_version=DL_CNN_VERSION,
                            do_opt=True, apply_filters_bg_subtraction= True, models_folder="/kaggle/working/CV_CNN_models", results_folder= "/kaggle/working/CV_CNN_results")
    # End the timer
    end_time = time.time()
    # Calculate the elapsed time
    elapsed_time = end_time - start_time
    # Print the elapsed time
    print("Training time: {:.2f} seconds".format(elapsed_time))

# Train the model
print("Training and evaluating the model...")
# Start the timer
start_time = time.time()
model_history = model.fit(X_train, y_train, batch_size=DL_BATCH_SIZE,
                          epochs=DL_EPOCH, validation_data=(X_val, y_val), shuffle=True, callbacks=callbacks)
# End the timer
end_time = time.time()
# Calculate the elapsed time
elapsed_time = end_time - start_time
# Print the elapsed time
print("Training time: {:.2f} seconds".format(elapsed_time))
# Compile the model

# Save the deep learning model
print("Saving model to ", dl_model_path)
model.save(dl_model_path)

# Save the deep learning model's weights
print("Saving model weights to ", dl_weights_path)
model.save_weights(dl_weights_path)

# Evaluating the model
print("Evaluating the CNN model... ")
# Calculate model loss and accuracy
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_accuracy)

# Save the model's metrics
print("Saving the model metrics to ", dl_metrics_path)
save_dl_metrics(model_history, test_loss,
                test_accuracy, dl_metrics_path)

# Plot the model history
plot_dl_history(model_history)
# Out:
# ========================================
# Fold: 1
# Selecting the augmented data
# Apply Filters
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 16s 8ms/step - loss: 2.4827 - accuracy: 0.3629 - val_loss: 1.6381 - val_accuracy: 0.4155
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.8907 - accuracy: 0.3821 - val_loss: 1.5378 - val_accuracy: 0.5211
# Epoch 3/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.7389 - accuracy: 0.3998 - val_loss: 1.5349 - val_accuracy: 0.5423
# Epoch 4/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.6671 - accuracy: 0.4023 - val_loss: 1.5017 - val_accuracy: 0.5423
# Epoch 5/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6270 - accuracy: 0.4135 - val_loss: 1.4766 - val_accuracy: 0.5704
# Epoch 6/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5976 - accuracy: 0.4273 - val_loss: 1.4468 - val_accuracy: 0.5915
# Epoch 7/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.5718 - accuracy: 0.4411 - val_loss: 1.4475 - val_accuracy: 0.5493
# Epoch 8/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5527 - accuracy: 0.4527 - val_loss: 1.4120 - val_accuracy: 0.5634
# Epoch 9/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5194 - accuracy: 0.4692 - val_loss: 1.3945 - val_accuracy: 0.5845
# Epoch 10/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4870 - accuracy: 0.4825 - val_loss: 1.3662 - val_accuracy: 0.5352
# Epoch 11/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4576 - accuracy: 0.5072 - val_loss: 1.3407 - val_accuracy: 0.5775
# Epoch 12/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.4119 - accuracy: 0.5358 - val_loss: 1.2724 - val_accuracy: 0.5704
# Epoch 13/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3718 - accuracy: 0.5529 - val_loss: 1.2475 - val_accuracy: 0.6056
# Epoch 14/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3208 - accuracy: 0.5807 - val_loss: 1.1938 - val_accuracy: 0.6197
# Epoch 15/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2655 - accuracy: 0.6060 - val_loss: 1.1725 - val_accuracy: 0.6620
# Epoch 16/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2337 - accuracy: 0.6234 - val_loss: 1.1330 - val_accuracy: 0.6620
# Epoch 17/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1918 - accuracy: 0.6394 - val_loss: 1.1207 - val_accuracy: 0.6761
# Epoch 18/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.1594 - accuracy: 0.6499 - val_loss: 1.0871 - val_accuracy: 0.6549
# Epoch 19/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1325 - accuracy: 0.6623 - val_loss: 1.0965 - val_accuracy: 0.6056
# Epoch 20/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0998 - accuracy: 0.6739 - val_loss: 1.0326 - val_accuracy: 0.6831
# Epoch 21/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0517 - accuracy: 0.6900 - val_loss: 1.0178 - val_accuracy: 0.6831
# Epoch 22/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0312 - accuracy: 0.6956 - val_loss: 1.0070 - val_accuracy: 0.6831
# Epoch 23/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0031 - accuracy: 0.7048 - val_loss: 0.9654 - val_accuracy: 0.6972
# Epoch 24/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.9740 - accuracy: 0.7117 - val_loss: 0.9616 - val_accuracy: 0.6972
# Epoch 25/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9471 - accuracy: 0.7220 - val_loss: 0.9583 - val_accuracy: 0.7324
# Epoch 26/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9207 - accuracy: 0.7358 - val_loss: 0.9228 - val_accuracy: 0.7394
# Epoch 27/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9054 - accuracy: 0.7387 - val_loss: 0.9143 - val_accuracy: 0.7817
# Epoch 28/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8770 - accuracy: 0.7491 - val_loss: 0.8693 - val_accuracy: 0.7746
# Epoch 29/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8571 - accuracy: 0.7553 - val_loss: 0.8760 - val_accuracy: 0.7324
# Epoch 30/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.8432 - accuracy: 0.7580 - val_loss: 0.8621 - val_accuracy: 0.7676
# Epoch 31/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8148 - accuracy: 0.7696 - val_loss: 0.8566 - val_accuracy: 0.8099
# Epoch 32/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.
80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4634 - accuracy: 0.8757 - val_loss: 0.6798 - val_accuracy: 0.7817
# Epoch 63/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4628 - accuracy: 0.8791 - val_loss: 0.6831 - val_accuracy: 0.7958
# Epoch 64/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4548 - accuracy: 0.8800 - val_loss: 0.6685 - val_accuracy: 0.8169
# Epoch 65/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4500 - accuracy: 0.8804 - val_loss: 0.6500 - val_accuracy: 0.8099
# Epoch 66/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4431 - accuracy: 0.8826 - val_loss: 0.6830 - val_accuracy: 0.7887
# Epoch 67/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4428 - accuracy: 0.8828 - val_loss: 0.6558 - val_accuracy: 0.7746
# Epoch 68/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4284 - accuracy: 0.8903 - val_loss: 0.6680 - val_accuracy: 0.7958
# Epoch 69/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4335 - accuracy: 0.8865 - val_loss: 0.6942 - val_accuracy: 0.7958
# Epoch 70/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4262 - accuracy: 0.8891 - val_loss: 0.7046 - val_accuracy: 0.7817
# Epoch 71/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4190 - accuracy: 0.8898 - val_loss: 0.6990 - val_accuracy: 0.7958
# Epoch 72/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4123 - accuracy: 0.8945 - val_loss: 0.7020 - val_accuracy: 0.8028
# Epoch 73/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4140 - accuracy: 0.8913 - val_loss: 0.6933 - val_accuracy: 0.7958
# Epoch 74/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4069 - accuracy: 0.8954 - val_loss: 0.6705 - val_accuracy: 0.8310
# Epoch 75/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4053 - accuracy: 0.8954 - val_loss: 0.6444 - val_accuracy: 0.8310
# Epoch 76/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3970 - accuracy: 0.8982 - val_loss: 0.6888 - val_accuracy: 0.8099
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3962 - accuracy: 0.8979 - val_loss: 0.6875 - val_accuracy: 0.7958
# Epoch 78/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3886 - accuracy: 0.9020 - val_loss: 0.6666 - val_accuracy: 0.8099
# Epoch 79/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3868 - accuracy: 0.9023 - val_loss: 0.7044 - val_accuracy: 0.7887
# Epoch 80/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3795 - accuracy: 0.9032 - val_loss: 0.6844 - val_accuracy: 0.8169
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 13ms/step
# Precision: 0.7890
# Recall: 0.7899
# F1 Score: 0.7893
# Fold 1, Accuracy: 0.7958, Test Loss: 0.5968, Test Accuracy: 0.7958
# ========================================
# ========================================
# Fold: 2
# Selecting the augmented data
# Apply Filters
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 7s 8ms/step - loss: 2.2906 - accuracy: 0.3640 - val_loss: 1.5480 - val_accuracy: 0.5070
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.8141 - accuracy: 0.3850 - val_loss: 1.5334 - val_accuracy: 0.4789
# Epoch 3/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.7047 - accuracy: 0.3930 - val_loss: 1.5230 - val_accuracy: 0.4718
# Epoch 4/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.6572 - accuracy: 0.4022 - val_loss: 1.4939 - val_accuracy: 0.5000
# Epoch 5/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1
80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4509 - accuracy: 0.8774 - val_loss: 0.6838 - val_accuracy: 0.7746
# Epoch 66/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4398 - accuracy: 0.8780 - val_loss: 0.6645 - val_accuracy: 0.8099
# Epoch 67/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4468 - accuracy: 0.8799 - val_loss: 0.6946 - val_accuracy: 0.7958
# Epoch 68/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4318 - accuracy: 0.8855 - val_loss: 0.6799 - val_accuracy: 0.8028
# Epoch 69/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4279 - accuracy: 0.8842 - val_loss: 0.6885 - val_accuracy: 0.8099
# Epoch 70/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4286 - accuracy: 0.8833 - val_loss: 0.6879 - val_accuracy: 0.8028
# Epoch 71/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4221 - accuracy: 0.8887 - val_loss: 0.6728 - val_accuracy: 0.8099
# Epoch 72/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4167 - accuracy: 0.8880 - val_loss: 0.6623 - val_accuracy: 0.7887
# Epoch 73/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4034 - accuracy: 0.8934 - val_loss: 0.6787 - val_accuracy: 0.8169
# Epoch 74/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4039 - accuracy: 0.8903 - val_loss: 0.6682 - val_accuracy: 0.8169
# Epoch 75/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3982 - accuracy: 0.8931 - val_loss: 0.6846 - val_accuracy: 0.8169
# Epoch 76/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4026 - accuracy: 0.8929 - val_loss: 0.6577 - val_accuracy: 0.8028
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3997 - accuracy: 0.8940 - val_loss: 0.6298 - val_accuracy: 0.8099
# Epoch 78/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3910 - accuracy: 0.8996 - val_loss: 0.6561 - val_accuracy: 0.7958
# Epoch 79/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3849 - accuracy: 0.8998 - val_loss: 0.6612 - val_accuracy: 0.7817
# Epoch 80/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3855 - accuracy: 0.8994 - val_loss: 0.6586 - val_accuracy: 0.8310
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 2ms/step
# Precision: 0.7853
# Recall: 0.7870
# F1 Score: 0.7860
# Fold 2, Accuracy: 0.7928, Test Loss: 0.6340, Test Accuracy: 0.7928
# ========================================
# ========================================
# Fold: 3
# Selecting the augmented data
# Apply Filters
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 7s 7ms/step - loss: 2.4532 - accuracy: 0.3639 - val_loss: 1.5828 - val_accuracy: 0.4859
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.8588 - accuracy: 0.3777 - val_loss: 1.5050 - val_accuracy: 0.5141
# Epoch 3/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.7203 - accuracy: 0.3913 - val_loss: 1.4822 - val_accuracy: 0.5282
# Epoch 4/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.6533 - accuracy: 0.4010 - val_loss: 1.4789 - val_accuracy: 0.5282
# Epoch 5/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.6195 - accuracy: 0.4081 - val_loss: 1.4644 - val_accuracy: 0.5211
# Epoch 6/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.5933 - accuracy: 0.4246 - val_loss: 1.4389 - val_accuracy: 0.4930
# Epoch 7/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5746 - accuracy: 0.4288 - val_loss: 1.4310 - val_accuracy: 0.5070
# Epoch 8/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.5498 - accuracy: 0.4398 - val_loss: 1.4281 - val_accuracy: 0.5000
# Epoch 9/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5247 - accuracy: 0.4510 - val_loss: 1.3946 - val_accuracy: 0.5070
# Epoch 10/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5035 - accuracy: 0.4633 - val_loss: 1.4059 - val_accuracy: 0.5352
# Epoch 11/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.4791 - accuracy: 0.4683 - val_loss: 1.3643 - val_accuracy: 0.5282
# Epoch 12/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4505 - accuracy: 0.4812 - val_loss: 1.3941 - val_accuracy: 0.5000
# Epoch 13/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4140 - accuracy: 0.5039 - val_loss: 1.3181 - val_accuracy: 0.5423
# Epoch 14/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3766 - accuracy: 0.5207 - val_loss: 1.2841 - val_accuracy: 0.5563
# Epoch 15/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3347 - accuracy: 0.5454 - val_loss: 1.2343 - val_accuracy: 0.5775
# Epoch 16/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2702 - accuracy: 0.5798 - val_loss: 1.1823 - val_accuracy: 0.6690
# Epoch 17/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2205 - accuracy: 0.6065 - val_loss: 1.1319 - val_accuracy: 0.6690
# Epoch 18/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.1736 - accuracy: 0.6339 - val_loss: 1.1139 - val_accuracy: 0.6620
# Epoch 19/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1252 - accuracy: 0.6475 - val_loss: 1.0407 - val_accuracy: 0.6761
# Epoch 20/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0778 - accuracy: 0.6704 - val_loss: 1.0191 - val_accuracy: 0.6831
# Epoch 21/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0523 - accuracy: 0.6775 - val_loss: 0.9962 - val_accuracy: 0.6972
# Epoch 22/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0181 - accuracy: 0.6897 - val_loss: 0.9943 - val_accuracy: 0.6831
# Epoch 23/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9753 - accuracy: 0.7089 - val_loss: 0.9375 - val_accuracy: 0.7183
# Epoch 24/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9517 - accuracy: 0.7158 - val_loss: 0.9279 - val_accuracy: 0.7113
# Epoch 25/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9210 - accuracy: 0.7178 - val_loss: 0.9138 - val_accuracy: 0.7394
# Epoch 26/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9026 - accuracy: 0.7341 - val_loss: 0.8880 - val_accuracy: 0.7676
# Epoch 27/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8827 - accuracy: 0.7355 - val_loss: 0.8793 - val_accuracy: 0.7394
# Epoch 28/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8718 - accuracy: 0.7405 - val_loss: 0.8620 - val_accuracy: 0.7254
# Epoch 29/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8333 - accuracy: 0.7509 - val_loss: 0.8416 - val_accuracy: 0.7817
# Epoch 30/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.8245 - accuracy: 0.7522 - val_loss: 0.8251 - val_accuracy: 0.7817
# Epoch 31/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.7992 - accuracy: 0.7625 - val_loss: 0.8316 - val_accuracy: 0.7746
# Epoch 32/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7825 - accuracy: 0.7720 - val_loss: 0.8098 - val_accuracy: 0.8099
# Epoch 33/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7659 - accuracy: 0.7777 - val_loss: 0.8325 - val_accuracy: 0.7676
# Epoch 34/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.7490 - accuracy: 0.7803 - val_loss: 0.7807 - val_accuracy: 0.8028
# Epoch 35/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7304 - accuracy: 0.7829 - val_loss: 0.7803 - val_accuracy: 0.7746
# Epoch 36/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.7184 - accuracy: 0.7889 - val_loss: 0.7826 - val_accuracy: 0.8028
# Epoch 37/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7084 - accuracy: 0.7927 - val_loss: 0.7662 - val_accuracy: 0.8239
# Epoch 38/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.
80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4250 - accuracy: 0.8897 - val_loss: 0.6789 - val_accuracy: 0.7887
# Epoch 69/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4217 - accuracy: 0.8899 - val_loss: 0.6264 - val_accuracy: 0.8099
# Epoch 70/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4220 - accuracy: 0.8903 - val_loss: 0.6531 - val_accuracy: 0.8239
# Epoch 71/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4157 - accuracy: 0.8925 - val_loss: 0.6501 - val_accuracy: 0.8169
# Epoch 72/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4132 - accuracy: 0.8949 - val_loss: 0.6618 - val_accuracy: 0.8028
# Epoch 73/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4127 - accuracy: 0.8944 - val_loss: 0.6855 - val_accuracy: 0.7958
# Epoch 74/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3952 - accuracy: 0.9006 - val_loss: 0.6782 - val_accuracy: 0.8028
# Epoch 75/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3975 - accuracy: 0.8983 - val_loss: 0.6722 - val_accuracy: 0.8099
# Epoch 76/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3951 - accuracy: 0.8992 - val_loss: 0.6666 - val_accuracy: 0.7817
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3951 - accuracy: 0.8981 - val_loss: 0.6993 - val_accuracy: 0.7958
# Epoch 78/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3809 - accuracy: 0.9058 - val_loss: 0.6644 - val_accuracy: 0.8028
# Epoch 79/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3769 - accuracy: 0.9019 - val_loss: 0.7116 - val_accuracy: 0.8169
# Epoch 80/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3758 - accuracy: 0.9052 - val_loss: 0.6731 - val_accuracy: 0.8239
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 2ms/step
# Precision: 0.7796
# Recall: 0.7821
# F1 Score: 0.7787
# Fold 3, Accuracy: 0.7838, Test Loss: 0.6480, Test Accuracy: 0.7838
# ========================================
# ========================================
# Fold: 4
# Selecting the augmented data
# Apply Filters
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 7s 7ms/step - loss: 2.3266 - accuracy: 0.3619 - val_loss: 1.5509 - val_accuracy: 0.5000
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.8190 - accuracy: 0.3854 - val_loss: 1.5206 - val_accuracy: 0.5141
# Epoch 3/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6926 - accuracy: 0.3972 - val_loss: 1.5464 - val_accuracy: 0.5141
# Epoch 4/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6444 - accuracy: 0.4098 - val_loss: 1.5607 - val_accuracy: 0.4577
# Epoch 5/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6138 - accuracy: 0.4145 - val_loss: 1.4946 - val_accuracy: 0.5070
# Epoch 6/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5852 - accuracy: 0.4254 - val_loss: 1.5202 - val_accuracy: 0.4859
# Epoch 7/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5615 - accuracy: 0.4422 - val_loss: 1.4756 - val_accuracy: 0.5070
# Epoch 8/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5367 - accuracy: 0.4429 - val_loss: 1.4259 - val_accuracy: 0.5141
# Epoch 9/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5164 - accuracy: 0.4570 - val_loss: 1.4089 - val_accuracy: 0.5352
# Epoch 10/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4879 - accuracy: 0.4660 - val_loss: 1.3976 - val_accuracy: 0.5352
# Epoch 11/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4590 - accuracy: 0.4767 - val_loss: 1.3683 - val_accuracy: 0.5211
# Epoch 12/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4311 - accuracy: 0.4937 - val_loss: 1.3322 - val_accuracy: 0.5563
# Epoch 13/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3981 - accuracy: 0.5060 - val_loss: 1.3250 - val_accuracy: 0.5563
# Epoch 14/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3617 - accuracy: 0.5254 - val_loss: 1.2657 - val_accuracy: 0.5775
# Epoch 15/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3184 - accuracy: 0.5483 - val_loss: 1.2321 - val_accuracy: 0.6197
# Epoch 16/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2660 - accuracy: 0.5817 - val_loss: 1.1924 - val_accuracy: 0.6479
# Epoch 17/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2180 - accuracy: 0.6064 - val_loss: 1.1337 - val_accuracy: 0.6972
# Epoch 18/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1717 - accuracy: 0.6247 - val_loss: 1.1147 - val_accuracy: 0.6690
# Epoch 19/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1216 - accuracy: 0.6508 - val_loss: 1.0683 - val_accuracy: 0.6831
# Epoch 20/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0916 - accuracy: 0.6615 - val_loss: 1.0299 - val_accuracy: 0.6901
# Epoch 21/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0488 - accuracy: 0.6785 - val_loss: 0.9958 - val_accuracy: 0.7042
# Epoch 22/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0143 - accuracy: 0.6925 - val_loss: 0.9685 - val_accuracy: 0.7113
# Epoch 23/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9883 - accuracy: 0.7018 - val_loss: 0.9553 - val_accuracy: 0.7113
# Epoch 24/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9582 - accuracy: 0.7139 - val_loss: 0.9230 - val_accuracy: 0.7254
# Epoch 25/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9337 - accuracy: 0.7198 - val_loss: 0.9124 - val_accuracy: 0.7324
# Epoch 26/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8966 - accuracy: 0.7315 - val_loss: 0.8903 - val_accuracy: 0.7606
# Epoch 27/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8777 - accuracy: 0.7408 - val_loss: 0.8906 - val_accuracy: 0.7676
# Epoch 28/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8542 - accuracy: 0.7438 - val_loss: 0.8869 - val_accuracy: 0.7746
# Epoch 29/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.8374 - accuracy: 0.7505 - val_loss: 0.8656 - val_accuracy: 0.7676
# Epoch 30/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8087 - accuracy: 0.7595 - val_loss: 0.8447 - val_accuracy: 0.7958
# Epoch 31/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7908 - accuracy: 0.7655 - val_loss: 0.8348 - val_accuracy: 0.8028
# Epoch 32/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7764 - accuracy: 0.7686 - val_loss: 0.8418 - val_accuracy: 0.7817
# Epoch 33/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7578 - accuracy: 0.7762 - val_loss: 0.7988 - val_accuracy: 0.8380
# Epoch 34/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7409 - accuracy: 0.7825 - val_loss: 0.8132 - val_accuracy: 0.8028
# Epoch 35/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7248 - accuracy: 0.7883 - val_loss: 0.8022 - val_accuracy: 0.8169
# Epoch 36/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7211 - accuracy: 0.7848 - val_loss: 0.7848 - val_accuracy: 0.8099
# Epoch 37/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.6932 - accuracy: 0.7938 - val_loss: 0.7689 - val_accuracy: 0.8099
# Epoch 38/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6805 - accuracy: 0.8045 - val_loss: 0.7630 - val_accuracy: 0.8239
# Epoch 39/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6640 - accuracy: 0.8054 - val_loss: 0.7266 - val_accuracy: 0.8099
# Epoch 40/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6593 - accuracy: 0.8065 - val_loss: 0.7290 - val_accuracy: 0.8099
# Epoch 41/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.
80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4147 - accuracy: 0.8918 - val_loss: 0.6238 - val_accuracy: 0.8310
# Epoch 72/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4139 - accuracy: 0.8901 - val_loss: 0.6480 - val_accuracy: 0.7958
# Epoch 73/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4105 - accuracy: 0.8936 - val_loss: 0.6180 - val_accuracy: 0.8028
# Epoch 74/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4061 - accuracy: 0.8924 - val_loss: 0.6224 - val_accuracy: 0.7958
# Epoch 75/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4004 - accuracy: 0.8956 - val_loss: 0.6513 - val_accuracy: 0.8169
# Epoch 76/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3930 - accuracy: 0.8975 - val_loss: 0.6306 - val_accuracy: 0.8169
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3940 - accuracy: 0.8952 - val_loss: 0.6652 - val_accuracy: 0.8310
# Epoch 78/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3914 - accuracy: 0.8966 - val_loss: 0.6727 - val_accuracy: 0.8028
# Epoch 79/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3927 - accuracy: 0.8942 - val_loss: 0.6536 - val_accuracy: 0.8380
# Epoch 80/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3777 - accuracy: 0.9040 - val_loss: 0.6464 - val_accuracy: 0.8592
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 2ms/step
# Precision: 0.7805
# Recall: 0.7846
# F1 Score: 0.7780
# Fold 4, Accuracy: 0.7808, Test Loss: 0.6624, Test Accuracy: 0.7808
# ========================================
# ========================================
# Fold: 5
# Selecting the augmented data
# Apply Filters
# Standardizing the data
# Reshaping the data for deep learning models
# X_train shape: (15184, 270, 1)
# X_test shape: (333, 270, 1)
# X_val shape: (142, 270, 1)
# Building the model 3 with the following hyperparameters:
# Learning rate: 0.0001
# Dropout rate: 0.5
# L2 Regularizer: 0.001
# Number of epochs: 80
# Batch size: 32
# Saving the data
# Training the model
# Epoch 1/80
# 475/475 [==============================] - 7s 7ms/step - loss: 2.2261 - accuracy: 0.3640 - val_loss: 1.5607 - val_accuracy: 0.5070
# Epoch 2/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.7949 - accuracy: 0.3874 - val_loss: 1.5435 - val_accuracy: 0.5423
# Epoch 3/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6968 - accuracy: 0.3946 - val_loss: 1.5334 - val_accuracy: 0.5563
# Epoch 4/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6486 - accuracy: 0.4075 - val_loss: 1.5185 - val_accuracy: 0.5423
# Epoch 5/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.6212 - accuracy: 0.4190 - val_loss: 1.5033 - val_accuracy: 0.5493
# Epoch 6/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5832 - accuracy: 0.4366 - val_loss: 1.4630 - val_accuracy: 0.5563
# Epoch 7/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.5672 - accuracy: 0.4452 - val_loss: 1.4557 - val_accuracy: 0.5563
# Epoch 8/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5365 - accuracy: 0.4542 - val_loss: 1.4282 - val_accuracy: 0.5704
# Epoch 9/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.5145 - accuracy: 0.4669 - val_loss: 1.4283 - val_accuracy: 0.5000
# Epoch 10/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.4878 - accuracy: 0.4757 - val_loss: 1.3780 - val_accuracy: 0.5070
# Epoch 11/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.4594 - accuracy: 0.4922 - val_loss: 1.3769 - val_accuracy: 0.5352
# Epoch 12/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.4169 - accuracy: 0.5121 - val_loss: 1.3228 - val_accuracy: 0.5704
# Epoch 13/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3839 - accuracy: 0.5291 - val_loss: 1.2927 - val_accuracy: 0.5845
# Epoch 14/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.3410 - accuracy: 0.5490 - val_loss: 1.2510 - val_accuracy: 0.6479
# Epoch 15/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2893 - accuracy: 0.5786 - val_loss: 1.2097 - val_accuracy: 0.6056
# Epoch 16/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.2462 - accuracy: 0.6073 - val_loss: 1.1671 - val_accuracy: 0.6549
# Epoch 17/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.1966 - accuracy: 0.6236 - val_loss: 1.1297 - val_accuracy: 0.6549
# Epoch 18/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1495 - accuracy: 0.6477 - val_loss: 1.0854 - val_accuracy: 0.6690
# Epoch 19/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.1219 - accuracy: 0.6577 - val_loss: 1.0548 - val_accuracy: 0.6831
# Epoch 20/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.0807 - accuracy: 0.6694 - val_loss: 1.0235 - val_accuracy: 0.6549
# Epoch 21/80
# 475/475 [==============================] - 3s 6ms/step - loss: 1.0528 - accuracy: 0.6771 - val_loss: 1.0029 - val_accuracy: 0.6761
# Epoch 22/80
# 475/475 [==============================] - 3s 7ms/step - loss: 1.0135 - accuracy: 0.6951 - val_loss: 1.0049 - val_accuracy: 0.6901
# Epoch 23/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9886 - accuracy: 0.7028 - val_loss: 0.9640 - val_accuracy: 0.7183
# Epoch 24/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9548 - accuracy: 0.7154 - val_loss: 0.9555 - val_accuracy: 0.7535
# Epoch 25/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9404 - accuracy: 0.7177 - val_loss: 0.8842 - val_accuracy: 0.7183
# Epoch 26/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.9144 - accuracy: 0.7214 - val_loss: 0.8814 - val_accuracy: 0.7606
# Epoch 27/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.8900 - accuracy: 0.7354 - val_loss: 0.8410 - val_accuracy: 0.7606
# Epoch 28/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8682 - accuracy: 0.7438 - val_loss: 0.8271 - val_accuracy: 0.8099
# Epoch 29/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8409 - accuracy: 0.7492 - val_loss: 0.8941 - val_accuracy: 0.7606
# Epoch 30/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.8266 - accuracy: 0.7536 - val_loss: 0.8053 - val_accuracy: 0.8169
# Epoch 31/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.8070 - accuracy: 0.7614 - val_loss: 0.8118 - val_accuracy: 0.8028
# Epoch 32/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7888 - accuracy: 0.7646 - val_loss: 0.7728 - val_accuracy: 0.8169
# Epoch 33/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7806 - accuracy: 0.7677 - val_loss: 0.7579 - val_accuracy: 0.8028
# Epoch 34/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7646 - accuracy: 0.7705 - val_loss: 0.7589 - val_accuracy: 0.8239
# Epoch 35/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7397 - accuracy: 0.7766 - val_loss: 0.7666 - val_accuracy: 0.8239
# Epoch 36/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.7208 - accuracy: 0.7855 - val_loss: 0.7327 - val_accuracy: 0.8310
# Epoch 37/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.7151 - accuracy: 0.7914 - val_loss: 0.7457 - val_accuracy: 0.8239
# Epoch 38/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6982 - accuracy: 0.7911 - val_loss: 0.7491 - val_accuracy: 0.8169
# Epoch 39/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.6817 - accuracy: 0.7987 - val_loss: 0.6983 - val_accuracy: 0.8310
# Epoch 40/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6768 - accuracy: 0.8012 - val_loss: 0.6911 - val_accuracy: 0.8380
# Epoch 41/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6580 - accuracy: 0.8098 - val_loss: 0.6874 - val_accuracy: 0.8310
# Epoch 42/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.6493 - accuracy: 0.8074 - val_loss: 0.6905 - val_accuracy: 0.8239
# Epoch 43/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.
80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4191 - accuracy: 0.8871 - val_loss: 0.5907 - val_accuracy: 0.8310
# Epoch 74/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.4098 - accuracy: 0.8927 - val_loss: 0.6189 - val_accuracy: 0.8380
# Epoch 75/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.4060 - accuracy: 0.8930 - val_loss: 0.6550 - val_accuracy: 0.8028
# Epoch 76/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3988 - accuracy: 0.8940 - val_loss: 0.6194 - val_accuracy: 0.8239
# Epoch 77/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3963 - accuracy: 0.8971 - val_loss: 0.6049 - val_accuracy: 0.8310
# Epoch 78/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3975 - accuracy: 0.8932 - val_loss: 0.5844 - val_accuracy: 0.8521
# Epoch 79/80
# 475/475 [==============================] - 3s 6ms/step - loss: 0.3825 - accuracy: 0.9025 - val_loss: 0.6452 - val_accuracy: 0.8169
# Epoch 80/80
# 475/475 [==============================] - 3s 7ms/step - loss: 0.3866 - accuracy: 0.9016 - val_loss: 0.6512 - val_accuracy: 0.8310
# The best model was loaded and ready to be evaluated
# 11/11 [==============================] - 0s 2ms/step
# Precision: 0.7940
# Recall: 0.7982
# F1 Score: 0.7946
# Fold 5, Accuracy: 0.7988, Test Loss: 0.6010, Test Accuracy: 0.7988
# ========================================
# test losses: [0.5967836976051331, 0.6339938640594482, 0.6479905247688293, 0.6624122858047485, 0.6010215878486633]
# test accuracy: [0.7957957983016968, 0.792792797088623, 0.7837837934494019, 0.7807807922363281, 0.7987987995147705]
# ****************************************
# Mean training loss over 5-fold cross-validation: 0.8232
# Mean training accuracy over 5-fold cross-validation: 0.7466
# Mean validation loss over 5-fold cross-validation: 0.8835
# Mean validation accuracy over 5-fold cross-validation: 0.7436
# ****************************************
# Mean accuracy over stratified 5-fold cross-validation: 0.7904
# Mean test loss over stratified 5-fold cross-validation: 0.6284
# Mean test accuracy over stratified 5-fold cross-validation: 0.7904
# ****************************************
# Standard deviation of training loss over 5-fold cross-validation: 0.4369
# Standard deviation of training accuracy over 5-fold cross-validation: 0.1587
# Standard deviation of validation loss over 5-fold cross-validation: 0.2867
# Standard deviation of validation accuracy over 5-fold cross-validation: 0.1068
# ****************************************
# Standard deviation of accuracy over stratified 5-fold cross-validation: 0.0070
# Standard deviation of test loss over stratified 5-fold cross-validation: 0.0258
# Standard deviation of test accuracy over stratified 5-fold cross-validation: 0.0070
# ****************************************
# Mean precision over stratified 5-fold cross-validation: 0.7857
# Standard deviation of precision over stratified 5-fold cross-validation: 0.0054
# Mean recall over stratified 5-fold cross-validation: 0.7884
# Standard deviation of recall over stratified 5-fold cross-validation: 0.0055
# Mean F1 score over stratified 5-fold cross-validation: 0.7853
# Standard deviation of F1 score over stratified 5-fold cross-validation: 0.0063
# Training time: 1350.87 seconds
# Training and evaluating the model...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 23
#      21 # Start the timer
#      22 start_time = time.time()
# ---> 23 model_history = model.fit(X_train, y_train, batch_size=DL_BATCH_SIZE,
#      24                           epochs=DL_EPOCH, validation_data=(X_val, y_val), shuffle=True, callbacks=callbacks)
#      25 # End the timer
#      26 end_time = time.time()
#
# NameError: name 'model' is not defined
