# %%
# %cd /kaggle/input/chemcancer-v2/src/
# %mkdir /kaggle/working/Deep_Learning_metrics/
# %mkdir /kaggle/working/During_train/
# %mkdir /kaggle/working/CV_VIT_models
# %mkdir /kaggle/working/CV_VIT_results
# %mkdir /kaggle/working/CV_fold_data
# Out:
# /kaggle/input/chemcancer-v2/src

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tensorflow.keras.optimizers import Adam
from data import *
from machine_learning_models import *
from deep_learning_models import *
from vision_transformer import *
from utils_dl_model import *
from utils_ml_model import print_ml_results
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
# Set the seed value.
SEED = 7
np.random.seed(SEED)

# Deep Learning parameters
DL_EPOCH = 250
DL_BATCH_SIZE = 32
DL_CNN_VERSION = 3
DL_TRANSFORMER_VISION_VERSION = 14
DL_CV_FOLD = 5

DO_DL = True
CV_DL = True
OPT_DL = False

DO_CNN = False
DO_TRANSFORMER_VISION = True
DO_ML = False

# Percentage of test set out of the dataset.
TEST_SET = 0.2

# Percentage of validation set out of the training dataset.
VAL_SET = 0.2

# Folder path associated with deep learning models
dl_models_folder = "../Deep_Learning_models/"
dl_metrics_folder = "../Deep_Learning_metrics/"
dl_weights_folder = "../Deep_Learning_weights/"
dl_cv_models_folder = "../Deep_Learning_CV/"
dl_cv_results_folder = "../Deep_Learning_CV_results/"

# Folder path associated with machine learning models
ml_models_folder = "../Machine_Learning_models/"
ml_models_results_folder = "../Machine_Learning_models_results/"

# Model names (Saved in h5 format)
cnn_model_name = f"cnn_v{DL_CNN_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"
transformer_vis_model_name = f"transformer_vision_v{DL_TRANSFORMER_VISION_VERSION}_{DL_BATCH_SIZE}_{DL_EPOCH}_seed_{SEED}.h5"

# Metric filenames
cnn_metrics_filename = f"metrics_{cnn_model_name}.json"
transformer_vis_metrics_filename = f"metrics_{transformer_vis_model_name}.json"

# Weight filenames
cnn_weights_filename = f"weights_{cnn_model_name}.json"
transformer_vis_weights_filename = f"weights_{transformer_vis_model_name}.json"


# Deep Learning models path
if DO_CNN:
    dl_model_path = os.path.join(
        dl_models_folder, cnn_model_name)
elif DO_TRANSFORMER_VISION:
    dl_model_path = os.path.join(
        dl_models_folder, transformer_vis_model_name)


# Deep Learning metrics path
if DO_CNN:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, cnn_metrics_filename)
elif DO_TRANSFORMER_VISION:
    dl_metrics_path = os.path.join(
        dl_metrics_folder, transformer_vis_metrics_filename)


# Deep Learning weights path
if DO_CNN:
    dl_weights_path = os.path.join(
        dl_weights_folder, cnn_weights_filename)

elif DO_TRANSFORMER_VISION:
    dl_weights_path = os.path.join(
        dl_weights_folder, transformer_vis_weights_filename)

# %%
def load_extract_data(data_file):
    # Load the data
    print("Load the data")
    data = load_data(data_file)
    print(f"Data shape : {data.shape}")

    # Extract the feature and target data
    print("Extract the feature and target data")
    X, y = extract_data(data)
    print(f"X shaped: {X.shape}")
    print(f"y shaped: {y.shape}")

    return X, y

def extract_data_from_csv(filename="generated_data.csv"):
    # Read the CSV file into a DataFrame
    df_extracted = pd.read_csv(filename)
    
    # Split the DataFrame into features and labels
    X_extracted = df_extracted.drop(columns=["labels"]).values
    y_extracted = df_extracted["labels"].values
    
    return X_extracted, y_extracted

# %%
# Apply median filter and background subtraction to the data
def apply_filters_and_background_subtraction(X):
    # Reshape the input data to a 2D array if necessary
    if len(X.shape) == 1:
        X = X.reshape((1, -1))
    
    # Apply median filter
    datamedfilt = scipy.ndimage.median_filter(X, size=(1, 5))
    
    # Apply airPLS for background subtraction
    baseline = np.zeros_like(datamedfilt)
    cols = baseline.shape[1]
    for col in range(cols):
        baseline[:, col] = airPLS(datamedfilt[:, col], lambda_=150)
    
    data_bksb = datamedfilt - baseline
    return datamedfilt

# %%
# With bksb, slope and roll set to true
data_file= "/kaggle/input/chemcancer-v2/Data/HC05_HC07.csv"

# %%
# Load the data
print("Load the data")
data = load_data(data_file)
print(f"Data shape : {data.shape}")

# Extract the feature and target data
print("Extract the feature and target data")
X, y = extract_data(data)
print(f"X shaped: {X.shape}")
print(f"y shaped: {y.shape}")
# Out:
# Load the data
# Data shape : (2373, 274)
# Extract the feature and target data
# X shaped: (2373, 270)
# y shaped: (2373,)

# %%
import pickle

def perform_vit_cross_validation(X, y, patch_size, embed_dim, num_heads, mlp_dim, num_layers, dropout_rate,
                                 n_splits=5, epochs=100, batch_size=32, vit_version = 1, val_set = 0.2,
                                 do_opt = False,models_folder = "models", results_folder = "results"):
    
    if not os.path.exists(models_folder):
        os.makedirs(models_folder)

    if not os.path.exists(results_folder):
        os.makedirs(results_folder)
        
        # Initialize variables for tracking the best model
    best_val_accuracy = 0
    best_model_filepath = ""
    
    accuracies = []
    test_losses = []
    test_accuracies = []
    
    # Initialize lists to store precision, recall, and F1 scores
    precisions = []
    recalls = []
    f1_scores = []
    
    # Initialize lists to store losses and accuracies for each epoch
    mean_training_losses = []
    mean_training_accuracies = []
    mean_val_losses = []   
    mean_val_accuracies = []
    
    fold = 1
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)
    
    for train_index, test_index in skf.split(X, y):
        # Split the data into training and validation sets
        print("=" * 40)
        print(f"Fold: {fold}")
        print("Splitting the data")
        X_train_full, X_test = X[train_index], X[test_index]
        y_train_full, y_test = y[train_index], y[test_index]
        
        # Standardize the data
        print("Standardizing the data")
        X_train_full, X_test = standardize_data(X_train_full, X_test)
        
        # Reshape the data
        print("Reshaping the data for deep learning models")
        X_train_full, X_test = reshape_data(X_train_full, X_test)
        
        # Input shape and number of classes for the model
        input_shape = (X_train_full.shape[1], 1)
        num_classes = len(np.unique(y))
        
        X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size = 0.2, random_state = seed_value, stratify = y_train_full)
        num_patches = input_shape[0] // patch_size
        try:
            if do_opt:
                # Create the model
                model = create_vit(input_shape, patch_size, num_patches, num_classes,
                                embed_dim, num_heads, mlp_dim, num_layers, dropout_rate)
                model.summary()
                # Compile the model
                model.compile(
                    optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
            else:
                # Create the model
                print("Building the vit model with the following hyperparameters:")
                print(f"Patch size: {learning_rate}")
                print(f"num_patches: {num_patches}") 
                print(f"embed_dim: {embed_dim}")
                print(f"num_heads: {num_heads}")
                print(f"mlp_dim: {mlp_dim}")
                print(f"num_layers: {num_layers}")
                print(f"dropout_rate: {dropout_rate}")
                model = create_vit(input_shape, patch_size, num_patches, num_classes,
                                embed_dim, num_heads, mlp_dim, num_layers, dropout_rate)
                model.summary()
                # Compile the model
                model.compile(
                    optimizer=Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
            if model is not None:
                "Build VIT"
                # model.summary()
            else:
                print("Failed to build the VIT model.")
        except Exception as e:
            print(f"Error while building the VIT model: {e}")
        
        print("Saving the data")
        fold_data = {

            'X_train': X_train,
            'X_val': X_val,
            'X_test': X_test,
            'y_train': y_train,
            'y_val': y_val,
            'y_test': y_test
        }

        with open(f"/kaggle/working/CV_fold_data/fold_{fold}_data.pkl", 'wb') as f:
            pickle.dump(fold_data, f)
        
        filepath = f'/kaggle/working/CV_VIT_models/temp_best_fold_{fold}.h5'
        # the ModelCheckpoint callback to save the best model of the current fold
        model_checkpoint_callback = ModelCheckpoint(
            filepath=os.path.join(filepath),
            save_best_only=True,
            monitor='val_accuracy',
            mode='max'
        )
        
        print("Training the model")
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val),
                           callbacks=[model_checkpoint_callback])
         
        # Check if this model is the best so far
        max_val_accuracy_this_fold = max(history.history['val_accuracy'])
        if max_val_accuracy_this_fold > best_val_accuracy:
            best_val_accuracy = max_val_accuracy_this_fold
            best_model_filepath = filepath
            
        if best_model_filepath:
            best_model = tf.keras.models.load_model(
                best_model_filepath,
                custom_objects={'ClassToken': ClassToken, 'TransformerBlock': TransformerBlock})
            print(f"The best model was loaded and ready to be evaluated")
        
        
        
        
        y_pred = np.argmax(model.predict(X_test), axis=-1)
        accuracy = accuracy_score(y_test, y_pred)
        test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
        
            # Calculate precision, recall, and F1 score
        precision = precision_score(y_test, y_pred, average='macro')
        recall = recall_score(y_test, y_pred, average='macro')
        f1 = f1_score(y_test, y_pred, average='macro')

        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")

        # Append the scores to the lists
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        
        # Append the losses and accuracies for each epoch to the respective lists
        for epoch in range(epochs):
            if fold == 1:
                # For the first fold, initialize the lists with the first fold's values
                mean_training_losses.append(history.history['loss'][epoch])
                mean_training_accuracies.append(history.history['accuracy'][epoch])
                mean_val_losses.append(history.history['val_loss'][epoch])
                mean_val_accuracies.append(history.history['val_accuracy'][epoch])
            else:
                # For subsequent folds, add the fold's values to the running sum
                mean_training_losses[epoch] += history.history['loss'][epoch]
                mean_training_accuracies[epoch] += history.history['accuracy'][epoch]
                mean_val_losses[epoch] += history.history['val_loss'][epoch]
                mean_val_accuracies[epoch] += history.history['val_accuracy'][epoch]

        # Save the model
        if do_opt:
            model_filename = f"VIT_v{vit_version}_opt_{batch_size}_{epochs}_seed{seed_value}.h5"
        else:
            model_filename = f"VIT_v{vit_version}_{batch_size}_{epochs}_seed{seed_value}.h5"
        model_filepath = os.path.join(models_folder, f"fold_{fold}_split_{n_splits}_{model_filename}")
        model.save(model_filepath)

        # Save the results as a JSON file
        if do_opt:
            results_filename = f"VIT_v{vit_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            results_filename = f"VIT_v{vit_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filepath = os.path.join(results_folder, f"fold_{fold}_split_{n_splits}_{results_filename}")

        results = {
            "fold": fold,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "f1_scores": f1_scores,
            "test_loss": test_loss,
            "test_accuracy": test_accuracy,
            "training_loss": history.history['loss'],
            "training_accuracy": history.history['accuracy'],
            "validation_loss": history.history['val_loss'],
            "validation_accuracy": history.history['val_accuracy'],
        }

        with open(results_filepath, "w") as results_file:
            json.dump(results, results_file, indent=4)
        
        # Append the results to the lists
        accuracies.append(accuracy)
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)
        
        print(f"Fold {fold}, Accuracy: {accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
        print("=" * 40)
        fold += 1

    # At the end, divide the sums by the number of folds to get the mean
    mean_training_losses = [loss / n_splits for loss in mean_training_losses]
    mean_training_accuracies = [acc / n_splits for acc in mean_training_accuracies]
    mean_val_losses = [loss / n_splits for loss in mean_val_losses]
    mean_val_accuracies = [acc / n_splits for acc in mean_val_accuracies]
    # Convert lists to numpy arrays for easier calculation of mean and standard deviation
    mean_accuracy = np.mean(accuracies)
    mean_test_loss = np.mean(test_losses)
    mean_test_accuracy = np.mean(test_accuracies)

    # Calculate standard deviations
    std_accuracy = np.std(accuracies)
    std_test_loss = np.std(test_losses)
    std_test_accuracy = np.std(test_accuracies)

    std_training_loss = np.std(mean_training_losses)
    std_training_accuracy = np.std(mean_training_accuracies)
    std_val_loss = np.std(mean_val_losses)
    std_val_accuracy = np.std(mean_val_accuracies)

    precisions = np.array(precisions)
    recalls = np.array(recalls)
    f1_scores = np.array(f1_scores)

      
    print(f"test losses: {test_losses}")
    print(f"test accuracy: {test_accuracies}")
    
    print("*" * 40)
    print(f"Mean training loss over stratified {n_splits}-fold cross-validation: {np.mean(mean_training_losses):.4f}")
    print(f"Mean training accuracy over stratified {n_splits}-fold cross-validation: {np.mean(mean_training_accuracies):.4f}")
    print(f"Mean validation loss over stratified {n_splits}-fold cross-validation: {np.mean(mean_val_losses):.4f}")
    print(f"Mean validation accuracy over stratified {n_splits}-fold cross-validation: {np.mean(mean_val_accuracies):.4f}")
    print("*" * 40)
    print(f"Mean accuracy over stratified {n_splits}-fold cross-validation: {mean_accuracy:.4f}")
    print(f"Mean test loss over stratified {n_splits}-fold cross-validation: {mean_test_loss:.4f}")
    print(f"Mean test accuracy over stratified {n_splits}-fold cross-validation: {mean_test_accuracy:.4f}")
    print("*" * 40)

    print(f"Standard deviation of training loss over stratified {n_splits}-fold cross-validation: {np.std(mean_training_losses):.4f}")
    print(f"Standard deviation of training accuracy over stratified {n_splits}-fold cross-validation: {np.std(mean_training_accuracies):.4f}")
    print(f"Standard deviation of validation loss over stratified {n_splits}-fold cross-validation: {np.std(mean_val_losses):.4f}")
    print(f"Standard deviation of validation accuracy over stratified {n_splits}-fold cross-validation: {np.std(mean_val_accuracies):.4f}")
    print("*" * 40)
    print(f"Standard deviation of accuracy over stratified {n_splits}-fold cross-validation: {std_accuracy:.4f}")
    print(f"Standard deviation of test loss over stratified {n_splits}-fold cross-validation: {std_test_loss:.4f}")
    print(f"Standard deviation of test accuracy over stratified {n_splits}-fold cross-validation: {std_test_accuracy:.4f}")
    print("*" * 40)
    
    # Calculate and print the mean and standard deviation of precision, recall, and F1 score
    print(f"Mean precision over stratified {n_splits}-fold cross-validation: {np.mean(precisions):.4f}")
    print(f"Standard deviation of precision over stratified {n_splits}-fold cross-validation: {np.std(precisions):.4f}")
    print(f"Mean recall over stratified {n_splits}-fold cross-validation: {np.mean(recalls):.4f}")
    print(f"Standard deviation of recall over stratified {n_splits}-fold cross-validation: {np.std(recalls):.4f}")
    print(f"Mean F1 score over stratified {n_splits}-fold cross-validation: {np.mean(f1_scores):.4f}")
    print(f"Standard deviation of F1 score over stratified {n_splits}-fold cross-validation: {np.std(f1_scores):.4f}")

    
# Define the directory where the JSON files are stored

    fig, axes = plt.subplots(2, n_splits, figsize=(20, 10))

    for fold in range(1, n_splits+1):
        # Load the JSON file for this fold
        if do_opt:
            cnn_filename = f"VIT_v{vit_version}_opt_{batch_size}_{epochs}_seed{seed_value}.json"
        else:
            cnn_filename = f"VIT_v{vit_version}_{batch_size}_{epochs}_seed{seed_value}.json"
        results_filename = f"fold_{fold}_split_{n_splits}_{cnn_filename}"
        
        results_filepath = os.path.join(results_folder, results_filename)
        
        with open(results_filepath, "r") as results_file:
            results = json.load(results_file)
        
        # Plot training and validation loss
        axes[0, fold-1].plot(results["training_loss"], label='Train')
        axes[0, fold-1].plot(results["validation_loss"], label='Validation')
        axes[0, fold-1].set_title(f'Fold {fold} Loss')
        axes[0, fold-1].set_xlabel('Epochs')
        axes[0, fold-1].set_ylabel('Loss')
        axes[0, fold-1].legend()

        # Plot training and validation accuracy
        axes[1, fold-1].plot(results["training_accuracy"], label='Train')
        axes[1, fold-1].plot(results["validation_accuracy"], label='Validation')
        axes[1, fold-1].set_title(f'Fold {fold} Accuracy')
        axes[1, fold-1].set_xlabel('Epochs')
        axes[1, fold-1].set_ylabel('Accuracy')
        axes[1, fold-1].legend()

    plt.tight_layout()
    plt.show()
    
    return mean_val_accuracies

# %%
DL_EPOCH = 150
if DO_TRANSFORMER_VISION:
    # Train and evaluate deep learning models
    print("Building Transformer model...")
    patch_size = 30
    embed_dim = 64
    num_heads = 4
    mlp_dim = 128  # patch_size * patch_size * input_shape[1]
    num_layers = 4
    dropout_rate = 0.3

    # Create the model
    perform_vit_cross_validation(X,y, patch_size, embed_dim, num_heads, mlp_dim, num_layers, dropout_rate,
                                n_splits=DL_CV_FOLD, epochs=DL_EPOCH, batch_size=DL_BATCH_SIZE, 
                                vit_version = DL_TRANSFORMER_VISION_VERSION, val_set = 0.2,
                                do_opt = True, models_folder = "/kaggle/working/CV_VIT_models", results_folder = "/kaggle/working/CV_VIT_results")

# Train the model
print("Training and evaluating the model...")
# Start the timer
start_time = time.time()
model_history = model.fit(X_train, y_train, batch_size=DL_BATCH_SIZE,
                          epochs=DL_EPOCH, validation_data=(X_val, y_val), shuffle=True, callbacks=callbacks)
# End the timer
end_time = time.time()
# Calculate the elapsed time
elapsed_time = end_time - start_time
# Print the elapsed time
print("Training time: {:.2f} seconds".format(elapsed_time))
# Compile the model

# Save the deep learning model
print("Saving model to ", dl_model_path)
model.save(dl_model_path)

# Save the deep learning model's weights
print("Saving model weights to ", dl_weights_path)
model.save_weights(dl_weights_path)

# Evaluating the model
print("Evaluating the CNN model... ")
# Calculate model loss and accuracy
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_accuracy)

# Save the model's metrics
print("Saving the model metrics to ", dl_metrics_path)
save_dl_metrics(model_history, test_loss,
                test_accuracy, dl_metrics_path)

# Plot the model history
plot_dl_history(model_history)
# Out:
# Building Transformer model...
# ========================================
# Fold: 1
# Splitting the data
# Standardizing the data
# Reshaping the data for deep learning models
# Input shape: (None, 270, 1)
# No. of patches: 9
# Num Patches: 9
# Patch Embed shape: (None, 9, 64)
# Positions shape: (9,)
# Positional Embed shape: (9, 64)
# Embed shape: (None, 9, 64)
# Model: "model_18"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 270, 1)]     0           []
#
#  conv1d_2 (Conv1D)              (None, 9, 64)        1984        ['input_15[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 9, 64)       0           ['conv1d_2[0][0]']
#  mbda)
#
#  class_token_2 (ClassToken)     (None, 1, 64)        64          ['tf.__operators__.add_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 10, 64)       0           ['class_token_2[0][0]',
#                                                                   'tf.__operators__.add_2[0][0]']
#
#  transformer_block_8 (Transform  (None, 10, 64)      83072       ['concatenate_2[0][0]']
#  erBlock)
#
#  transformer_block_9 (Transform  (None, 10, 64)      83072       ['transformer_block_8[0][0]']
#  erBlock)
#
#  transformer_block_10 (Transfor  (None, 10, 64)      83072       ['transformer_block_9[0][0]']
#  merBlock)
#
#  transformer_block_11 (Transfor  (None, 10, 64)      83072       ['transformer_block_10[0][0]']
#  merBlock)
#
#  tf.__operators__.getitem_2 (Sl  (None, 64)          0           ['transformer_block_11[0][0]']
#  icingOpLambda)
#
#  dropout_66 (Dropout)           (None, 64)           0           ['tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  dense_34 (Dense)               (None, 3)            195         ['dropout_66[0][0]']
#
# ==================================================================================================
# Total params: 334,531
# Trainable params: 334,531
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Saving the data
# Training the model
# Epoch 1/150
# 48/48 [==============================] - 14s 35ms/step - loss: 2.3985 - accuracy: 0.3162 - val_loss: 1.2391 - val_accuracy: 0.4316
# Epoch 2/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.9404 - accuracy: 0.3913 - val_loss: 1.0969 - val_accuracy: 0.4421
# Epoch 3/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.9222 - accuracy: 0.3353 - val_loss: 1.1481 - val_accuracy: 0.4342
# Epoch 4/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.7470 - accuracy: 0.3702 - val_loss: 1.0987 - val_accuracy: 0.4447
# Epoch 5/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.6574 - accuracy: 0.3742 - val_loss: 1.0636 - val_accuracy: 0.4711
# Epoch 6/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.5778 - accuracy: 0.3854 - val_loss: 1.0678 - val_accuracy: 0.4579
# Epoch 7/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.5255 - accuracy: 0.3920 - val_loss: 1.0552 - val_accuracy: 0.4763
# Epoch 8/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.5734 - accuracy: 0.3682 - val_loss: 1.0630 - val_accuracy: 0.4474
# Epoch 9/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.4340 - accuracy: 0.4091 - val_loss: 1.0643 - val_accuracy: 0.4684
# Epoch 10/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.4507 - accuracy: 0.4084 - val_loss: 1.0345 - val_accuracy: 0.4711
# Epoch 11/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.4987 - accuracy: 0.3768 - val_loss: 1.0521 - val_accuracy: 0.4421
# Epoch 12/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.4721 - accuracy: 0.3775 - val_loss: 1.1023 - val_accuracy: 0.4553
# Epoch 13/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.4314 - accuracy: 0.3748 - val_loss: 1.0469 - val_accuracy: 0.4342
# Epoch 14/150
# 48/48 [==============================] - 1s 19ms/step - loss: 1.3862 - accuracy: 0.3926 - val_loss: 1.0299 - val_accuracy: 0.4737
# Epoch 15/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.3865 - accuracy: 0.3814 - val_loss: 1.0316 - val_accuracy: 0.4711
# Epoch 16/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.3308 - accuracy: 0.3959 - val_loss: 1.0181 - val_accuracy: 0.4921
# Epoch 17/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.3470 - accuracy: 0.3992 - val_loss: 1.0138 - val_accuracy: 0.4789
# Epoch 18/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.3444 - accuracy: 0.3893 - val_loss: 1.0122 - val_accuracy: 0.4737
# Epoch 19/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.3465 - accuracy: 0.3748 - val_loss: 1.0106 - val_accuracy: 0.4842
# Epoch 20/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.3232 - accuracy: 0.3867 - val_loss: 1.0083 - val_accuracy: 0.4816
# Epoch 21/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.3286 - accuracy: 0.3827 - val_loss: 1.0064 - val_accuracy: 0.5053
# Epoch 22/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.3094 - accuracy: 0.4012 - val_loss: 1.0044 - val_accuracy: 0.4947
# Epoch 23/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.3252 - accuracy: 0.3781 - val_loss: 1.0076 - val_accuracy: 0.4895
# Epoch 24/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.2884 - accuracy: 0.3953 - val_loss: 0.9969 - val_accuracy: 0.4868
# Epoch 25/150
# 48/48 [==============================] - 1s 19ms/step - loss: 1.2728 - accuracy: 0.3953 - val_loss: 0.9939 - val_accuracy: 0.5053
# Epoch 26/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.2612 - accuracy: 0.4203 - val_loss: 1.0114 - val_accuracy: 0.4842
# Epoch 27/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.2373 - accuracy: 0.4065 - val_loss: 1.0017 - val_accuracy: 0.4895
# Epoch 28/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.2302 - accuracy: 0.4091 - val_loss: 0.9912 - val_accuracy: 0.4921
# Epoch 29/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.1927 - accuracy: 0.4381 - val_loss: 1.0134 - val_accuracy: 0.4842
# Epoch 30/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1
150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.4456 - accuracy: 0.8241 - val_loss: 0.6723 - val_accuracy: 0.7368
# Epoch 142/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.4915 - accuracy: 0.7938 - val_loss: 0.7189 - val_accuracy: 0.7289
# Epoch 143/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.4583 - accuracy: 0.8202 - val_loss: 0.6667 - val_accuracy: 0.7579
# Epoch 144/150
# 48/48 [==============================] - 1s 22ms/step - loss: 0.4929 - accuracy: 0.7912 - val_loss: 0.6331 - val_accuracy: 0.7658
# Epoch 145/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.4658 - accuracy: 0.8129 - val_loss: 0.6773 - val_accuracy: 0.7421
# Epoch 146/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.4718 - accuracy: 0.8123 - val_loss: 0.6410 - val_accuracy: 0.7474
# Epoch 147/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.4495 - accuracy: 0.8333 - val_loss: 0.6879 - val_accuracy: 0.7500
# Epoch 148/150
# 48/48 [==============================] - 1s 19ms/step - loss: 0.4543 - accuracy: 0.8162 - val_loss: 0.6983 - val_accuracy: 0.7263
# Epoch 149/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.4606 - accuracy: 0.8162 - val_loss: 0.7062 - val_accuracy: 0.7421
# Epoch 150/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.4950 - accuracy: 0.8017 - val_loss: 0.6670 - val_accuracy: 0.7368
# The best model was loaded and ready to be evaluated
# 15/15 [==============================] - 1s 6ms/step
# Precision: 0.7584
# Recall: 0.7514
# F1 Score: 0.7516
# Fold 1, Accuracy: 0.7579, Test Loss: 0.6131, Test Accuracy: 0.7579
# ========================================
# ========================================
# Fold: 2
# Splitting the data
# Standardizing the data
# Reshaping the data for deep learning models
# Input shape: (None, 270, 1)
# No. of patches: 9
# Num Patches: 9
# Patch Embed shape: (None, 9, 64)
# Positions shape: (9,)
# Positional Embed shape: (9, 64)
# Embed shape: (None, 9, 64)
# Model: "model_27"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_24 (InputLayer)          [(None, 270, 1)]     0           []
#
#  conv1d_3 (Conv1D)              (None, 9, 64)        1984        ['input_24[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 9, 64)       0           ['conv1d_3[0][0]']
#  mbda)
#
#  class_token_3 (ClassToken)     (None, 1, 64)        64          ['tf.__operators__.add_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 10, 64)       0           ['class_token_3[0][0]',
#                                                                   'tf.__operators__.add_3[0][0]']
#
#  transformer_block_12 (Transfor  (None, 10, 64)      83072       ['concatenate_3[0][0]']
#  merBlock)
#
#  transformer_block_13 (Transfor  (None, 10, 64)      83072       ['transformer_block_12[0][0]']
#  merBlock)
#
#  transformer_block_14 (Transfor  (None, 10, 64)      83072       ['transformer_block_13[0][0]']
#  merBlock)
#
#  transformer_block_15 (Transfor  (None, 10, 64)      83072       ['transformer_block_14[0][0]']
#  merBlock)
#
#  tf.__operators__.getitem_3 (Sl  (None, 64)          0           ['transformer_block_15[0][0]']
#  icingOpLambda)
#
#  dropout_99 (Dropout)           (None, 64)           0           ['tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  dense_51 (Dense)               (None, 3)            195         ['dropout_99[0][0]']
#
# ==================================================================================================
# Total params: 334,531
# Trainable params: 334,531
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Saving the data
# Training the model
# Epoch 1/150
# 48/48 [==============================] - 14s 35ms/step - loss: 2.0575 - accuracy: 0.3689 - val_loss: 1.1873 - val_accuracy: 0.4579
# Epoch 2/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.8948 - accuracy: 0.3551 - val_loss: 1.0923 - val_accuracy: 0.4079
# Epoch 3/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.7479 - accuracy: 0.3630 - val_loss: 1.0642 - val_accuracy: 0.4868
# Epoch 4/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.7232 - accuracy: 0.3531 - val_loss: 1.0892 - val_accuracy: 0.4474
# Epoch 5/150
# 48/48 [==============================] - 1s 19ms/step - loss: 1.6524 - accuracy: 0.3610 - val_loss: 1.0480 - val_accuracy: 0.4684
# Epoch 6/150
# 48/48 [==============================] - 1s 20ms/step - loss: 1.5954 - accuracy: 0.3821 - val_loss: 1.0433 - val_accuracy: 0.4658
# Epoch 7/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.6167 - accuracy: 0.3498 - val_loss: 1.0262 - val_accuracy: 0.4789
# Epoch 8/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.5051 - accuracy: 0.3577 - val_loss: 1.0272 - val_accuracy: 0.4289
# Epoch 9/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.4633 - accuracy: 0.3748 - val_loss: 1.0367 - val_accuracy: 0.4605
# Epoch 10/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.4696 - accuracy: 0.3748 - val_loss: 1.0248 - val_accuracy: 0.4553
# Epoch 11/150
# 48/48 [==============================] - 1s 19ms/step - loss: 1.3719 - accuracy: 0.3821 - val_loss: 1.0266 - val_accuracy: 0.4132
# Epoch 12/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.4218 - accuracy: 0.3676 - val_loss: 1.0132 - val_accuracy: 0.4895
# Epoch 13/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.3618 - accuracy: 0.3821 - val_loss: 1.0237 - val_accuracy: 0.4684
# Epoch 14/150
# 48/48 [==============================] - 1s 22ms/step - loss: 1.3470 - accuracy: 0.3742 - val_loss: 1.0157 - val_accuracy: 0.5053
# Epoch 15/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.3602 - accuracy: 0.3854 - val_loss: 1.0135 - val_accuracy: 0.4868
# Epoch 16/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.3584 - accuracy: 0.3775 - val_loss: 1.0175 - val_accuracy: 0.4579
# Epoch 17/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.3542 - accuracy: 0.3794 - val_loss: 1.0271 - val_accuracy: 0.4658
# Epoch 18/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.2898 - accuracy: 0.4051 - val_loss: 1.0326 - val_accuracy: 0.4684
# Epoch 19/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.2765 - accuracy: 0.3887 - val_loss: 1.0088 - val_accuracy: 0.4789
# Epoch 20/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.2911 - accuracy: 0.3874 - val_loss: 1.0087 - val_accuracy: 0.4921
# Epoch 21/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.2930 - accuracy: 0.3775 - val_loss: 1.0069 - val_accuracy: 0.4658
# Epoch 22/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.2483 - accuracy: 0.4058 - val_loss: 1.0151 - val_accuracy: 0.4500
# Epoch 23/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.2276 - accuracy: 0.4183 - val_loss: 1.0027 - val_accuracy: 0.4842
# Epoch 24/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.1907 - accuracy: 0.4203 - val_loss: 1.0040 - val_accuracy: 0.4921
# Epoch 25/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.2524 - accuracy: 0.3953 - val_loss: 0.9988 - val_accuracy: 0.4842
# Epoch 26/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.2524 - accuracy: 0.3933 - val_loss: 1.0016 - val_accuracy: 0.4947
# Epoch 27/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.2463 - accuracy: 0.3953 - val_loss: 1.0021 - val_accuracy: 0.4868
# Epoch 28/150
# 48/48 [==============================] - 1s 20ms/step - loss: 1.2103 - accuracy: 0.4130 - val_loss: 0.9964 - val_accuracy: 0.5132
# Epoch 29/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.2093 - accuracy: 0.4203 - val_loss: 1.0060 - val_accuracy: 0.4895
# Epoch 30/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.2075 - accuracy: 0.3953 - val_loss: 0.9930 - val_accuracy: 0.4947
# Epoch 31/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.1884 - accuracy: 0.4058 - val_loss: 0.9890 - val_accuracy: 0.4947
# Epoch 32/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.1921 - accuracy: 0.4170 - val_loss: 0.9868 - val_accuracy: 0.4921
# Epoch 33/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.1629 - accuracy: 0.4354 - val_loss: 0.9934 - val_accuracy: 0.5000
# Epoch 34/150
# 48/48 [==============================] - 1s 17ms/step - loss: 1.2012 - accuracy: 0.3992 - val_loss: 0.9795 - val_accuracy: 0.5026
# Epoch 35/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.1895 - accuracy: 0.4236 - val_loss: 0.9859 - val_accuracy: 0.5105
# Epoch 36/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.1657 - accuracy: 0.4236 - val_loss: 0.9803 - val_accuracy: 0.5000
# Epoch 37/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.1780 - accuracy: 0.4137 - val_loss: 0.9776 - val_accuracy: 0.5079
# Epoch 38/150
# 48/48 [==============================] - 1s 19ms/step - loss: 1.1833 - accuracy: 0.4025 - val_loss: 0.9714 - val_accuracy: 0.4974
# Epoch 39/150
# 48/48 [==============================] - 1s 19ms/step - loss: 1.1485 - accuracy: 0.4315 - val_loss: 0.9721 - val_accuracy: 0.5079
# Epoch 40/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.1459 - accuracy: 0.4308 - val_loss: 0.9659 - val_accuracy: 0.5026
# Epoch 41/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.1253 - accuracy: 0.4480 - val_loss: 0.9611 - val_accuracy: 0.5184
# Epoch 42/150
# 48/48 [==============================] - 1s 24ms/step - loss: 1.1279 - accuracy: 0.4407 - val_loss: 0.9849 - val_accuracy: 0.5263
# Epoch 43/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1.1243 - accuracy: 0.4381 - val_loss: 0.9505 - val_accuracy: 0.5237
# Epoch 44/150
# 48/48 [==============================] - 1s 21ms/step - loss: 1.1067 - accuracy: 0.4341 - val_loss: 0.9459 - val_accuracy: 0.5342
# Epoch 45/150
# 48/48 [==============================] - 1s 22ms/step - loss: 1.0954 - accuracy: 0.4578 - val_loss: 0.9405 - val_accuracy: 0.5421
# Epoch 46/150
# 48/48 [==============================] - 1s 22ms/step - loss: 1.1183 - accuracy: 0.4374 - val_loss: 0.9262 - val_accuracy: 0.5526
# Epoch 47/150
# 48/48 [==============================] - 1s 18ms/step - loss: 1
150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.6766 - accuracy: 0.7036 - val_loss: 0.7037 - val_accuracy: 0.6895
# Epoch 101/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.6630 - accuracy: 0.7167 - val_loss: 0.6902 - val_accuracy: 0.6921
# Epoch 102/150
# 48/48 [==============================] - 1s 17ms/step - loss: 0.6432 - accuracy: 0.7101 - val_loss: 0.6844 - val_accuracy: 0.6947
# Epoch 103/150
# 48/48 [==============================] - 1s 21ms/step - loss: 0.6183 - accuracy: 0.7273 - val_loss: 0.6909 - val_accuracy: 0.7053
# Epoch 104/150
# 48/48 [==============================] - 1s 17ms/step - loss: 0.6698 - accuracy: 0.7227 - val_loss: 0.7004 - val_accuracy: 0.6895
# Epoch 105/150
# 48/48 [==============================] - 1s 17ms/step - loss: 0.6186 - accuracy: 0.7372 - val_loss: 0.6963 - val_accuracy: 0.7000
# Epoch 106/150
# 48/48 [==============================] - 1s 17ms/step - loss: 0.6260 - accuracy: 0.7312 - val_loss: 0.7408 - val_accuracy: 0.6684
# Epoch 107/150
# 48/48 [==============================] - 1s 17ms/step - loss: 0.6120 - accuracy: 0.7352 - val_loss: 0.7217 - val_accuracy: 0.6921
# Epoch 108/150
# 48/48 [==============================] - 1s 20ms/step - loss: 0.5926 - accuracy: 0.7596 - val_loss: 0.6855 - val_accuracy: 0.7211
# Epoch 109/150
# 48/48 [==============================] - 1s 17ms/step - loss: 0.6110 - accuracy: 0.7306 - val_loss: 0.7057 - val_accuracy: 0.7158
# Epoch 110/150
# 48/48 [==============================] - 1s 20ms/step - loss: 0.5799 - accuracy: 0.7596 - val_loss: 0.6737 - val_accuracy: 0.7289
# Epoch 111/150
# 48/48 [==============================] - 1s 20ms/step - loss: 0.5981 - accuracy: 0.7569 - val_loss: 0.7175 - val_accuracy: 0.7079
# Epoch 112/150
# 48/48 [==============================] - 1s 20ms/step - loss: 0.6002 - accuracy: 0.7358 - val_loss: 0.7877 - val_accuracy: 0.6553
# Epoch 113/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.5800 - accuracy: 0.7530 - val_loss: 0.6774 - val_accuracy: 0.7289
# Epoch 114/150
# 48/48 [==============================] - 1s 19ms/step - loss: 0.5760 - accuracy: 0.7536 - val_loss: 0.6786 - val_accuracy: 0.7026
# Epoch 115/150
# 48/48 [==============================] - 1s 21ms/step - loss: 0.5775 - accuracy: 0.7490 - val_loss: 0.6591 - val_accuracy: 0.7447
# Epoch 116/150
# 48/48 [==============================] - 1s 17ms/step - loss: 0.5742 - accuracy: 0.7655 - val_loss: 0.6909 - val_accuracy: 0.7263
# Epoch 117/150
# 48/48 [==============================] - 1s 17ms/step - loss: 0.5711 - accuracy: 0.7635 - val_loss: 0.6484 - val_accuracy: 0.7447
# Epoch 118/150
# 48/48 [==============================] - 1s 17ms/step - loss: 0.5420 - accuracy: 0.7734 - val_loss: 0.6916 - val_accuracy: 0.7184
# Epoch 119/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.5491 - accuracy: 0.7701 - val_loss: 0.6480 - val_accuracy: 0.7447
# Epoch 120/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.5433 - accuracy: 0.7760 - val_loss: 0.6779 - val_accuracy: 0.7289
# Epoch 121/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.5478 - accuracy: 0.7694 - val_loss: 0.6515 - val_accuracy: 0.7368
# Epoch 122/150
# 48/48 [==============================] - 1s 20ms/step - loss: 0.5307 - accuracy: 0.7773 - val_loss: 0.6289 - val_accuracy: 0.7632
# Epoch 123/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.5164 - accuracy: 0.7787 - val_loss: 0.6661 - val_accuracy: 0.7500
# Epoch 124/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.4970 - accuracy: 0.7892 - val_loss: 0.6334 - val_accuracy: 0.7605
# Epoch 125/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.5197 - accuracy: 0.7885 - val_loss: 0.6412 - val_accuracy: 0.7500
# Epoch 126/150
# ...
# Epoch 59/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0
150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.3926 - accuracy: 0.8348 - val_loss: 0.6461 - val_accuracy: 0.7526
# Epoch 145/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.3979 - accuracy: 0.8512 - val_loss: 0.6663 - val_accuracy: 0.7474
# Epoch 146/150
# 48/48 [==============================] - 1s 21ms/step - loss: 0.3920 - accuracy: 0.8446 - val_loss: 0.6228 - val_accuracy: 0.7816
# Epoch 147/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.3718 - accuracy: 0.8611 - val_loss: 0.6594 - val_accuracy: 0.7447
# Epoch 148/150
# 48/48 [==============================] - 1s 19ms/step - loss: 0.4030 - accuracy: 0.8387 - val_loss: 0.6966 - val_accuracy: 0.7395
# Epoch 149/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.3724 - accuracy: 0.8532 - val_loss: 0.6537 - val_accuracy: 0.7737
# Epoch 150/150
# 48/48 [==============================] - 1s 18ms/step - loss: 0.3886 - accuracy: 0.8440 - val_loss: 0.6527 - val_accuracy: 0.7395
# The best model was loaded and ready to be evaluated
# 15/15 [==============================] - 1s 6ms/step
# Precision: 0.8053
# Recall: 0.7769
# F1 Score: 0.7796
# Fold 5, Accuracy: 0.7890, Test Loss: 0.5685, Test Accuracy: 0.7890
# ========================================
# test losses: [0.613121509552002, 0.8989877104759216, 0.6255341172218323, 0.7531219124794006, 0.5684969425201416]
# test accuracy: [0.75789475440979, 0.7178947329521179, 0.7726315855979919, 0.74472576379776, 0.7890295386314392]
# ****************************************
# Mean training loss over stratified 5-fold cross-validation: 0.8576
# Mean training accuracy over stratified 5-fold cross-validation: 0.6177
# Mean validation loss over stratified 5-fold cross-validation: 0.8318
# Mean validation accuracy over stratified 5-fold cross-validation: 0.6215
# ****************************************
# Mean accuracy over stratified 5-fold cross-validation: 0.7564
# Mean test loss over stratified 5-fold cross-validation: 0.6919
# Mean test accuracy over stratified 5-fold cross-validation: 0.7564
# ****************************************
# Standard deviation of training loss over stratified 5-fold cross-validation: 0.3619
# Standard deviation of training accuracy over stratified 5-fold cross-validation: 0.1630
# Standard deviation of validation loss over stratified 5-fold cross-validation: 0.1435
# Standard deviation of validation accuracy over stratified 5-fold cross-validation: 0.1085
# ****************************************
# Standard deviation of accuracy over stratified 5-fold cross-validation: 0.0243
# Standard deviation of test loss over stratified 5-fold cross-validation: 0.1204
# Standard deviation of test accuracy over stratified 5-fold cross-validation: 0.0243
# ****************************************
# Mean precision over stratified 5-fold cross-validation: 0.7623
# Standard deviation of precision over stratified 5-fold cross-validation: 0.0261
# Mean recall over stratified 5-fold cross-validation: 0.7504
# Standard deviation of recall over stratified 5-fold cross-validation: 0.0200
# Mean F1 score over stratified 5-fold cross-validation: 0.7501
# Standard deviation of F1 score over stratified 5-fold cross-validation: 0.0210
# Training and evaluating the model...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 22
#      20 # Start the timer
#      21 start_time = time.time()
# ---> 22 model_history = model.fit(X_train, y_train, batch_size=DL_BATCH_SIZE,
#      23                           epochs=DL_EPOCH, validation_data=(X_val, y_val), shuffle=True, callbacks=callbacks)
#      24 # End the timer
#      25 end_time = time.time()
#
# NameError: name 'model' is not defined
